# %%
from __future__ import division
import pandas as pd
import numpy as np

from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.preprocessing import MinMaxScaler

import matplotlib.pyplot as plt
import time, os, math, warnings
from matplotlib import pyplot

import tensorflow as tf
from keras.models import Sequential, Model
from keras.layers import Input, Dense, Dropout, Activation, Flatten, TimeDistributed, Reshape
from keras.layers.recurrent import LSTM, GRU, SimpleRNN
from keras.utils import plot_model
# Out:
# Using TensorFlow backend.

# %%
# Set up some global variables
USE_GPU = True

if USE_GPU:
    device = '/device:GPU:0'
else:
    device = '/cpu:0'

# Constant to control how often we print when training models
print_every = 100

print('Using device: ', device)
# Out:
# Using device:  /device:GPU:0

# %% [markdown]
# ### Pre-processing Functions

# %% [markdown]
# Reshape input data

# %%
# Every "looK_back" X points, only one Y, does not predict future. 
def reshape_data(X, Y, look_back=1):
    dataX, dataY = [], []
    for i in range(len(X) - look_back):
        a = X[i:(i + look_back), :]
        dataX.append(a)
        dataY.append(Y[i + look_back, :])
    print('# of data: ', len(dataY))
    return np.array(dataX), np.array(dataY)

# %% [markdown]
# ### Plotting Functions

# %%
# %matplotlib inline
plt.rcParams['figure.figsize'] = (10.0, 8.0) # set default size of plots
plt.rcParams['image.interpolation'] = 'nearest'
plt.rcParams['image.cmap'] = 'gray'

# for auto-reloading external modules
# see http://stackoverflow.com/questions/1907993/autoreload-of-modules-in-ipython
# %load_ext autoreload
# %autoreload 2



def plot_pressure(t, q_actual, q_pred, dev_fraction, test_fraction, well):
    """This function plots actual and predicted bottom hole pressure"""
    # Plotting pwf v time
    plt.figure()
    plt.plot(t, q_actual, 'k-', linewidth=3, label='Actual oil rate')

    # Training
    train_end = int((1 - dev_fraction - test_fraction) * q_pred.shape[0])
    plt.plot(t[0:train_end], q_pred[0:train_end],
                 'r-', markeredgecolor='red', label='Training Set', linewidth=3)
    
    # Dev
    dev_end = int((1 - test_fraction) * q_pred.shape[0])
    plt.plot(t[train_end:dev_end], q_pred[train_end:dev_end],
                 'y-', markeredgecolor='orange', label='Dev Set', linewidth=3)
    
    # Test
    plt.plot(t[dev_end:], q_pred[dev_end:],
                 'g-', markeredgecolor='green', label='Test Set', linewidth=3)    
    
    plt.xlabel("Time (hours)", fontsize=14)
    plt.ylabel("Bottom Hole Pressure (psi)", fontsize=14)
    plt.title("Bottom Hole Pressure Well "+str(well), y=1, fontsize=13)
    plt.legend(loc="best", prop=dict(size=14))
    plt.xlim(0, max(t))
    plt.ylim(0, max(max(q_actual), max(q_pred)) + 10)
    plt.grid(True)

def plot_pred_rate(t, q_actual, q_pred, dev_fraction, test_fraction, well):
    """This function plots actual and predicted bottom hole pressure"""
    # Plotting pwf v time
    plt.figure()
    plt.plot(t, q_actual, 'k-', linewidth=3, label='Actual oil rate')

    # Training
    train_end = int((1 - dev_fraction - test_fraction) * q_pred.shape[0])
    plt.plot(t[0:train_end], q_pred[0:train_end],
                 'r-', markeredgecolor='red', label='Training Set', linewidth=3)
    
    # Dev
    dev_end = int((1 - test_fraction) * q_pred.shape[0])
    plt.plot(t[train_end:dev_end], q_pred[train_end:dev_end],
                 'y-', markeredgecolor='orange', label='Dev Set', linewidth=3)
    
    # Test
    plt.plot(t[dev_end:], q_pred[dev_end:],
                 'g-', markeredgecolor='green', label='Test Set', linewidth=3)    
    
    plt.xlabel("Time (hours)", fontsize=14)
    plt.ylabel("Flow Rate (STB/d)", fontsize=14)
    plt.title("Flow Rate Well " +str(well), y=1, fontsize=13)
    plt.legend(loc="best", prop=dict(size=14))
    plt.xlim(0, max(t))
    plt.ylim(0, max(max(q_actual), max(q_pred)) + 10)
    plt.grid(True)

def plot_rates(t, q, wellname, color, label):
    """This function plots actual flow rates"""
    # Plotting Flow Rate v time
    plt.plot(t, q, color, linewidth=3, label=label)
    plt.xlabel("Time (hours)", fontsize=11)
    plt.ylabel("Flow Rate (STB/D)", fontsize=11)
    plt.title('Flow Rate Well ' + wellname, y=0.82, fontsize=9)
    plt.legend(loc=1, prop=dict(size=8))
    plt.xlim(0, max(t))
    plt.ylim(0, max(q) + 10)
    plt.grid(True)

def plot_pressure_rates(x, y, y_pred, labelname):
    """This function plots both pressure and actual flow rates"""
    plt.figure()
    if labelname=='Training Data':
        color='red'
    else:
        color='green'

    plt.subplot(411)
    plot_pressure(x['TIME'], y, y_pred, labelname, color)

    plt.subplot(412)
    plot_rates(x['TIME'], x['WWPR:P1'], wellname='A', color='blue', label='Water Rate')
    plot_rates(x['TIME'], x['WOPR:P1'], wellname='A', color='green', label='Oil Rate')
    plt.ylim(0, max(max(x['WWPR:P1'].values), max(x['WOPR:P1'].values)) + 10)

    plt.subplot(413)
    plot_rates(x['TIME'], x['WOPR:P2'],wellname='B',color='green', label='Oil Rate')
    plot_rates(x['TIME'], x['WWPR:P2'],wellname='B',color='blue', label='Water Rate')
    plt.ylim(0, max(max(x['WWPR:P2'].values), max(x['WOPR:P2'].values)) + 10)

    plt.subplot(414)
    plot_rates(x['TIME'], x['WOPR:P3'], wellname='C', color='green', label='Oil Rate')
    plot_rates(x['TIME'], x['WWPR:P3'], wellname='C', color='blue', label='Water Rate')
    plt.ylim(0, max(max(x['WWPR:P3'].values), max(x['WOPR:P3'].values)) + 10)

def plot_loss(history, title):
    plt.figure()
    plt.plot(history.history['loss'], label='Train Loss', linewidth=3)
    plt.plot(history.history['val_loss'], label='Dev Loss', linewidth=3)
    plt.legend()
    plt.grid()
    plt.xlabel("No of Epochs", fontsize=15)
    plt.ylabel("Loss", fontsize=15)
    plt.title('Loss - ' + title, fontsize=15)
    plt.xlim(0, len(history.history['loss']))
    plt.ylim(0, max(history.history['val_loss']))
    plt.show()

def plot_loss_comparison(histories):
    plt.figure()
    plt.plot(histories['Simple RNN'].history['val_loss'], linewidth=3, label='Simple RNN')
    plt.plot(histories['GRU'].history['val_loss'], linewidth=3, label='GRU')
    plt.plot(histories['LSTM'].history['val_loss'], linewidth=3, label='LSTM')
    plt.legend()
    plt.grid()
    plt.xlabel("No of Epochs", fontsize=15)
    plt.ylabel("Loss", fontsize=15)
    plt.title(' Dev Loss', fontsize=15)
    plt.xlim(0, len(histories['Simple RNN'].history['loss']))
    plt.ylim(0, 0.02)
    plt.show()

# %% [markdown]
# ### Load Data

# %%
df=pd.read_csv('simple_well_portional_noise3_less.csv')

# %%
df.drop(columns='Date', inplace=True)
df2=pd.get_dummies(df['FlowPatternGasLiquid6'],prefix='FlowPattern')
df=pd.concat([df,df2],axis=1)
df.drop(columns='FlowPatternGasLiquid6', inplace=True)
df.head()
# Out:
#    Gas Flow_MMSCFD  Oil_bpd    Water_bpd  FWHP_psig  FroudeNumberGas6  \
# 0            2.006    434.3  4358.796496     5714.6          0.082530
# 1            1.983    425.3  3954.486042     5569.2          0.084297
# 2            1.971    423.3  3483.036837     5551.1          0.083442
# 3            1.977    416.3  3290.559813     5483.7          0.085425
# 4            1.961    410.4  2967.713050     5482.5          0.084584
#
#    FroudeNumberLiquid6  HoldupFractionLiquid6  ReynoldsNumber6  \
# 0             0.802494               0.838955      397428.0850
# 1             0.729662               0.820790      370815.2940
# 2             0.658774               0.808913      335519.3383
# 3             0.624417               0.796104      323486.3778
# 4             0.575357               0.786456      298405.2945
#
#    SuperficialVelocityGas6  SuperficialVelocityLiquid6  \
# 0                 0.514045                    2.533015
# 1                 0.537978                    2.317304
# 2                 0.525775                    2.085509
# 3                 0.543198                    1.981269
# 4                 0.530236                    1.819061
#
#    SurfaceTensionLiquidInSitu6  ViscosityLiquidInSitu6    FINAPRESS  \
# 0                     0.012455                0.273919  2245.856283
# 1                     0.013136                0.275289  2167.784425
# 2                     0.012690                0.276644  2214.713037
# 3                     0.012918                0.277573  2191.448539
# 4                     0.012455                0.278797  2240.738376
#
#      FINATEMP  FlowPattern_3  FlowPattern_4
# 0  212.007518              0              1
# 1  210.591058              0              1
# 2  208.827114              0              1
# 3  207.873805              0              1
# 4  206.288196              0              1

# %%
y_pre=df[['FINAPRESS','FINATEMP']]      # Pressure label
X_pre=df.drop(columns=['FINAPRESS','FINATEMP'], axis=1) # Pressure data

# %%
y_pre.head()
# Out:
#      FINAPRESS    FINATEMP
# 0  2245.856283  212.007518
# 1  2167.784425  210.591058
# 2  2214.713037  208.827114
# 3  2191.448539  207.873805
# 4  2240.738376  206.288196

# %% [markdown]
# ### Pre-processing

# %%
# Split train-dev and test sets
test_fraction = 0.20
x_traindev_raw, x_test_raw, y_traindev_raw, y_test_raw = train_test_split(X_pre,
                                                  y_pre,
                                                  test_size=test_fraction,
                                                  shuffle=False)

# Split train and val sets
dev_fraction = 0.20 # of total dataset
x_train_raw, x_dev_raw, y_train_raw, y_dev_raw = train_test_split(x_traindev_raw,
                                                  y_traindev_raw,
                                                  test_size= dev_fraction/(1-test_fraction),
                                                  shuffle=False)

# Data Scaling
scaler_x = MinMaxScaler()
x_train_norm = scaler_x.fit_transform(x_train_raw.as_matrix())  #based on train data
x_dev_norm = scaler_x.transform(x_dev_raw.as_matrix())
x_test_norm = scaler_x.transform(x_test_raw.as_matrix())

scaler_y = MinMaxScaler()
y_train_norm = scaler_y.fit_transform(y_train_raw.as_matrix())
y_dev_norm = scaler_y.transform(y_dev_raw.as_matrix())
y_test_norm = scaler_y.transform(y_test_raw.as_matrix())

# Create time blocks
x_train, y_train = reshape_data(x_train_norm, y_train_norm, look_back=10)
x_dev, y_dev = reshape_data(x_dev_norm, y_dev_norm, look_back=10)
x_test, y_test = reshape_data(x_test_norm, y_test_norm, look_back=10)
# Out:
# # of data:  146
# # of data:  42
# # of data:  42
# C:\Users\xuesong.wang1\AppData\Local\Programs\Python\Python37\lib\site-packages\ipykernel_launcher.py:17: FutureWarning: Method .as_matrix will be removed in a future version. Use .values instead.
# C:\Users\xuesong.wang1\AppData\Local\Programs\Python\Python37\lib\site-packages\ipykernel_launcher.py:18: FutureWarning: Method .as_matrix will be removed in a future version. Use .values instead.
# C:\Users\xuesong.wang1\AppData\Local\Programs\Python\Python37\lib\site-packages\ipykernel_launcher.py:19: FutureWarning: Method .as_matrix will be removed in a future version. Use .values instead.
# C:\Users\xuesong.wang1\AppData\Local\Programs\Python\Python37\lib\site-packages\ipykernel_launcher.py:22: FutureWarning: Method .as_matrix will be removed in a future version. Use .values instead.
# C:\Users\xuesong.wang1\AppData\Local\Programs\Python\Python37\lib\site-packages\ipykernel_launcher.py:23: FutureWarning: Method .as_matrix will be removed in a future version. Use .values instead.
# C:\Users\xuesong.wang1\AppData\Local\Programs\Python\Python37\lib\site-packages\ipykernel_launcher.py:24: FutureWarning: Method .as_matrix will be removed in a future version. Use .values instead.

# %%
y_train.shape
# Out:
# (146, 2)

# %%
def run_model(x_train, y_train, x_dev, y_dev, epochs=500, batch_size=50, method='LSTM'):
    classifier = {'GRU' : GRU,
                  'LSTM' : LSTM,
                  'Simple RNN' : SimpleRNN}


    inputs = Input(shape=(x_train.shape[1], x_train.shape[2]))

    X = classifier[method](512, return_sequences=True)(inputs)    
    # equvilent to X=LSTM(512, return_sequences=True)(inputs)   
    X = classifier[method](1024, return_sequences=True)(X)
    
    X = TimeDistributed(Dense(256, activation='relu'))(X)
    # TimeDistrituted allows you to apply that Dense function across every output at same time
    # 2 outputs in current case
    # 2 results at the same time, hence 2 outputs, not 2 nodes. 
    X = Dropout(0.3)(X)
    
    out1 = Dense(1)(Flatten()(X)) # three well flow rates
    out2 = Dense(1)(Flatten()(X))
  
    
    model = Model(input=inputs, output=[out1, out2])
    
    #parallel_model = multi_gpu_model(model, gpus=8)

    model.compile(loss='mean_squared_error', optimizer=tf.keras.optimizers.RMSprop(clipvalue=1), metrics=['mae','accuracy'])
    history = model.fit(x_train, [y_train[:, 0], y_train[:, 1]], 
                        epochs=epochs, batch_size=batch_size,
                        validation_data=(x_dev, [y_dev[:, 0], y_dev[:, 1]]), 
                        verbose=1, shuffle=False)
    return model, history

# %%
model_LSTM, history_LSTM = run_model(x_train, y_train, x_dev, y_dev, epochs=50, batch_size=80, method='LSTM')
# Out:
# ss: 0.0876 - val_dense_3_loss: 0.0298 - val_dense_2_mae: 0.2918 - val_dense_2_accuracy: 0.0000e+00 - val_dense_3_mae: 0.1698 - val_dense_3_accuracy: 0.0000e+00
# Epoch 4/50
# 146/146 [==============================] - 2s 12ms/step - loss: 0.5016 - dense_2_loss: 0.2729 - dense_3_loss: 0.1871 - dense_2_mae: 0.4334 - dense_2_accuracy: 0.0068 - dense_3_mae: 0.3435 - dense_3_accuracy: 0.0068 - val_loss: 0.1358 - val_dense_2_loss: 0.0933 - val_dense_3_loss: 0.0424 - val_dense_2_mae: 0.3021 - val_dense_2_accuracy: 0.0000e+00 - val_dense_3_mae: 0.2038 - val_dense_3_accuracy: 0.0000e+00
# Epoch 5/50
# 146/146 [==============================] - 2s 13ms/step - loss: 0.2964 - dense_2_loss: 0.1673 - dense_3_loss: 0.1065 - dense_2_mae: 0.3532 - dense_2_accuracy: 0.0068 - dense_3_mae: 0.2697 - dense_3_accuracy: 0.0068 - val_loss: 0.0570 - val_dense_2_loss: 0.0331 - val_dense_3_loss: 0.0239 - val_dense_2_mae: 0.1788 - val_dense_2_accuracy: 0.0000e+00 - val_dense_3_mae: 0.1523 - val_dense_3_accuracy: 0.0000e+00
# Epoch 6/50
# 146/146 [==============================] - 2s 11ms/step - loss: 0.1053 - dense_2_loss: 0.0600 - dense_3_loss: 0.0387 - dense_2_mae: 0.2290 - dense_2_accuracy: 0.0137 - dense_3_mae: 0.1779 - dense_3_accuracy: 0.0068 - val_loss: 0.0162 - val_dense_2_loss: 0.0010 - val_dense_3_loss: 0.0151 - val_dense_2_mae: 0.0273 - val_dense_2_accuracy: 0.0000e+00 - val_dense_3_mae: 0.1204 - val_dense_3_accuracy: 0.0000e+00
# Epoch 7/50
# 146/146 [==============================] - 2s 11ms/step - loss: 0.0956 - dense_2_loss: 0.0486 - dense_3_loss: 0.0409 - dense_2_mae: 0.1859 - dense_2_accuracy: 0.0137 - dense_3_mae: 0.1597 - dense_3_accuracy: 0.0068 - val_loss: 0.0743 - val_dense_2_loss: 0.0499 - val_dense_3_loss: 0.0244 - val_dense_2_mae: 0.2213 - val_dense_2_accuracy: 0.0000e+00 - val_dense_3_mae: 0.1543 - val_dense_3_accuracy: 0.0000e+00
# Epoch 8/50
# 146/146 [==============================] - 2s 12ms/step - loss: 0.2279 - dense_2_loss: 0.1161 - dense_3_loss: 0.0948 - dense_2_mae: 0.2991 - dense_2_accuracy: 0.0068 - dense_3_mae: 0.2503 - dense_3_accuracy: 0.0068 - val_loss: 0.0089 - val_dense_2_loss: 3.0755e-04 - val_dense_3_loss: 0.0086 - val_dense_2_mae: 0.0151 - val_dense_2_accuracy: 0.0000e+00 - val_dense_3_mae: 0.0907 - val_dense_3_accuracy: 0.0000e+00
# Epoch 9/50
# 146/146 [==============================] - 2s 12ms/step - loss: 0.0661 - dense_2_loss: 0.0350 - dense_3_loss: 0.0265 - dense_2_mae: 0.1662 - dense_2_accuracy: 0.0137 - dense_3_mae: 0.1389 - dense_3_accuracy: 0.0068 - val_loss: 0.0095 - val_dense_2_loss: 0.0036 - val_dense_3_loss: 0.0059 - val_dense_2_mae: 0.0581 - val_dense_2_accuracy: 0.0000e+00 - val_dense_3_mae: 0.0732 - val_dense_3_accuracy: 0.0000e+00
# Epoch 10/50
# 146/146 [==============================] - 2s 13ms/step - loss: 0.0421 - dense_2_loss: 0.0302 - dense_3_loss: 0.0112 - dense_2_mae: 0.1487 - dense_2_accuracy: 0.0137 - dense_3_mae: 0.0874 - dense_3_accuracy: 0.0068 - val_loss: 0.0730 - val_dense_2_loss: 0.0559 - val_dense_3_loss: 0.0171 - val_dense_2_mae: 0.2345 - val_dense_2_accuracy: 0.0000e+00 - val_dense_3_mae: 0.1294 - val_dense_3_accuracy: 0.0000e+00
# Epoch 11/50
# 146/146 [==============================] - 2s 15ms/step - loss: 0.0929 - dense_2_loss: 0.0636 - dense_3_loss: 0.0264 - dense_2_mae: 0.2384 - dense_2_accuracy: 0.0137 - dense_3_mae: 0.1456 - dense_3_accuracy: 0.0068 - val_loss: 0.0132 - val_dense_2_loss: 0.0015 - val_dense_3_loss: 0.0117 - val_dense_2_mae: 0.0326 - val_dense_2_accuracy: 0.0000e+00 - val_dense_3_mae: 0.1052 - val_dense_3_accuracy: 0.0000e+00
# Epoch 12/50
# 146/146 [==============================] - 2s 13ms/step - loss: 0.0320 - dense_2_loss: 0.0210 - dense_3_loss: 0.0095 - dense_2_mae: 0.1223 - dense_2_accuracy: 0.0137 - dense_3_mae: 0.0828 - dense_3_accuracy: 0.0068 - val_loss: 0.0458 - val_dense_2_loss: 0.0319 - val_dense_3_loss: 0.0139 - val_dense_2_mae: 0.1759 - val_dense_2_accuracy: 0.0000e+00 - val_dense_3_mae: 0.1158 - val_dense_3_accuracy: 0.0000e+00
# Epoch 13/50
# 146/146 [==============================] - 2s 13ms/step - loss: 0.0209 - dense_2_loss: 0.0156 - dense_3_loss: 0.0045 - dense_2_mae: 0.1002 - dense_2_accuracy: 0.0137 - dense_3_mae: 0.0545 - dense_3_accuracy: 0.0068 - val_loss: 0.0454 - val_dense_2_loss: 0.0350 - val_dense_3_loss: 0.0104 - val_dense_2_mae: 0.1847 - val_dense_2_accuracy: 0.0000e+00 - val_dense_3_mae: 0.1006 - val_dense_3_accuracy: 0.0000e+00
# Epoch 14/50
# 146/146 [==============================] - 2s 16ms/step - loss: 0.0787 - dense_2_loss: 0.0546 - dense_3_loss: 0.0202 - dense_2_mae: 0.2162 - dense_2_accuracy: 0.0137 - dense_3_mae: 0.1246 - dense_3_accuracy: 0.0068 - val_loss: 0.0170 - val_dense_2_loss: 0.0063 - val_dense_3_loss: 0.0107 - val_dense_2_mae: 0.0745 - val_dense_2_accuracy: 0.0000e+00 - val_dense_3_mae: 0.1004 - val_dense_3_accuracy: 0.0000e+00
# Epoch 15/50
# 146/146 [==============================] - 2s 12ms/step - loss: 0.0475 - dense_2_loss: 0.0292 - dense_3_loss: 0.0166 - dense_2_mae: 0.1491 - dense_2_accuracy: 0.0137 - dense_3_mae: 0.1114 - dense_3_accuracy: 0.0068 - val_loss: 0.0626 - val_dense_2_loss: 0.0401 - val_dense_3_loss: 0.0225 - val_dense_2_mae: 0.1974 - val_dense_2_accuracy: 0.0000e+00 - val_dense_3_mae: 0.1483 - val_dense_3_accuracy: 0.0000e+00
# Epoch 16/50
# 146/146 [==============================] - 2s 13ms/step - loss: 0.1155 - dense_2_loss: 0.0578 - dense_3_loss: 0.0509 - dense_2_mae: 0.2196 - dense_2_accuracy: 0.0137 - dense_3_mae: 0.2000 - dense_3_accuracy: 0.0068 - val_loss: 0.0327 - val_dense_2_loss: 0.0131 - val_dense_3_loss: 0.0196 - val_dense_2_mae: 0.1094 - val_dense_2_accuracy: 0.0000e+00 - val_dense_3_mae: 0.1370 - val_dense_3_accuracy: 0.0000e+00
# Epoch 17/50
# 146/146 [==============================] - 2s 15ms/step - loss: 0.0276 - dense_2_loss: 0.0133 - dense_3_loss: 0.0137 - dense_2_mae: 0.1014 - dense_2_accuracy: 0.0137 - dense_3_mae: 0.0970 - dense_3_accuracy: 0.0068 - val_loss: 0.0565 - val_dense_2_loss: 0.0375 - val_dense_3_loss: 0.0190 - val_dense_2_mae: 0.1905 - val_dense_2_accuracy: 0.0000e+00 - val_dense_3_mae: 0.1352 - val_dense_3_accuracy: 0.0000e+00
# Epoch 18/50
# 146/146 [==============================] - 2s 11ms/step - loss: 0.0432 - dense_2_loss: 0.0131 - dense_3_loss: 0.0278 - dense_2_mae: 0.0955 - dense_2_accuracy: 0.0137 - dense_3_mae: 0.1386 - dense_3_accuracy: 0.0068 - val_loss: 0.0269 - val_dense_2_loss: 0.0132 - val_dense_3_loss: 0.0138 - val_dense_2_mae: 0.1102 - val_dense_2_accuracy: 0.0000e+00 - val_dense_3_mae: 0.1148 - val_dense_3_accuracy: 0.0000e+00
# Epoch 19/50
# 146/146 [==============================] - 2s 12ms/step - loss: 0.0521 - dense_2_loss: 0.0220 - dense_3_loss: 0.0279 - dense_2_mae: 0.1219 - dense_2_accuracy: 0.0137 - dense_3_mae: 0.1340 - dense_3_accuracy: 0.0068 - val_loss: 0.0749 - val_dense_2_loss: 0.0505 - val_dense_3_loss: 0.0244 - val_dense_2_mae: 0.2218 - val_dense_2_accuracy: 0.0000e+00 - val_dense_3_mae: 0.1547 - val_dense_3_accuracy: 0.0000e+00
# Epoch 20/50
# 146/146 [==============================] - 2s 11ms/step - loss: 0.1785 - dense_2_loss: 0.0960 - dense_3_loss: 0.0702 - dense_2_mae: 0.2843 - dense_2_accuracy: 0.0068 - dense_3_mae: 0.2236 - dense_3_accuracy: 0.0068 - val_loss: 0.0260 - val_dense_2_loss: 0.0081 - val_dense_3_loss: 0.0179 - val_dense_2_mae: 0.0843 - val_dense_2_accuracy: 0.0000e+00 - val_dense_3_mae: 0.1317 - val_dense_3_accuracy: 0.0000e+00
# Epoch 21/50
# 146/146 [==============================] - 2s 11ms/step - loss: 0.0232 - dense_2_loss: 0.0103 - dense_3_loss: 0.0114 - dense_2_mae: 0.0832 - dense_2_accuracy: 0.0137 - dense_3_mae: 0.0864 - dense_3_accuracy: 0.0068 - val_loss: 0.0633 - val_dense_2_loss: 0.0618 - val_dense_3_loss: 0.0014 - val_dense_2_mae: 0.2445 - val_dense_2_accuracy: 0.0000e+00 - val_dense_3_mae: 0.0360 - val_dense_3_accuracy: 0.0000e+00
# Epoch 22/50
# 146/146 [==============================] - 2s 11ms/step - loss: 0.0808 - dense_2_loss: 0.0424 - dense_3_loss: 0.0342 - dense_2_mae: 0.1810 - dense_2_accuracy: 0.0137 - dense_3_mae: 0.1606 - dense_3_accuracy: 0.0068 - val_loss: 0.0616 - val_dense_2_loss: 0.0470 - val_dense_3_loss: 0.0145 - val_dense_2_mae: 0.2128 - val_dense_2_accuracy: 0.0000e+00 - val_dense_3_mae: 0.1185 - val_dense_3_accuracy: 0.0000e+00
# Epoch 23/50
# 146/146 [==============================] - 2s 11ms/step - loss: 0.2216 - dense_2_loss: 0.1404 - dense_3_loss: 0.0623 - dense_2_mae: 0.2982 - dense_2_accuracy: 0.0068 - dense_3_mae: 0.1958 - dense_3_accuracy: 0.0068 - val_loss: 0.0331 - val_dense_2_loss: 0.0190 - val_dense_3_loss: 0.0141 - val_dense_2_mae: 0.1338 - val_dense_2_accuracy: 0.0000e+00 - val_dense_3_mae: 0.1168 - val_dense_3_accuracy: 0.0000e+00
# Epoch 24/50
# 146/146 [==============================] - 2s 11ms/step - loss: 0.0385 - dense_2_loss: 0.0224 - dense_3_loss: 0.0137 - dense_2_mae: 0.1349 - dense_2_accuracy: 0.0137 - dense_3_mae: 0.1019 - dense_3_accuracy: 0.0068 - val_loss: 0.0061 - val_dense_2_loss: 0.0018 - val_dense_3_loss: 0.0043 - val_dense_2_mae: 0.0356 - val_dense_2_accuracy: 0.0000e+00 - val_dense_3_mae: 0.0631 - val_dense_3_accuracy: 0.0000e+00
# Epoch 25/50
# 146/146 [==============================] - 2s 11ms/step - loss: 0.0847 - dense_2_loss: 0.0460 - dense_3_loss: 0.0324 - dense_2_mae: 0.1741 - dense_2_accuracy: 0.0137 - dense_3_mae: 0.1335 - dense_3_accuracy: 0.0068 - val_loss: 0.0565 - val_dense_2_loss: 0.0419 - val_dense_3_loss: 0.0145 - val_dense_2_mae: 0.2001 - val_dense_2_accuracy: 0.0000e+00 - val_dense_3_mae: 0.1182 - val_dense_3_accuracy: 0.0000e+00
# Epoch 26/50
# 146/146 [==============================] - 2s 12ms/step - loss: 0.1838 - dense_2_loss: 0.0962 - dense_3_loss: 0.0813 - dense_2_mae: 0.2582 - dense_2_accuracy: 0.0068 - dense_3_mae: 0.2324 - dense_3_accuracy: 0.0068 - val_loss: 0.0329 - val_dense_2_loss: 0.0206 - val_dense_3_loss: 0.0122 - val_dense_2_mae: 0.1384 - val_dense_2_accuracy: 0.0000e+00 - val_dense_3_mae: 0.1088 - val_dense_3_accuracy: 0.0000e+00
# Epoch 27/50
# 146/146 [==============================] - 2s 12ms/step - loss: 0.1375 - dense_2_loss: 0.0781 - dense_3_loss: 0.0488 - dense_2_mae: 0.2478 - dense_2_accuracy: 0.0137 - dense_3_mae: 0.1910 - dense_3_accuracy: 0.0068 - val_loss: 0.0118 - val_dense_2_loss: 2.4158e-04 - val_dense_3_loss: 0.0116 - val_dense_2_mae: 0.0133 - val_dense_2_accuracy: 0.0000e+00 - val_dense_3_mae: 0.1072 - val_dense_3_accuracy: 0.0000e+00
# Epoch 28/50
# 146/146 [==============================] - 2s 11ms/step - loss: 0.1094 - dense_2_loss: 0.0678 - dense_3_loss: 0.0343 - dense_2_mae: 0.2081 - dense_2_accuracy: 0.0137 - dense_3_mae: 0.1530 - dense_3_accuracy: 0.0068 - val_loss: 0.1715 - val_dense_2_loss: 0.0717 - val_dense_3_loss: 0.0998 - val_dense_2_mae: 0.2650 - val_dense_2_accuracy: 0.0000e+00 - val_dense_3_mae: 0.3133 - val_dense_3_accuracy: 0.0000e+00
# Epoch 29/50
# 146/146 [==============================] - 2s 11ms/step - loss: 0.2312 - dense_2_loss: 0.1388 - dense_3_loss: 0.0741 - dense_2_mae: 0.3092 - dense_2_accuracy: 0.0068 - dense_3_mae: 0.2277 - dense_3_accuracy: 0.0068 - val_loss: 0.0054 - val_dense_2_loss: 0.0020 - val_dense_3_loss: 0.0034 - val_dense_2_mae: 0.0388 - val_dense_2_accuracy: 0.0000e+00 - val_dense_3_mae: 0.0547 - val_dense_3_accuracy: 0.0000e+00
# Epoch 30/50
# 146/146 [==============================] - 2s 11ms/step - loss: 0.0552 - dense_2_loss: 0.0348 - dense_3_loss: 0.0168 - dense_2_mae: 0.1580 - dense_2_accuracy: 0.0137 - dense_3_mae: 0.1088 - dense_3_accuracy: 0.0068 - val_loss: 0.0325 - val_dense_2_loss: 0.0299 - val_dense_3_loss: 0.0026 - val_dense_2_mae: 0.1685 - val_dense_2_accuracy: 0.0000e+00 - val_dense_3_mae: 0.0478 - val_dense_3_accuracy: 0.0000e+00
# Epoch 31/50
# 146/146 [==============================] - 2s 12ms/step - loss: 0.0635 - dense_2_loss: 0.0338 - dense_3_loss: 0.0258 - dense_2_mae: 0.1325 - dense_2_accuracy: 0.0137 - dense_3_mae: 0.1221 - dense_3_accuracy: 0.0068 - val_loss: 0.1368 - val_dense_2_loss: 0.1111 - val_dense_3_loss: 0.0257 - val_dense_2_mae: 0.3295 - val_dense_2_accuracy: 0.0000e+00 - val_dense_3_mae: 0.1579 - val_dense_3_accuracy: 0.0000e+00
# Epoch 32/50
# 146/146 [==============================] - 2s 12ms/step - loss: 0.1770 - dense_2_loss: 0.1042 - dense_3_loss: 0.0664 - dense_2_mae: 0.3002 - dense_2_accuracy: 0.0068 - dense_3_mae: 0.2223 - dense_3_accuracy: 0.0068 - val_loss: 0.0406 - val_dense_2_loss: 0.0029 - val_dense_3_loss: 0.0376 - val_dense_2_mae: 0.0513 - val_dense_2_accuracy: 0.0000e+00 - val_dense_3_mae: 0.1909 - val_dense_3_accuracy: 0.0000e+00
# Epoch 33/50
# 146/146 [==============================] - 2s 12ms/step - loss: 0.0847 - dense_2_loss: 0.0502 - dense_3_loss: 0.0287 - dense_2_mae: 0.2114 - dense_2_accuracy: 0.0137 - dense_3_mae: 0.1432 - dense_3_accuracy: 0.0068 - val_loss: 0.4679 - val_dense_2_loss: 0.4310 - val_dense_3_loss: 0.0369 - val_dense_2_mae: 0.6509 - val_dense_2_accuracy: 0.0000e+00 - val_dense_3_mae: 0.1911 - val_dense_3_accuracy: 0.0000e+00
# Epoch 34/50
# 146/146 [==============================] - 2s 12ms/step - loss: 0.0459 - dense_2_loss: 0.0249 - dense_3_loss: 0.0189 - dense_2_mae: 0.1272 - dense_2_accuracy: 0.0137 - dense_3_mae: 0.1151 - dense_3_accuracy: 0.0068 - val_loss: 0.0843 - val_dense_2_loss: 0.0174 - val_dense_3_loss: 0.0669 - val_dense_2_mae: 0.1270 - val_dense_2_accuracy: 0.0000e+00 - val_dense_3_mae: 0.2560 - val_dense_3_accuracy: 0.0000e+00
# Epoch 35/50
# 146/146 [==============================] - 2s 11ms/step - loss: 0.1135 - dense_2_loss: 0.0625 - dense_3_loss: 0.0419 - dense_2_mae: 0.1853 - dense_2_accuracy: 0.0137 - dense_3_mae: 0.1661 - dense_3_accuracy: 0.0068 - val_loss: 0.0212 - val_dense_2_loss: 0.0189 - val_dense_3_loss: 0.0023 - val_dense_2_mae: 0.1324 - val_dense_2_accuracy: 0.0000e+00 - val_dense_3_mae: 0.0448 - val_dense_3_accuracy: 0.0000e+00
# Epoch 36/50
# 146/146 [==============================] - 2s 11ms/step - loss: 0.0089 - dense_2_loss: 0.0050 - dense_3_loss: 0.0039 - dense_2_mae: 0.0606 - dense_2_accuracy: 0.0137 - dense_3_mae: 0.0526 - dense_3_accuracy: 0.0068 - val_loss: 0.0468 - val_dense_2_loss: 0.0305 - val_dense_3_loss: 0.0163 - val_dense_2_mae: 0.1710 - val_dense_2_accuracy: 0.0000e+00 - val_dense_3_mae: 0.1254 - val_dense_3_accuracy: 0.0000e+00
# Epoch 37/50
# 146/146 [==============================] - 2s 12ms/step - loss: 0.0051 - dense_2_loss: 0.0032 - dense_3_loss: 0.0016 - dense_2_mae: 0.0454 - dense_2_accuracy: 0.0137 - dense_3_mae: 0.0319 - dense_3_accuracy: 0.0068 - val_loss: 0.0309 - val_dense_2_loss: 0.0210 - val_dense_3_loss: 0.0099 - val_dense_2_mae: 0.1412 - val_dense_2_accuracy: 0.0000e+00 - val_dense_3_mae: 0.0970 - val_dense_3_accuracy: 0.0000e+00
# Epoch 38/50
# 146/146 [==============================] - 2s 12ms/step - loss: 0.0039 - dense_2_loss: 0.0017 - dense_3_loss: 0.0020 - dense_2_mae: 0.0319 - dense_2_accuracy: 0.0137 - dense_3_mae: 0.0304 - dense_3_accuracy: 0.0068 - val_loss: 0.0230 - val_dense_2_loss: 0.0162 - val_dense_3_loss: 0.0068 - val_dense_2_mae: 0.1238 - val_dense_2_accuracy: 0.0000e+00 - val_dense_3_mae: 0.0801 - val_dense_3_accuracy: 0.0000e+00
# Epoch 39/50
# 146/146 [==============================] - 2s 12ms/step - loss: 0.0051 - dense_2_loss: 0.0023 - dense_3_loss: 0.0025 - dense_2_mae: 0.0369 - dense_2_accuracy: 0.0137 - dense_3_mae: 0.0385 - dense_3_accuracy: 0.0068 - val_loss: 0.0264 - val_dense_2_loss: 0.0177 - val_dense_3_loss: 0.0087 - val_dense_2_mae: 0.1301 - val_dense_2_accuracy: 0.0000e+00 - val_dense_3_mae: 0.0917 - val_dense_3_accuracy: 0.0000e+00
# Epoch 40/50
# 146/146 [==============================] - 2s 12ms/step - loss: 0.0097 - dense_2_loss: 0.0044 - dense_3_loss: 0.0049 - dense_2_mae: 0.0572 - dense_2_accuracy: 0.0137 - dense_3_mae: 0.0534 - dense_3_accuracy: 0.0068 - val_loss: 0.0081 - val_dense_2_loss: 0.0062 - val_dense_3_loss: 0.0019 - val_dense_2_mae: 0.0732 - val_dense_2_accuracy: 0.0000e+00 - val_dense_3_mae: 0.0393 - val_dense_3_accuracy: 0.0000e+00
# Epoch 41/50
# 146/146 [==============================] - 2s 11ms/step - loss: 0.0223 - dense_2_loss: 0.0125 - dense_3_loss: 0.0091 - dense_2_mae: 0.0940 - dense_2_accuracy: 0.0137 - dense_3_mae: 0.0780 - dense_3_accuracy: 0.0068 - val_loss: 0.0504 - val_dense_2_loss: 0.0356 - val_dense_3_loss: 0.0148 - val_dense_2_mae: 0.1845 - val_dense_2_accuracy: 0.0000e+00 - val_dense_3_mae: 0.1194 - val_dense_3_accuracy: 0.0000e+00
# Epoch 42/50
# 146/146 [==============================] - 2s 11ms/step - loss: 0.0632 - dense_2_loss: 0.0350 - dense_3_loss: 0.0252 - dense_2_mae: 0.1558 - dense_2_accuracy: 0.0137 - dense_3_mae: 0.1245 - dense_3_accuracy: 0.0068 - val_loss: 0.0181 - val_dense_2_loss: 0.0120 - val_dense_3_loss: 0.0061 - val_dense_2_mae: 0.1047 - val_dense_2_accuracy: 0.0000e+00 - val_dense_3_mae: 0.0742 - val_dense_3_accuracy: 0.0000e+00
# Epoch 43/50
# 146/146 [==============================] - 2s 12ms/step - loss: 0.0230 - dense_2_loss: 0.0160 - dense_3_loss: 0.0063 - dense_2_mae: 0.1112 - dense_2_accuracy: 0.0137 - dense_3_mae: 0.0700 - dense_3_accuracy: 0.0068 - val_loss: 0.0756 - val_dense_2_loss: 0.0609 - val_dense_3_loss: 0.0147 - val_dense_2_mae: 0.2424 - val_dense_2_accuracy: 0.0000e+00 - val_dense_3_mae: 0.1189 - val_dense_3_accuracy: 0.0000e+00
# Epoch 44/50
# 146/146 [==============================] - 2s 11ms/step - loss: 0.0062 - dense_2_loss: 0.0038 - dense_3_loss: 0.0022 - dense_2_mae: 0.0489 - dense_2_accuracy: 0.0137 - dense_3_mae: 0.0389 - dense_3_accuracy: 0.0068 - val_loss: 0.0389 - val_dense_2_loss: 0.0243 - val_dense_3_loss: 0.0146 - val_dense_2_mae: 0.1525 - val_dense_2_accuracy: 0.0000e+00 - val_dense_3_mae: 0.1185 - val_dense_3_accuracy: 0.0000e+00
# Epoch 45/50
# 146/146 [==============================] - 2s 12ms/step - loss: 0.0100 - dense_2_loss: 0.0079 - dense_3_loss: 0.0019 - dense_2_mae: 0.0748 - dense_2_accuracy: 0.0137 - dense_3_mae: 0.0351 - dense_3_accuracy: 0.0068 - val_loss: 0.0398 - val_dense_2_loss: 0.0324 - val_dense_3_loss: 0.0074 - val_dense_2_mae: 0.1767 - val_dense_2_accuracy: 0.0000e+00 - val_dense_3_mae: 0.0849 - val_dense_3_accuracy: 0.0000e+00
# Epoch 46/50
# 146/146 [==============================] - 2s 13ms/step - loss: 0.0357 - dense_2_loss: 0.0297 - dense_3_loss: 0.0053 - dense_2_mae: 0.1605 - dense_2_accuracy: 0.0137 - dense_3_mae: 0.0551 - dense_3_accuracy: 0.0068 - val_loss: 0.0053 - val_dense_2_loss: 0.0019 - val_dense_3_loss: 0.0034 - val_dense_2_mae: 0.0370 - val_dense_2_accuracy: 0.0000e+00 - val_dense_3_mae: 0.0582 - val_dense_3_accuracy: 0.0000e+00
# Epoch 47/50
# 146/146 [==============================] - 2s 11ms/step - loss: 0.0255 - dense_2_loss: 0.0183 - dense_3_loss: 0.0069 - dense_2_mae: 0.1203 - dense_2_accuracy: 0.0137 - dense_3_mae: 0.0731 - dense_3_accuracy: 0.0068 - val_loss: 0.1004 - val_dense_2_loss: 0.0638 - val_dense_3_loss: 0.0366 - val_dense_2_mae: 0.2476 - val_dense_2_accuracy: 0.0000e+00 - val_dense_3_mae: 0.1879 - val_dense_3_accuracy: 0.0000e+00
# Epoch 48/50
# 146/146 [==============================] - 2s 12ms/step - loss: 0.0220 - dense_2_loss: 0.0159 - dense_3_loss: 0.0047 - dense_2_mae: 0.0991 - dense_2_accuracy: 0.0137 - dense_3_mae: 0.0563 - dense_3_accuracy: 0.0068 - val_loss: 0.0105 - val_dense_2_loss: 0.0091 - val_dense_3_loss: 0.0013 - val_dense_2_mae: 0.0915 - val_dense_2_accuracy: 0.0000e+00 - val_dense_3_mae: 0.0324 - val_dense_3_accuracy: 0.0000e+00
# Epoch 49/50
# 146/146 [==============================] - 2s 12ms/step - loss: 0.0476 - dense_2_loss: 0.0331 - dense_3_loss: 0.0128 - dense_2_mae: 0.1517 - dense_2_accuracy: 0.0137 - dense_3_mae: 0.0900 - dense_3_accuracy: 0.0068 - val_loss: 0.0967 - val_dense_2_loss: 0.0568 - val_dense_3_loss: 0.0398 - val_dense_2_mae: 0.2356 - val_dense_2_accuracy: 0.0000e+00 - val_dense_3_mae: 0.1976 - val_dense_3_accuracy: 0.0000e+00
# Epoch 50/50
# 146/146 [==============================] - 2s 11ms/step - loss: 0.2040 - dense_2_loss: 0.1017 - dense_3_loss: 0.0870 - dense_2_mae: 0.2798 - dense_2_accuracy: 0.0068 - dense_3_mae: 0.2491 - dense_3_accuracy: 0.0068 - val_loss: 0.0111 - val_dense_2_loss: 0.0103 - val_dense_3_loss: 8.4734e-04 - val_dense_2_mae: 0.0968 - val_dense_2_accuracy: 0.0000e+00 - val_dense_3_mae: 0.0278 - val_dense_3_accuracy: 0.0000e+00

# %%
# Training
y_pred_train_pre = model_LSTM.predict(x_train)
y_pred_train_scaled = np.concatenate((y_pred_train_pre[0], y_pred_train_pre[1]), axis=1)
y_pred_train = scaler_y.inverse_transform(y_pred_train_scaled)
y_train_act = scaler_y.inverse_transform(y_train)

# Dev
y_pred_dev_pre = model_LSTM.predict(x_dev)
y_pred_dev_scaled = np.concatenate((y_pred_dev_pre[0], y_pred_dev_pre[1]), axis=1)
y_pred_dev = scaler_y.inverse_transform(y_pred_dev_scaled)
y_dev_act = scaler_y.inverse_transform(y_dev)

# Test
y_pred_test_pre = model_LSTM.predict(x_test)
y_pred_test_scaled = np.concatenate((y_pred_test_pre[0], y_pred_test_pre[1]), axis=1)
y_pred_test = scaler_y.inverse_transform(y_pred_test_scaled)
y_test_act = scaler_y.inverse_transform(y_test)

# Train-Dev-Test
y_act = np.concatenate([y_train_act, y_dev_act, y_test_act])
y_pred = np.concatenate([y_pred_train, y_pred_dev, y_pred_test])

# %%
def plot_train_history(history, title):
  loss = history.history['loss']
  val_loss = history.history['val_loss']

  epochs = range(len(loss))

  plt.figure()

  plt.plot(epochs, loss, 'b', label='Training loss')
  plt.plot(epochs, val_loss, 'r', label='Validation loss')
  plt.title(title)
  plt.legend()

  plt.show()

# %%
plot_train_history(history_LSTM,
                   'LSTM Training and validation loss')

# %%
from sklearn import metrics

def RNN_comp_plot(dnn, testy, pred, labelx, labely, ftitle):
    # Look at the results
    lw = 2
    
    fig= plt.figure(figsize=(12, 10))
   
    y_hat=pred
        
    MAE=format(metrics.mean_absolute_error(testy, y_hat),'.3f')
    MSE=format(metrics.mean_squared_error(testy, y_hat),'.2f')
    R2=format(metrics.r2_score(testy, y_hat),'.4f')        
        
    plt.plot(y_hat, color='blue', lw=lw,
                      label='{} (MAE: {},  R^2: {})'.format(dnn, MAE, R2))
    plt.plot(testy, color='red', linestyle=':', lw=3,
                      label='Test data')                    
    plt.legend(loc='upper center',bbox_to_anchor=(0.5, 1.1),fontsize=12)
    plt.xlabel(labelx, fontsize=12)
    plt.ylabel(labely, fontsize=12)
    fig.suptitle(ftitle, fontsize=16)
    plt.show()

# %%
RNN_comp_plot("RNN",
              y_test_act[:,0],
              y_pred_test[:,0],
             "Week",
             "Pressure",
             "Deep Learning")
