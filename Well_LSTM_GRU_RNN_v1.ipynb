# %%
from __future__ import division
import pandas as pd
import numpy as np

from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.preprocessing import MinMaxScaler

import matplotlib.pyplot as plt
import time, os, math, warnings
from matplotlib import pyplot

import tensorflow as tf
from keras.models import Sequential, Model
from keras.layers import Input, Dense, Dropout, Activation, Flatten, TimeDistributed, Reshape
from keras.layers.recurrent import LSTM, GRU, SimpleRNN
from keras.utils import plot_model
# Out:
# Using TensorFlow backend.

# %%
# Set up some global variables
USE_GPU = True

if USE_GPU:
    device = '/device:GPU:0'
else:
    device = '/cpu:0'

# Constant to control how often we print when training models
print_every = 100

print('Using device: ', device)
# Out:
# Using device:  /device:GPU:0

# %% [markdown]
# ### Pre-processing Functions

# %% [markdown]
# Reshape input data

# %%
# Every "looK_back" X points, only one Y, does not predict future. 
def reshape_data(X, Y, look_back=1):
    dataX, dataY = [], []
    for i in range(len(X) - look_back):
        a = X[i:(i + look_back), :]
        dataX.append(a)
        dataY.append(Y[i + look_back, :])
    print('# of data: ', len(dataY))
    return np.array(dataX), np.array(dataY)

# %% [markdown]
# ### Plotting Functions

# %%
# %matplotlib inline
plt.rcParams['figure.figsize'] = (10.0, 8.0) # set default size of plots
plt.rcParams['image.interpolation'] = 'nearest'
plt.rcParams['image.cmap'] = 'gray'

# for auto-reloading external modules
# see http://stackoverflow.com/questions/1907993/autoreload-of-modules-in-ipython
# %load_ext autoreload
# %autoreload 2



def plot_pressure(t, q_actual, q_pred, dev_fraction, test_fraction, well):
    """This function plots actual and predicted bottom hole pressure"""
    # Plotting pwf v time
    plt.figure()
    plt.plot(t, q_actual, 'k-', linewidth=3, label='Actual oil rate')

    # Training
    train_end = int((1 - dev_fraction - test_fraction) * q_pred.shape[0])
    plt.plot(t[0:train_end], q_pred[0:train_end],
                 'r-', markeredgecolor='red', label='Training Set', linewidth=3)
    
    # Dev
    dev_end = int((1 - test_fraction) * q_pred.shape[0])
    plt.plot(t[train_end:dev_end], q_pred[train_end:dev_end],
                 'y-', markeredgecolor='orange', label='Dev Set', linewidth=3)
    
    # Test
    plt.plot(t[dev_end:], q_pred[dev_end:],
                 'g-', markeredgecolor='green', label='Test Set', linewidth=3)    
    
    plt.xlabel("Time (hours)", fontsize=14)
    plt.ylabel("Bottom Hole Pressure (psi)", fontsize=14)
    plt.title("Bottom Hole Pressure Well "+str(well), y=1, fontsize=13)
    plt.legend(loc="best", prop=dict(size=14))
    plt.xlim(0, max(t))
    plt.ylim(0, max(max(q_actual), max(q_pred)) + 10)
    plt.grid(True)

def plot_pred_rate(t, q_actual, q_pred, dev_fraction, test_fraction, well):
    """This function plots actual and predicted bottom hole pressure"""
    # Plotting pwf v time
    plt.figure()
    plt.plot(t, q_actual, 'k-', linewidth=3, label='Actual oil rate')

    # Training
    train_end = int((1 - dev_fraction - test_fraction) * q_pred.shape[0])
    plt.plot(t[0:train_end], q_pred[0:train_end],
                 'r-', markeredgecolor='red', label='Training Set', linewidth=3)
    
    # Dev
    dev_end = int((1 - test_fraction) * q_pred.shape[0])
    plt.plot(t[train_end:dev_end], q_pred[train_end:dev_end],
                 'y-', markeredgecolor='orange', label='Dev Set', linewidth=3)
    
    # Test
    plt.plot(t[dev_end:], q_pred[dev_end:],
                 'g-', markeredgecolor='green', label='Test Set', linewidth=3)    
    
    plt.xlabel("Time (hours)", fontsize=14)
    plt.ylabel("Flow Rate (STB/d)", fontsize=14)
    plt.title("Flow Rate Well " +str(well), y=1, fontsize=13)
    plt.legend(loc="best", prop=dict(size=14))
    plt.xlim(0, max(t))
    plt.ylim(0, max(max(q_actual), max(q_pred)) + 10)
    plt.grid(True)

def plot_rates(t, q, wellname, color, label):
    """This function plots actual flow rates"""
    # Plotting Flow Rate v time
    plt.plot(t, q, color, linewidth=3, label=label)
    plt.xlabel("Time (hours)", fontsize=11)
    plt.ylabel("Flow Rate (STB/D)", fontsize=11)
    plt.title('Flow Rate Well ' + wellname, y=0.82, fontsize=9)
    plt.legend(loc=1, prop=dict(size=8))
    plt.xlim(0, max(t))
    plt.ylim(0, max(q) + 10)
    plt.grid(True)

def plot_pressure_rates(x, y, y_pred, labelname):
    """This function plots both pressure and actual flow rates"""
    plt.figure()
    if labelname=='Training Data':
        color='red'
    else:
        color='green'

    plt.subplot(411)
    plot_pressure(x['TIME'], y, y_pred, labelname, color)

    plt.subplot(412)
    plot_rates(x['TIME'], x['WWPR:P1'], wellname='A', color='blue', label='Water Rate')
    plot_rates(x['TIME'], x['WOPR:P1'], wellname='A', color='green', label='Oil Rate')
    plt.ylim(0, max(max(x['WWPR:P1'].values), max(x['WOPR:P1'].values)) + 10)

    plt.subplot(413)
    plot_rates(x['TIME'], x['WOPR:P2'],wellname='B',color='green', label='Oil Rate')
    plot_rates(x['TIME'], x['WWPR:P2'],wellname='B',color='blue', label='Water Rate')
    plt.ylim(0, max(max(x['WWPR:P2'].values), max(x['WOPR:P2'].values)) + 10)

    plt.subplot(414)
    plot_rates(x['TIME'], x['WOPR:P3'], wellname='C', color='green', label='Oil Rate')
    plot_rates(x['TIME'], x['WWPR:P3'], wellname='C', color='blue', label='Water Rate')
    plt.ylim(0, max(max(x['WWPR:P3'].values), max(x['WOPR:P3'].values)) + 10)

def plot_loss(history, title):
    plt.figure()
    plt.plot(history.history['loss'], label='Train Loss', linewidth=3)
    plt.plot(history.history['val_loss'], label='Dev Loss', linewidth=3)
    plt.legend()
    plt.grid()
    plt.xlabel("No of Epochs", fontsize=15)
    plt.ylabel("Loss", fontsize=15)
    plt.title('Loss - ' + title, fontsize=15)
    plt.xlim(0, len(history.history['loss']))
    plt.ylim(0, max(history.history['val_loss']))
    plt.show()

def plot_loss_comparison(histories):
    plt.figure()
    plt.plot(histories['Simple RNN'].history['val_loss'], linewidth=3, label='Simple RNN')
    plt.plot(histories['GRU'].history['val_loss'], linewidth=3, label='GRU')
    plt.plot(histories['LSTM'].history['val_loss'], linewidth=3, label='LSTM')
    plt.legend()
    plt.grid()
    plt.xlabel("No of Epochs", fontsize=15)
    plt.ylabel("Loss", fontsize=15)
    plt.title(' Dev Loss', fontsize=15)
    plt.xlim(0, len(histories['Simple RNN'].history['loss']))
    plt.ylim(0, 0.02)
    plt.show()

# %% [markdown]
# ### Load Data

# %%
df=pd.read_csv('simple_well_portional_noise3_less.csv')

# %%
df.drop(columns='Date', inplace=True)
df2=pd.get_dummies(df['FlowPatternGasLiquid6'],prefix='FlowPattern')
df=pd.concat([df,df2],axis=1)
df.drop(columns='FlowPatternGasLiquid6', inplace=True)
df.head()
# Out:
#    Gas Flow_MMSCFD  Oil_bpd    Water_bpd  FWHP_psig  FroudeNumberGas6  \
# 0            2.006    434.3  4358.796496     5714.6          0.082530
# 1            1.983    425.3  3954.486042     5569.2          0.084297
# 2            1.971    423.3  3483.036837     5551.1          0.083442
# 3            1.977    416.3  3290.559813     5483.7          0.085425
# 4            1.961    410.4  2967.713050     5482.5          0.084584
#
#    FroudeNumberLiquid6  HoldupFractionLiquid6  ReynoldsNumber6  \
# 0             0.802494               0.838955      397428.0850
# 1             0.729662               0.820790      370815.2940
# 2             0.658774               0.808913      335519.3383
# 3             0.624417               0.796104      323486.3778
# 4             0.575357               0.786456      298405.2945
#
#    SuperficialVelocityGas6  SuperficialVelocityLiquid6  \
# 0                 0.514045                    2.533015
# 1                 0.537978                    2.317304
# 2                 0.525775                    2.085509
# 3                 0.543198                    1.981269
# 4                 0.530236                    1.819061
#
#    SurfaceTensionLiquidInSitu6  ViscosityLiquidInSitu6    FINAPRESS  \
# 0                     0.012455                0.273919  2245.856283
# 1                     0.013136                0.275289  2167.784425
# 2                     0.012690                0.276644  2214.713037
# 3                     0.012918                0.277573  2191.448539
# 4                     0.012455                0.278797  2240.738376
#
#      FINATEMP  FlowPattern_3  FlowPattern_4
# 0  212.007518              0              1
# 1  210.591058              0              1
# 2  208.827114              0              1
# 3  207.873805              0              1
# 4  206.288196              0              1

# %%
y_pre=df[['FINAPRESS','FINATEMP']]      # Pressure label
X_pre=df.drop(columns=['FINAPRESS','FINATEMP'], axis=1) # Pressure data

# %%
y_pre.head()
# Out:
#      FINAPRESS    FINATEMP
# 0  2245.856283  212.007518
# 1  2167.784425  210.591058
# 2  2214.713037  208.827114
# 3  2191.448539  207.873805
# 4  2240.738376  206.288196

# %% [markdown]
# ### Pre-processing

# %%
# Split train-dev and test sets
test_fraction = 0.20
x_traindev_raw, x_test_raw, y_traindev_raw, y_test_raw = train_test_split(X_pre,
                                                  y_pre,
                                                  test_size=test_fraction,
                                                  shuffle=False)

# Split train and val sets
dev_fraction = 0.20 # of total dataset
x_train_raw, x_dev_raw, y_train_raw, y_dev_raw = train_test_split(x_traindev_raw,
                                                  y_traindev_raw,
                                                  test_size= dev_fraction/(1-test_fraction),
                                                  shuffle=False)

# Data Scaling
scaler_x = MinMaxScaler()
x_train_norm = scaler_x.fit_transform(x_train_raw.as_matrix())  #based on train data
x_dev_norm = scaler_x.transform(x_dev_raw.as_matrix())
x_test_norm = scaler_x.transform(x_test_raw.as_matrix())

scaler_y = MinMaxScaler()
y_train_norm = scaler_y.fit_transform(y_train_raw.as_matrix())
y_dev_norm = scaler_y.transform(y_dev_raw.as_matrix())
y_test_norm = scaler_y.transform(y_test_raw.as_matrix())

# Create time blocks
x_train, y_train = reshape_data(x_train_norm, y_train_norm, look_back=10)
x_dev, y_dev = reshape_data(x_dev_norm, y_dev_norm, look_back=10)
x_test, y_test = reshape_data(x_test_norm, y_test_norm, look_back=10)
# Out:
# # of data:  146
# # of data:  42
# # of data:  42
# C:\Users\xuesong.wang1\AppData\Local\Programs\Python\Python37\lib\site-packages\ipykernel_launcher.py:17: FutureWarning: Method .as_matrix will be removed in a future version. Use .values instead.
# C:\Users\xuesong.wang1\AppData\Local\Programs\Python\Python37\lib\site-packages\ipykernel_launcher.py:18: FutureWarning: Method .as_matrix will be removed in a future version. Use .values instead.
# C:\Users\xuesong.wang1\AppData\Local\Programs\Python\Python37\lib\site-packages\ipykernel_launcher.py:19: FutureWarning: Method .as_matrix will be removed in a future version. Use .values instead.
# C:\Users\xuesong.wang1\AppData\Local\Programs\Python\Python37\lib\site-packages\ipykernel_launcher.py:22: FutureWarning: Method .as_matrix will be removed in a future version. Use .values instead.
# C:\Users\xuesong.wang1\AppData\Local\Programs\Python\Python37\lib\site-packages\ipykernel_launcher.py:23: FutureWarning: Method .as_matrix will be removed in a future version. Use .values instead.
# C:\Users\xuesong.wang1\AppData\Local\Programs\Python\Python37\lib\site-packages\ipykernel_launcher.py:24: FutureWarning: Method .as_matrix will be removed in a future version. Use .values instead.

# %%
y_train.shape
# Out:
# (146, 2)

# %%
def run_model(x_train, y_train, x_dev, y_dev, epochs=500, batch_size=50, method='LSTM'):
    classifier = {'GRU' : GRU,
                  'LSTM' : LSTM,
                  'Simple RNN' : SimpleRNN}


    inputs = Input(shape=(x_train.shape[1], x_train.shape[2]))

    X = classifier[method](512, return_sequences=True)(inputs)    
    # equvilent to X=LSTM(512, return_sequences=True)(inputs)   
    X = classifier[method](1024, return_sequences=True)(X)
    
    X = TimeDistributed(Dense(256, activation='relu'))(X)
    # TimeDistrituted allows you to apply that Dense function across every output at same time
    # 2 outputs in current case
    # 2 results at the same time, hence 2 outputs, not 2 nodes. 
    X = Dropout(0.3)(X)
    
    out1 = Dense(1)(Flatten()(X)) # three well flow rates
    out2 = Dense(1)(Flatten()(X))
  
    
    model = Model(input=inputs, output=[out1, out2])
    
    #parallel_model = multi_gpu_model(model, gpus=8)

    model.compile(loss='mean_squared_error', optimizer=tf.keras.optimizers.RMSprop(clipvalue=1), metrics=['mae','accuracy'])
    history = model.fit(x_train, [y_train[:, 0], y_train[:, 1]], 
                        epochs=epochs, batch_size=batch_size,
                        validation_data=(x_dev, [y_dev[:, 0], y_dev[:, 1]]), 
                        verbose=1, shuffle=False)
    return model, history

# %%
model_LSTM, history_LSTM = run_model(x_train, y_train, x_dev, y_dev, epochs=50, batch_size=50, method='LSTM')
# Out:
# _15_accuracy: 0.0000e+00
# Epoch 5/50
# 146/146 [==============================] - 2s 15ms/step - loss: 0.1937 - dense_14_loss: 0.0936 - dense_15_loss: 0.0952 - dense_14_mae: 0.2390 - dense_14_accuracy: 0.0137 - dense_15_mae: 0.2494 - dense_15_accuracy: 0.0068 - val_loss: 0.0830 - val_dense_14_loss: 0.0582 - val_dense_15_loss: 0.0248 - val_dense_14_mae: 0.2373 - val_dense_14_accuracy: 0.0000e+00 - val_dense_15_mae: 0.1549 - val_dense_15_accuracy: 0.0000e+00
# Epoch 6/50
# 146/146 [==============================] - 2s 17ms/step - loss: 0.2584 - dense_14_loss: 0.1323 - dense_15_loss: 0.1200 - dense_14_mae: 0.3210 - dense_14_accuracy: 0.0068 - dense_15_mae: 0.2746 - dense_15_accuracy: 0.0068 - val_loss: 0.0512 - val_dense_14_loss: 0.0303 - val_dense_15_loss: 0.0209 - val_dense_14_mae: 0.1701 - val_dense_14_accuracy: 0.0000e+00 - val_dense_15_mae: 0.1426 - val_dense_15_accuracy: 0.0000e+00
# Epoch 7/50
# 146/146 [==============================] - 2s 17ms/step - loss: 0.0407 - dense_14_loss: 0.0170 - dense_15_loss: 0.0232 - dense_14_mae: 0.1193 - dense_14_accuracy: 0.0137 - dense_15_mae: 0.1212 - dense_15_accuracy: 0.0068 - val_loss: 0.0450 - val_dense_14_loss: 0.0199 - val_dense_15_loss: 0.0251 - val_dense_14_mae: 0.1353 - val_dense_14_accuracy: 0.0000e+00 - val_dense_15_mae: 0.1556 - val_dense_15_accuracy: 0.0000e+00
# Epoch 8/50
# 146/146 [==============================] - 2s 16ms/step - loss: 0.1239 - dense_14_loss: 0.0787 - dense_15_loss: 0.0421 - dense_14_mae: 0.2394 - dense_14_accuracy: 0.0137 - dense_15_mae: 0.1700 - dense_15_accuracy: 0.0068 - val_loss: 0.0387 - val_dense_14_loss: 0.0264 - val_dense_15_loss: 0.0124 - val_dense_14_mae: 0.1572 - val_dense_14_accuracy: 0.0000e+00 - val_dense_15_mae: 0.1085 - val_dense_15_accuracy: 0.0000e+00
# Epoch 9/50
# 146/146 [==============================] - 2s 16ms/step - loss: 0.1792 - dense_14_loss: 0.1165 - dense_15_loss: 0.0581 - dense_14_mae: 0.2372 - dense_14_accuracy: 0.0068 - dense_15_mae: 0.1620 - dense_15_accuracy: 0.0068 - val_loss: 0.0483 - val_dense_14_loss: 0.0339 - val_dense_15_loss: 0.0144 - val_dense_14_mae: 0.1771 - val_dense_14_accuracy: 0.0000e+00 - val_dense_15_mae: 0.1158 - val_dense_15_accuracy: 0.0000e+00
# Epoch 10/50
# 146/146 [==============================] - 2s 16ms/step - loss: 0.0372 - dense_14_loss: 0.0236 - dense_15_loss: 0.0129 - dense_14_mae: 0.1275 - dense_14_accuracy: 0.0137 - dense_15_mae: 0.0920 - dense_15_accuracy: 0.0068 - val_loss: 0.0699 - val_dense_14_loss: 0.0540 - val_dense_15_loss: 0.0159 - val_dense_14_mae: 0.2275 - val_dense_14_accuracy: 0.0000e+00 - val_dense_15_mae: 0.1231 - val_dense_15_accuracy: 0.0000e+00
# Epoch 11/50
# 146/146 [==============================] - 2s 16ms/step - loss: 0.0581 - dense_14_loss: 0.0338 - dense_15_loss: 0.0230 - dense_14_mae: 0.1544 - dense_14_accuracy: 0.0137 - dense_15_mae: 0.1326 - dense_15_accuracy: 0.0068 - val_loss: 0.0752 - val_dense_14_loss: 0.0557 - val_dense_15_loss: 0.0194 - val_dense_14_mae: 0.2294 - val_dense_14_accuracy: 0.0000e+00 - val_dense_15_mae: 0.1354 - val_dense_15_accuracy: 0.0000e+00
# Epoch 12/50
# 146/146 [==============================] - 2s 16ms/step - loss: 0.1187 - dense_14_loss: 0.0722 - dense_15_loss: 0.0438 - dense_14_mae: 0.2340 - dense_14_accuracy: 0.0137 - dense_15_mae: 0.1783 - dense_15_accuracy: 0.0068 - val_loss: 0.1557 - val_dense_14_loss: 0.0946 - val_dense_15_loss: 0.0611 - val_dense_14_mae: 0.3025 - val_dense_14_accuracy: 0.0000e+00 - val_dense_15_mae: 0.2443 - val_dense_15_accuracy: 0.0000e+00
# Epoch 13/50
# 146/146 [==============================] - 2s 15ms/step - loss: 0.0867 - dense_14_loss: 0.0605 - dense_15_loss: 0.0266 - dense_14_mae: 0.2325 - dense_14_accuracy: 0.0137 - dense_15_mae: 0.1541 - dense_15_accuracy: 0.0068 - val_loss: 0.0253 - val_dense_14_loss: 0.0159 - val_dense_15_loss: 0.0095 - val_dense_14_mae: 0.1205 - val_dense_14_accuracy: 0.0000e+00 - val_dense_15_mae: 0.0940 - val_dense_15_accuracy: 0.0000e+00
# Epoch 14/50
# 146/146 [==============================] - 2s 16ms/step - loss: 0.1923 - dense_14_loss: 0.1261 - dense_15_loss: 0.0613 - dense_14_mae: 0.2991 - dense_14_accuracy: 0.0068 - dense_15_mae: 0.2067 - dense_15_accuracy: 0.0068 - val_loss: 0.0651 - val_dense_14_loss: 0.0390 - val_dense_15_loss: 0.0261 - val_dense_14_mae: 0.1936 - val_dense_14_accuracy: 0.0000e+00 - val_dense_15_mae: 0.1585 - val_dense_15_accuracy: 0.0000e+00
# Epoch 15/50
# 146/146 [==============================] - 2s 16ms/step - loss: 0.2457 - dense_14_loss: 0.1591 - dense_15_loss: 0.0829 - dense_14_mae: 0.3445 - dense_14_accuracy: 0.0068 - dense_15_mae: 0.2419 - dense_15_accuracy: 0.0068 - val_loss: 0.1395 - val_dense_14_loss: 0.0707 - val_dense_15_loss: 0.0688 - val_dense_14_mae: 0.2603 - val_dense_14_accuracy: 0.0000e+00 - val_dense_15_mae: 0.2579 - val_dense_15_accuracy: 0.0000e+00
# Epoch 16/50
# 146/146 [==============================] - 2s 15ms/step - loss: 0.0726 - dense_14_loss: 0.0419 - dense_15_loss: 0.0291 - dense_14_mae: 0.1698 - dense_14_accuracy: 0.0137 - dense_15_mae: 0.1348 - dense_15_accuracy: 0.0068 - val_loss: 0.0341 - val_dense_14_loss: 0.0327 - val_dense_15_loss: 0.0014 - val_dense_14_mae: 0.1760 - val_dense_14_accuracy: 0.0000e+00 - val_dense_15_mae: 0.0352 - val_dense_15_accuracy: 0.0000e+00
# Epoch 17/50
# 146/146 [==============================] - 2s 16ms/step - loss: 0.2094 - dense_14_loss: 0.1404 - dense_15_loss: 0.0636 - dense_14_mae: 0.3025 - dense_14_accuracy: 0.0068 - dense_15_mae: 0.2112 - dense_15_accuracy: 0.0068 - val_loss: 0.0359 - val_dense_14_loss: 0.0246 - val_dense_15_loss: 0.0113 - val_dense_14_mae: 0.1528 - val_dense_14_accuracy: 0.0000e+00 - val_dense_15_mae: 0.1039 - val_dense_15_accuracy: 0.0000e+00
# Epoch 18/50
# 146/146 [==============================] - 2s 15ms/step - loss: 0.1807 - dense_14_loss: 0.1110 - dense_15_loss: 0.0651 - dense_14_mae: 0.2277 - dense_14_accuracy: 0.0068 - dense_15_mae: 0.1762 - dense_15_accuracy: 0.0068 - val_loss: 0.0254 - val_dense_14_loss: 0.0152 - val_dense_15_loss: 0.0102 - val_dense_14_mae: 0.1180 - val_dense_14_accuracy: 0.0000e+00 - val_dense_15_mae: 0.0980 - val_dense_15_accuracy: 0.0000e+00
# Epoch 19/50
# 146/146 [==============================] - 2s 16ms/step - loss: 0.0868 - dense_14_loss: 0.0474 - dense_15_loss: 0.0377 - dense_14_mae: 0.1886 - dense_14_accuracy: 0.0137 - dense_15_mae: 0.1588 - dense_15_accuracy: 0.0068 - val_loss: 0.1364 - val_dense_14_loss: 0.0992 - val_dense_15_loss: 0.0372 - val_dense_14_mae: 0.3111 - val_dense_14_accuracy: 0.0000e+00 - val_dense_15_mae: 0.1910 - val_dense_15_accuracy: 0.0000e+00
# Epoch 20/50
# 146/146 [==============================] - 2s 16ms/step - loss: 0.0776 - dense_14_loss: 0.0543 - dense_15_loss: 0.0236 - dense_14_mae: 0.2201 - dense_14_accuracy: 0.0137 - dense_15_mae: 0.1436 - dense_15_accuracy: 0.0068 - val_loss: 0.0609 - val_dense_14_loss: 0.0463 - val_dense_15_loss: 0.0145 - val_dense_14_mae: 0.2092 - val_dense_14_accuracy: 0.0000e+00 - val_dense_15_mae: 0.1164 - val_dense_15_accuracy: 0.0000e+00
# Epoch 21/50
# 146/146 [==============================] - 2s 15ms/step - loss: 0.1891 - dense_14_loss: 0.1126 - dense_15_loss: 0.0717 - dense_14_mae: 0.2780 - dense_14_accuracy: 0.0068 - dense_15_mae: 0.2232 - dense_15_accuracy: 0.0068 - val_loss: 0.0624 - val_dense_14_loss: 0.0392 - val_dense_15_loss: 0.0232 - val_dense_14_mae: 0.1933 - val_dense_14_accuracy: 0.0000e+00 - val_dense_15_mae: 0.1494 - val_dense_15_accuracy: 0.0000e+00
# Epoch 22/50
# 146/146 [==============================] - 2s 15ms/step - loss: 0.1583 - dense_14_loss: 0.0884 - dense_15_loss: 0.0658 - dense_14_mae: 0.2000 - dense_14_accuracy: 0.0068 - dense_15_mae: 0.1812 - dense_15_accuracy: 0.0068 - val_loss: 0.0386 - val_dense_14_loss: 0.0229 - val_dense_15_loss: 0.0157 - val_dense_14_mae: 0.1469 - val_dense_14_accuracy: 0.0000e+00 - val_dense_15_mae: 0.1221 - val_dense_15_accuracy: 0.0000e+00
# Epoch 23/50
# 146/146 [==============================] - 2s 16ms/step - loss: 0.0931 - dense_14_loss: 0.0557 - dense_15_loss: 0.0354 - dense_14_mae: 0.1870 - dense_14_accuracy: 0.0137 - dense_15_mae: 0.1471 - dense_15_accuracy: 0.0068 - val_loss: 0.1109 - val_dense_14_loss: 0.0827 - val_dense_15_loss: 0.0282 - val_dense_14_mae: 0.2826 - val_dense_14_accuracy: 0.0000e+00 - val_dense_15_mae: 0.1650 - val_dense_15_accuracy: 0.0000e+00
# Epoch 24/50
# 146/146 [==============================] - 2s 16ms/step - loss: 0.1224 - dense_14_loss: 0.0790 - dense_15_loss: 0.0408 - dense_14_mae: 0.2559 - dense_14_accuracy: 0.0068 - dense_15_mae: 0.1736 - dense_15_accuracy: 0.0068 - val_loss: 0.0253 - val_dense_14_loss: 0.0120 - val_dense_15_loss: 0.0133 - val_dense_14_mae: 0.1046 - val_dense_14_accuracy: 0.0000e+00 - val_dense_15_mae: 0.1121 - val_dense_15_accuracy: 0.0000e+00
# Epoch 25/50
# 146/146 [==============================] - 2s 15ms/step - loss: 0.0256 - dense_14_loss: 0.0182 - dense_15_loss: 0.0069 - dense_14_mae: 0.1130 - dense_14_accuracy: 0.0137 - dense_15_mae: 0.0699 - dense_15_accuracy: 0.0068 - val_loss: 0.0214 - val_dense_14_loss: 0.0152 - val_dense_15_loss: 0.0062 - val_dense_14_mae: 0.1203 - val_dense_14_accuracy: 0.0000e+00 - val_dense_15_mae: 0.0765 - val_dense_15_accuracy: 0.0000e+00
# Epoch 26/50
# 146/146 [==============================] - 2s 16ms/step - loss: 0.0068 - dense_14_loss: 0.0043 - dense_15_loss: 0.0023 - dense_14_mae: 0.0470 - dense_14_accuracy: 0.0137 - dense_15_mae: 0.0339 - dense_15_accuracy: 0.0068 - val_loss: 0.0208 - val_dense_14_loss: 0.0148 - val_dense_15_loss: 0.0060 - val_dense_14_mae: 0.1187 - val_dense_14_accuracy: 0.0000e+00 - val_dense_15_mae: 0.0748 - val_dense_15_accuracy: 0.0000e+00
# Epoch 27/50
# 146/146 [==============================] - 2s 16ms/step - loss: 0.0403 - dense_14_loss: 0.0303 - dense_15_loss: 0.0092 - dense_14_mae: 0.1564 - dense_14_accuracy: 0.0137 - dense_15_mae: 0.0826 - dense_15_accuracy: 0.0068 - val_loss: 0.0070 - val_dense_14_loss: 0.0040 - val_dense_15_loss: 0.0030 - val_dense_14_mae: 0.0588 - val_dense_14_accuracy: 0.0000e+00 - val_dense_15_mae: 0.0518 - val_dense_15_accuracy: 0.0000e+00
# Epoch 28/50
# 146/146 [==============================] - 3s 20ms/step - loss: 0.0585 - dense_14_loss: 0.0403 - dense_15_loss: 0.0169 - dense_14_mae: 0.1479 - dense_14_accuracy: 0.0137 - dense_15_mae: 0.0940 - dense_15_accuracy: 0.0068 - val_loss: 0.0659 - val_dense_14_loss: 0.0511 - val_dense_15_loss: 0.0148 - val_dense_14_mae: 0.2228 - val_dense_14_accuracy: 0.0000e+00 - val_dense_15_mae: 0.1193 - val_dense_15_accuracy: 0.0000e+00
# Epoch 29/50
# 146/146 [==============================] - 3s 21ms/step - loss: 0.0523 - dense_14_loss: 0.0308 - dense_15_loss: 0.0206 - dense_14_mae: 0.1597 - dense_14_accuracy: 0.0137 - dense_15_mae: 0.1295 - dense_15_accuracy: 0.0068 - val_loss: 0.0230 - val_dense_14_loss: 0.0194 - val_dense_15_loss: 0.0036 - val_dense_14_mae: 0.1357 - val_dense_14_accuracy: 0.0000e+00 - val_dense_15_mae: 0.0571 - val_dense_15_accuracy: 0.0000e+00
# Epoch 30/50
# 146/146 [==============================] - 3s 20ms/step - loss: 0.0607 - dense_14_loss: 0.0329 - dense_15_loss: 0.0264 - dense_14_mae: 0.1414 - dense_14_accuracy: 0.0137 - dense_15_mae: 0.1257 - dense_15_accuracy: 0.0068 - val_loss: 0.0752 - val_dense_14_loss: 0.0287 - val_dense_15_loss: 0.0465 - val_dense_14_mae: 0.1665 - val_dense_14_accuracy: 0.0000e+00 - val_dense_15_mae: 0.2127 - val_dense_15_accuracy: 0.0000e+00
# Epoch 31/50
# 146/146 [==============================] - 3s 21ms/step - loss: 0.0157 - dense_14_loss: 0.0095 - dense_15_loss: 0.0061 - dense_14_mae: 0.0858 - dense_14_accuracy: 0.0137 - dense_15_mae: 0.0695 - dense_15_accuracy: 0.0068 - val_loss: 0.0169 - val_dense_14_loss: 0.0152 - val_dense_15_loss: 0.0018 - val_dense_14_mae: 0.1200 - val_dense_14_accuracy: 0.0000e+00 - val_dense_15_mae: 0.0381 - val_dense_15_accuracy: 0.0000e+00
# Epoch 32/50
# 146/146 [==============================] - 3s 22ms/step - loss: 0.0044 - dense_14_loss: 0.0016 - dense_15_loss: 0.0028 - dense_14_mae: 0.0309 - dense_14_accuracy: 0.0137 - dense_15_mae: 0.0423 - dense_15_accuracy: 0.0068 - val_loss: 0.0379 - val_dense_14_loss: 0.0038 - val_dense_15_loss: 0.0341 - val_dense_14_mae: 0.0592 - val_dense_14_accuracy: 0.0000e+00 - val_dense_15_mae: 0.1819 - val_dense_15_accuracy: 0.0000e+00
# Epoch 33/50
# 146/146 [==============================] - 3s 21ms/step - loss: 0.0114 - dense_14_loss: 0.0021 - dense_15_loss: 0.0092 - dense_14_mae: 0.0364 - dense_14_accuracy: 0.0137 - dense_15_mae: 0.0869 - dense_15_accuracy: 0.0068 - val_loss: 0.0156 - val_dense_14_loss: 0.0114 - val_dense_15_loss: 0.0042 - val_dense_14_mae: 0.1035 - val_dense_14_accuracy: 0.0000e+00 - val_dense_15_mae: 0.0610 - val_dense_15_accuracy: 0.0000e+00
# Epoch 34/50
# 146/146 [==============================] - 2s 17ms/step - loss: 0.0315 - dense_14_loss: 0.0120 - dense_15_loss: 0.0192 - dense_14_mae: 0.0908 - dense_14_accuracy: 0.0137 - dense_15_mae: 0.1183 - dense_15_accuracy: 0.0068 - val_loss: 0.3246 - val_dense_14_loss: 0.1901 - val_dense_15_loss: 0.1345 - val_dense_14_mae: 0.4317 - val_dense_14_accuracy: 0.0000e+00 - val_dense_15_mae: 0.3631 - val_dense_15_accuracy: 0.0000e+00
# Epoch 35/50
# 146/146 [==============================] - 2s 17ms/step - loss: 0.0315 - dense_14_loss: 0.0216 - dense_15_loss: 0.0106 - dense_14_mae: 0.1165 - dense_14_accuracy: 0.0137 - dense_15_mae: 0.0775 - dense_15_accuracy: 0.0068 - val_loss: 0.0248 - val_dense_14_loss: 0.0194 - val_dense_15_loss: 0.0054 - val_dense_14_mae: 0.1352 - val_dense_14_accuracy: 0.0000e+00 - val_dense_15_mae: 0.0705 - val_dense_15_accuracy: 0.0000e+00
# Epoch 36/50
# 146/146 [==============================] - 2s 16ms/step - loss: 0.1571 - dense_14_loss: 0.1112 - dense_15_loss: 0.0430 - dense_14_mae: 0.3048 - dense_14_accuracy: 0.0068 - dense_15_mae: 0.1754 - dense_15_accuracy: 0.0068 - val_loss: 0.0183 - val_dense_14_loss: 0.0127 - val_dense_15_loss: 0.0057 - val_dense_14_mae: 0.1087 - val_dense_14_accuracy: 0.0000e+00 - val_dense_15_mae: 0.0733 - val_dense_15_accuracy: 0.0000e+00
# Epoch 37/50
# 146/146 [==============================] - 3s 17ms/step - loss: 0.1659 - dense_14_loss: 0.1066 - dense_15_loss: 0.0551 - dense_14_mae: 0.2523 - dense_14_accuracy: 0.0068 - dense_15_mae: 0.1641 - dense_15_accuracy: 0.0068 - val_loss: 0.0047 - val_dense_14_loss: 4.0399e-04 - val_dense_15_loss: 0.0043 - val_dense_14_mae: 0.0176 - val_dense_14_accuracy: 0.0000e+00 - val_dense_15_mae: 0.0629 - val_dense_15_accuracy: 0.0000e+00
# Epoch 38/50
# 146/146 [==============================] - 2s 17ms/step - loss: 0.0209 - dense_14_loss: 0.0173 - dense_15_loss: 0.0031 - dense_14_mae: 0.1029 - dense_14_accuracy: 0.0137 - dense_15_mae: 0.0420 - dense_15_accuracy: 0.0068 - val_loss: 0.0141 - val_dense_14_loss: 0.0071 - val_dense_15_loss: 0.0070 - val_dense_14_mae: 0.0823 - val_dense_14_accuracy: 0.0000e+00 - val_dense_15_mae: 0.0818 - val_dense_15_accuracy: 0.0000e+00
# Epoch 39/50
# 146/146 [==============================] - 2s 16ms/step - loss: 0.0168 - dense_14_loss: 0.0110 - dense_15_loss: 0.0054 - dense_14_mae: 0.0905 - dense_14_accuracy: 0.0137 - dense_15_mae: 0.0589 - dense_15_accuracy: 0.0068 - val_loss: 0.0416 - val_dense_14_loss: 0.0403 - val_dense_15_loss: 0.0013 - val_dense_14_mae: 0.1978 - val_dense_14_accuracy: 0.0000e+00 - val_dense_15_mae: 0.0346 - val_dense_15_accuracy: 0.0000e+00
# Epoch 40/50
# 146/146 [==============================] - 2s 17ms/step - loss: 0.0462 - dense_14_loss: 0.0134 - dense_15_loss: 0.0321 - dense_14_mae: 0.0980 - dense_14_accuracy: 0.0137 - dense_15_mae: 0.1553 - dense_15_accuracy: 0.0068 - val_loss: 0.1124 - val_dense_14_loss: 0.0291 - val_dense_15_loss: 0.0833 - val_dense_14_mae: 0.1670 - val_dense_14_accuracy: 0.0000e+00 - val_dense_15_mae: 0.2860 - val_dense_15_accuracy: 0.0000e+00
# Epoch 41/50
# 146/146 [==============================] - 2s 17ms/step - loss: 0.0413 - dense_14_loss: 0.0215 - dense_15_loss: 0.0194 - dense_14_mae: 0.1225 - dense_14_accuracy: 0.0137 - dense_15_mae: 0.1066 - dense_15_accuracy: 0.0068 - val_loss: 0.0231 - val_dense_14_loss: 0.0029 - val_dense_15_loss: 0.0202 - val_dense_14_mae: 0.0499 - val_dense_14_accuracy: 0.0000e+00 - val_dense_15_mae: 0.1392 - val_dense_15_accuracy: 0.0000e+00
# Epoch 42/50
# 146/146 [==============================] - 3s 20ms/step - loss: 0.1267 - dense_14_loss: 0.0809 - dense_15_loss: 0.0428 - dense_14_mae: 0.2470 - dense_14_accuracy: 0.0137 - dense_15_mae: 0.1791 - dense_15_accuracy: 0.0068 - val_loss: 0.0165 - val_dense_14_loss: 0.0132 - val_dense_15_loss: 0.0033 - val_dense_14_mae: 0.1119 - val_dense_14_accuracy: 0.0000e+00 - val_dense_15_mae: 0.0563 - val_dense_15_accuracy: 0.0000e+00
# Epoch 43/50
# 146/146 [==============================] - 3s 20ms/step - loss: 0.1296 - dense_14_loss: 0.0826 - dense_15_loss: 0.0440 - dense_14_mae: 0.2161 - dense_14_accuracy: 0.0068 - dense_15_mae: 0.1540 - dense_15_accuracy: 0.0068 - val_loss: 5.3204e-04 - val_dense_14_loss: 2.3926e-04 - val_dense_15_loss: 2.9278e-04 - val_dense_14_mae: 0.0114 - val_dense_14_accuracy: 0.0000e+00 - val_dense_15_mae: 0.0148 - val_dense_15_accuracy: 0.0000e+00
# Epoch 44/50
# 146/146 [==============================] - 3s 20ms/step - loss: 0.0097 - dense_14_loss: 0.0060 - dense_15_loss: 0.0036 - dense_14_mae: 0.0653 - dense_14_accuracy: 0.0137 - dense_15_mae: 0.0511 - dense_15_accuracy: 0.0068 - val_loss: 0.0601 - val_dense_14_loss: 0.0422 - val_dense_15_loss: 0.0180 - val_dense_14_mae: 0.2021 - val_dense_14_accuracy: 0.0000e+00 - val_dense_15_mae: 0.1313 - val_dense_15_accuracy: 0.0000e+00
# Epoch 45/50
# 146/146 [==============================] - 3s 19ms/step - loss: 0.0542 - dense_14_loss: 0.0330 - dense_15_loss: 0.0200 - dense_14_mae: 0.1582 - dense_14_accuracy: 0.0137 - dense_15_mae: 0.1197 - dense_15_accuracy: 0.0068 - val_loss: 0.0125 - val_dense_14_loss: 0.0051 - val_dense_15_loss: 0.0074 - val_dense_14_mae: 0.0684 - val_dense_14_accuracy: 0.0000e+00 - val_dense_15_mae: 0.0836 - val_dense_15_accuracy: 0.0000e+00
# Epoch 46/50
# 146/146 [==============================] - 2s 17ms/step - loss: 0.0939 - dense_14_loss: 0.0564 - dense_15_loss: 0.0351 - dense_14_mae: 0.1688 - dense_14_accuracy: 0.0068 - dense_15_mae: 0.1193 - dense_15_accuracy: 0.0068 - val_loss: 0.0208 - val_dense_14_loss: 0.0188 - val_dense_15_loss: 0.0021 - val_dense_14_mae: 0.1347 - val_dense_14_accuracy: 0.0000e+00 - val_dense_15_mae: 0.0440 - val_dense_15_accuracy: 0.0000e+00
# Epoch 47/50
# 146/146 [==============================] - 3s 18ms/step - loss: 0.0068 - dense_14_loss: 0.0033 - dense_15_loss: 0.0034 - dense_14_mae: 0.0485 - dense_14_accuracy: 0.0137 - dense_15_mae: 0.0477 - dense_15_accuracy: 0.0068 - val_loss: 0.0235 - val_dense_14_loss: 0.0165 - val_dense_15_loss: 0.0070 - val_dense_14_mae: 0.1264 - val_dense_14_accuracy: 0.0000e+00 - val_dense_15_mae: 0.0821 - val_dense_15_accuracy: 0.0000e+00
# Epoch 48/50
# 146/146 [==============================] - 3s 18ms/step - loss: 0.0044 - dense_14_loss: 0.0028 - dense_15_loss: 0.0016 - dense_14_mae: 0.0453 - dense_14_accuracy: 0.0137 - dense_15_mae: 0.0328 - dense_15_accuracy: 0.0068 - val_loss: 0.0057 - val_dense_14_loss: 0.0029 - val_dense_15_loss: 0.0028 - val_dense_14_mae: 0.0515 - val_dense_14_accuracy: 0.0000e+00 - val_dense_15_mae: 0.0499 - val_dense_15_accuracy: 0.0000e+00
# Epoch 49/50
# 146/146 [==============================] - 3s 17ms/step - loss: 0.0095 - dense_14_loss: 0.0057 - dense_15_loss: 0.0036 - dense_14_mae: 0.0645 - dense_14_accuracy: 0.0137 - dense_15_mae: 0.0517 - dense_15_accuracy: 0.0068 - val_loss: 0.0037 - val_dense_14_loss: 0.0017 - val_dense_15_loss: 0.0020 - val_dense_14_mae: 0.0386 - val_dense_14_accuracy: 0.0000e+00 - val_dense_15_mae: 0.0425 - val_dense_15_accuracy: 0.0000e+00
# Epoch 50/50
# 146/146 [==============================] - 2s 17ms/step - loss: 0.0146 - dense_14_loss: 0.0098 - dense_15_loss: 0.0049 - dense_14_mae: 0.0866 - dense_14_accuracy: 0.0137 - dense_15_mae: 0.0587 - dense_15_accuracy: 0.0068 - val_loss: 0.0942 - val_dense_14_loss: 0.0716 - val_dense_15_loss: 0.0227 - val_dense_14_mae: 0.2645 - val_dense_14_accuracy: 0.0000e+00 - val_dense_15_mae: 0.1484 - val_dense_15_accuracy: 0.0000e+00

# %%
# Training
y_pred_train_pre = model_LSTM.predict(x_train)
y_pred_train_scaled = np.concatenate((y_pred_train_pre[0], y_pred_train_pre[1]), axis=1)
y_pred_train = scaler_y.inverse_transform(y_pred_train_scaled)
y_train_act = scaler_y.inverse_transform(y_train)

# Dev
y_pred_dev_pre = model_LSTM.predict(x_dev)
y_pred_dev_scaled = np.concatenate((y_pred_dev_pre[0], y_pred_dev_pre[1]), axis=1)
y_pred_dev = scaler_y.inverse_transform(y_pred_dev_scaled)
y_dev_act = scaler_y.inverse_transform(y_dev)

# Test
y_pred_test_pre = model_LSTM.predict(x_test)
y_pred_test_scaled = np.concatenate((y_pred_test_pre[0], y_pred_test_pre[1]), axis=1)
y_pred_test = scaler_y.inverse_transform(y_pred_test_scaled)
y_test_act = scaler_y.inverse_transform(y_test)

# Train-Dev-Test
y_act = np.concatenate([y_train_act, y_dev_act, y_test_act])
y_pred = np.concatenate([y_pred_train, y_pred_dev, y_pred_test])

# %%
def plot_train_history(history, title):
  loss = history.history['loss']
  val_loss = history.history['val_loss']

  epochs = range(len(loss))

  plt.figure()

  plt.plot(epochs, loss, 'b', label='Training loss')
  plt.plot(epochs, val_loss, 'r', label='Validation loss')
  plt.title(title)
  plt.legend()

  plt.show()

# %%
plot_train_history(history_LSTM,
                   'LSTM Training and validation loss')

# %%
from sklearn import metrics

def RNN_comp_plot(dnn, testy, pred, labelx, labely, ftitle):
    # Look at the results
    lw = 2
    
    fig= plt.figure(figsize=(12, 10))
   
    y_hat=pred
        
    MAE=format(metrics.mean_absolute_error(testy, y_hat),'.3f')
    MSE=format(metrics.mean_squared_error(testy, y_hat),'.2f')
    R2=format(metrics.r2_score(testy, y_hat),'.4f')        
        
    plt.plot(y_hat, color='blue', lw=lw,
                      label='{} (MAE: {},  R^2: {})'.format(dnn, MAE, R2))
    plt.plot(testy, color='red', linestyle=':', lw=3,
                      label='Test data')                    
    plt.legend(loc='upper center',bbox_to_anchor=(0.5, 1.1),fontsize=12)
    plt.xlabel(labelx, fontsize=12)
    plt.ylabel(labely, fontsize=12)
    fig.suptitle(ftitle, fontsize=16)
    plt.show()

# %%
RNN_comp_plot("RNN",
              y_test_act[:,0],
              y_pred_test[:,0],
             "Week",
             "Pressure",
             "Deep Learning")
