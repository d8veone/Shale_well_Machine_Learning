# %% [markdown]
# # Recurrent Neural Network

# %% [markdown]
# Modified from Tensorflow time series example

# %%
from __future__ import absolute_import, division, print_function, unicode_literals
try:
  # %tensorflow_version only exists in Colab.
  # %tensorflow_version 2.x
except Exception:
  pass
import tensorflow as tf

import matplotlib as mpl
import matplotlib.pyplot as plt
import numpy as np
import os
import pandas as pd

mpl.rcParams['figure.figsize'] = (8, 6)
mpl.rcParams['axes.grid'] = False

# %% [markdown]
# ### Read csv raw data

# %%
df=pd.read_csv('simple_well_portional_noise3_less.csv')

# %% [markdown]
# Let's take a glance at the data.

# %%
df.head()
# Out:
#        Date  Gas Flow_MMSCFD  Oil_bpd    Water_bpd  FWHP_psig  \
# 0  1/1/2020            2.006    434.3  4358.796496     5714.6
# 1  1/2/2020            1.983    425.3  3954.486042     5569.2
# 2  1/3/2020            1.971    423.3  3483.036837     5551.1
# 3  1/4/2020            1.977    416.3  3290.559813     5483.7
# 4  1/5/2020            1.961    410.4  2967.713050     5482.5
#
#    FroudeNumberGas6  FroudeNumberLiquid6  HoldupFractionLiquid6  \
# 0          0.082530             0.802494               0.838955
# 1          0.084297             0.729662               0.820790
# 2          0.083442             0.658774               0.808913
# 3          0.085425             0.624417               0.796104
# 4          0.084584             0.575357               0.786456
#
#    ReynoldsNumber6  SuperficialVelocityGas6  SuperficialVelocityLiquid6  \
# 0      397428.0850                 0.514045                    2.533015
# 1      370815.2940                 0.537978                    2.317304
# 2      335519.3383                 0.525775                    2.085509
# 3      323486.3778                 0.543198                    1.981269
# 4      298405.2945                 0.530236                    1.819061
#
#    SurfaceTensionLiquidInSitu6  ViscosityLiquidInSitu6  FlowPatternGasLiquid6  \
# 0                     0.012455                0.273919                      4
# 1                     0.013136                0.275289                      4
# 2                     0.012690                0.276644                      4
# 3                     0.012918                0.277573                      4
# 4                     0.012455                0.278797                      4
#
#      FINAPRESS    FINATEMP
# 0  2245.856283  212.007518
# 1  2167.784425  210.591058
# 2  2214.713037  208.827114
# 3  2191.448539  207.873805
# 4  2240.738376  206.288196

# %%
df.drop(columns='Date', inplace=True)

# %%
df2=pd.get_dummies(df['FlowPatternGasLiquid6'],prefix='FlowPattern')

# %%
df=pd.concat([df,df2],axis=1)

# %%
df.drop(columns='FlowPatternGasLiquid6', inplace=True)

# %%
df.head()
# Out:
#    Gas Flow_MMSCFD  Oil_bpd    Water_bpd  FWHP_psig  FroudeNumberGas6  \
# 0            2.006    434.3  4358.796496     5714.6          0.082530
# 1            1.983    425.3  3954.486042     5569.2          0.084297
# 2            1.971    423.3  3483.036837     5551.1          0.083442
# 3            1.977    416.3  3290.559813     5483.7          0.085425
# 4            1.961    410.4  2967.713050     5482.5          0.084584
#
#    FroudeNumberLiquid6  HoldupFractionLiquid6  ReynoldsNumber6  \
# 0             0.802494               0.838955      397428.0850
# 1             0.729662               0.820790      370815.2940
# 2             0.658774               0.808913      335519.3383
# 3             0.624417               0.796104      323486.3778
# 4             0.575357               0.786456      298405.2945
#
#    SuperficialVelocityGas6  SuperficialVelocityLiquid6  \
# 0                 0.514045                    2.533015
# 1                 0.537978                    2.317304
# 2                 0.525775                    2.085509
# 3                 0.543198                    1.981269
# 4                 0.530236                    1.819061
#
#    SurfaceTensionLiquidInSitu6  ViscosityLiquidInSitu6    FINAPRESS  \
# 0                     0.012455                0.273919  2245.856283
# 1                     0.013136                0.275289  2167.784425
# 2                     0.012690                0.276644  2214.713037
# 3                     0.012918                0.277573  2191.448539
# 4                     0.012455                0.278797  2240.738376
#
#      FINATEMP  FlowPattern_3  FlowPattern_4
# 0  212.007518              0              1
# 1  210.591058              0              1
# 2  208.827114              0              1
# 3  207.873805              0              1
# 4  206.288196              0              1

# %%
y_pre=df['FINAPRESS']      # Pressure label
X_pre=df.drop(columns=['FINAPRESS','FINATEMP'], axis=1) # Pressure data

# %%
y_hol=df['HoldupFractionLiquid6']     # holdup label
X_hol=df.drop(columns=['HoldupFractionLiquid6','FINATEMP'], axis=1)    # hold up data

# %%
X=df.iloc[:, 0:16]
y=df.iloc[:, 12]

# %%
y.head()
# Out:
# 0    2245.856283
# 1    2167.784425
# 2    2214.713037
# 3    2191.448539
# 4    2240.738376
# Name: FINAPRESS, dtype: float64

# %% [markdown]
# ### Plot the raw data

# %%
def four_y_plot(paraa, labela, parab, labelb, parac, labelc, parad, labeld, labelx, title):
    def make_patch_spines_invisible(ax):
        ax.set_frame_on(True)
        ax.patch.set_visible(False)
        for sp in ax.spines.values():
            sp.set_visible(False)
    
    fig, host = plt.subplots(figsize=(10, 8))
    fig.subplots_adjust(right=1)
    
    par1 = host.twinx()
    par2 = host.twinx()
    par3 = host.twinx()

    # Offset the right spine of par2.  The ticks and label have already been
    # placed on the right by twinx above.
    par2.spines["right"].set_position(("axes", 1.1))
    par3.spines["right"].set_position(("axes", 1.2))
    # Having been created by twinx, par2 has its frame off, so the line of its
    # detached spine is invisible.  First, activate the frame but make the patch
    # and spines invisible.
    make_patch_spines_invisible(par2)
    make_patch_spines_invisible(par3)
    # Second, show the right spine.
    par2.spines["right"].set_visible(True)
    par3.spines["right"].set_visible(True)
    
    p1, = host.plot(paraa, "b-", label=labela)
    p2, = par1.plot(parab, "r-", label=labelb)
    p3, = par2.plot(parac, "g-", label=labelc)
    p4, = par3.plot(parad, "black", label=labeld)
    
    # host.set_xlim(0, 250)
    # host.set_ylim(0, 2.2)
    # par1.set_ylim(0, 500)
    # par2.set_ylim(1, 5000)
    # par3.set_ylim(1, 6000)
    
    host.set_xlabel(labelx, fontsize=14)
    host.set_ylabel(labela, fontsize=14)
    par1.set_ylabel(labelb, fontsize=14)
    par2.set_ylabel(labelc, fontsize=14)
    par3.set_ylabel(labeld, fontsize=14)
    
    host.yaxis.label.set_color(p1.get_color())
    par1.yaxis.label.set_color(p2.get_color())
    par2.yaxis.label.set_color(p3.get_color())
    par3.yaxis.label.set_color(p4.get_color())
    
    tkw = dict(size=4, width=1.5)
    host.tick_params(axis='y', colors=p1.get_color(), labelsize=12)
    par1.tick_params(axis='y', colors=p2.get_color(), labelsize=12)
    par2.tick_params(axis='y', colors=p3.get_color(), labelsize=12)
    par3.tick_params(axis='y', colors=p4.get_color(), labelsize=12)
    host.tick_params(axis='x', labelsize=14)
 
    lines = [p1, p2, p3, p4]
    
    host.legend(lines, [l.get_label() for l in lines], fontsize=14)
    plt.title(title, fontsize=16)
    
    plt.show()

# %%
four_y_plot(df['Gas Flow_MMSCFD'], "Gas",
            df['Oil_bpd'], "Oil", 
            df['Water_bpd'],"Water",
            df['FWHP_psig'], "Pressure",
            "Week",
            "Bottom Hole Conditions")

# %% [markdown]
# ### Reshape the input data

# %% [markdown]
# In both the following, the first 180 rows of the data will be the training dataset, and there remaining will be the validation dataset.

# %%
TRAIN_VAL = 170   #train and validation split
VAL_TEST=212      #validation and test split

# %% [markdown]
# Setting seed to ensure reproducibility.

# %%
tf.random.set_seed(13)

# %% [markdown]
# Now that the data has been created, let's take a look at a single example. The information given to the network is given in blue, and it must predict the value at the red cross.

# %%
def create_time_steps(length):
  return list(range(-length, 0))

# %%
def show_plot(plot_data, delta, title):
  labels = ['History', 'True Future', 'Model Prediction']
  marker = ['.-', 'rx', 'go']
  time_steps = create_time_steps(plot_data[0].shape[0])
  if delta:
    future = delta
  else:
    future = 0

  plt.title(title)
  for i, x in enumerate(plot_data):
    if i:
      plt.plot(future, plot_data[i], marker[i], markersize=10,
               label=labels[i])
    else:
      plt.plot(time_steps, plot_data[i].flatten(), marker[i], label=labels[i]) 
      #flattren() remove one layer of list'[]'
  plt.legend()
  plt.xlim([time_steps[0], (future+5)*2])
  plt.xlabel('Time-Step')
  return plt

# %% [markdown]
# ### Baseline
# Before proceeding to train a model, let's first set a simple baseline. Given an input point, the baseline method looks at all the history and predicts the next point to be *the average of the last 20 observations*.

# %%
def baseline(history):
  return np.mean(history)

# %% [markdown]
# ### Recurrent neural network
#
# A Recurrent Neural Network (RNN) is a type of neural network well-suited to time series data. RNNs process a time series step-by-step, maintaining an internal state summarizing the information they've seen so far. For more details, read the [RNN tutorial](https://www.tensorflow.org/tutorials/sequences/recurrent). In this tutorial, you will use a specialized RNN layer called Long Short Term Memory ([LSTM](https://www.tensorflow.org/versions/r2.0/api_docs/python/tf/keras/layers/LSTM))
#
# Let's now use `tf.data` to shuffle, batch, and cache the dataset.

# %% [markdown]
# ## Forecast a multivariate time series

# %%
features = X_pre
# features.index = df['Date Time']
features.head()
# Out:
#    Gas Flow_MMSCFD  Oil_bpd    Water_bpd  FWHP_psig  FroudeNumberGas6  \
# 0            2.006    434.3  4358.796496     5714.6          0.082530
# 1            1.983    425.3  3954.486042     5569.2          0.084297
# 2            1.971    423.3  3483.036837     5551.1          0.083442
# 3            1.977    416.3  3290.559813     5483.7          0.085425
# 4            1.961    410.4  2967.713050     5482.5          0.084584
#
#    FroudeNumberLiquid6  HoldupFractionLiquid6  ReynoldsNumber6  \
# 0             0.802494               0.838955      397428.0850
# 1             0.729662               0.820790      370815.2940
# 2             0.658774               0.808913      335519.3383
# 3             0.624417               0.796104      323486.3778
# 4             0.575357               0.786456      298405.2945
#
#    SuperficialVelocityGas6  SuperficialVelocityLiquid6  \
# 0                 0.514045                    2.533015
# 1                 0.537978                    2.317304
# 2                 0.525775                    2.085509
# 3                 0.543198                    1.981269
# 4                 0.530236                    1.819061
#
#    SurfaceTensionLiquidInSitu6  ViscosityLiquidInSitu6  FlowPattern_3  \
# 0                     0.012455                0.273919              0
# 1                     0.013136                0.275289              0
# 2                     0.012690                0.276644              0
# 3                     0.012918                0.277573              0
# 4                     0.012455                0.278797              0
#
#    FlowPattern_4
# 0              1
# 1              1
# 2              1
# 3              1
# 4              1

# %%
X_pre.dtypes
# Out:
# Gas Flow_MMSCFD                float64
# Oil_bpd                        float64
# Water_bpd                      float64
# FWHP_psig                      float64
# FroudeNumberGas6               float64
# FroudeNumberLiquid6            float64
# HoldupFractionLiquid6          float64
# ReynoldsNumber6                float64
# SuperficialVelocityGas6        float64
# SuperficialVelocityLiquid6     float64
# SurfaceTensionLiquidInSitu6    float64
# ViscosityLiquidInSitu6         float64
# FlowPattern_3                    uint8
# FlowPattern_4                    uint8
# dtype: object

# %% [markdown]
# Let's have a look at how each of these features vary across time.

# %% [markdown]
# As mentioned, the first step will be to standardize the dataset using the mean and standard deviation of the training data.

# %%
dataset = features.values
data_mean = dataset[:TRAIN_VAL].mean(axis=0)
data_std = dataset[:TRAIN_VAL].std(axis=0)

# %%
dataset = X.values
data_mean = dataset[:TRAIN_VAL].mean(axis=0)
data_std = dataset[:TRAIN_VAL].std(axis=0)

# %%
data_mean
# Out:
# array([1.38858824e+00, 1.53460000e+02, 4.46290481e+02, 3.18819824e+03,
#        8.48023418e-02, 1.09134821e-01, 4.28539031e-01, 9.19050675e+04,
#        6.83677888e-01, 3.51375883e-01, 1.47818523e-02, 4.54107701e-01,
#        1.40101597e+03, 1.16786539e+02, 7.17647059e-01, 2.82352941e-01])

# %%
dataset = (dataset-data_mean)/data_std

# %% [markdown]
# ### Single step model (Predict current sequence '0' only, 'Future target' is 0)
# In a single step setup, the model learns to predict a single point in the future based on some history provided.

# %%
def multivariate_data(dataset, target, start_index, end_index, history_size,
                      target_size, step, single_step=False):
  data = []
  labels = []

  start_index = start_index + history_size
  if end_index is None:
    end_index = len(dataset) - target_size

  for i in range(start_index, end_index):
    indices = range(i-history_size, i, step)
    data.append(dataset[indices])

    if single_step:
      labels.append(target[i+target_size])
    else:
      labels.append(target[i:i+target_size])

  return np.array(data), np.array(labels)

# %% [markdown]
# In this tutorial, the network is shown data from the last five (5) days, i.e. 720 observations that are sampled every hour. The sampling is done every one hour since a drastic change is not expected within 60 minutes. Thus, 120 observation represent history of the last five days.  For the single step prediction model, the label for a datapoint is the temperature 12 hours into the future. In order to create a label for this, the temperature after 72(12*6) observations is used.

# %%
past_history = 10
future_target = 0   # predict current. use 'past_history' points
STEP = 1

x_train_single, y_train_single = multivariate_data(dataset, dataset[:,12], 0,
                                                   TRAIN_VAL, past_history,
                                                   future_target, STEP,
                                                   single_step=True)
x_val_single, y_val_single = multivariate_data(dataset, dataset[:,12],
                                               TRAIN_VAL, VAL_TEST, past_history,
                                               future_target, STEP,
                                               single_step=True)

# %%
x_test_single, y_test_single = multivariate_data(dataset, dataset[:,12],
                                               VAL_TEST, None, past_history,
                                               future_target, STEP,
                                               single_step=True)

# %% [markdown]
# Let's look at a single data-point.

# %%
y_test_single
# Out:
# array([-1.97925987, -1.97264879, -1.9843045 , -1.99358361, -1.98765379,
#        -2.00750984, -2.00145182, -2.01083039, -2.01503125, -2.01360814,
#        -2.00994853, -2.02435858, -2.02970401, -2.03603521, -2.04892703,
#        -2.03737415, -2.05733846, -2.04561311, -2.04695423, -2.05215527,
#        -2.06750597, -2.07753587, -2.08285047, -2.07773496, -2.07548417,
#        -2.0792956 , -2.09706979, -2.09193222, -2.10494555, -2.10258927,
#        -2.1041621 , -2.10172499, -2.11361919, -2.10853612, -2.11592371,
#        -2.12884697, -2.12367825, -2.13321822])

# %%
x_train_single.shape
# Out:
# (160, 10, 16)

# %%
y_train_single.shape
# Out:
# (160,)

# %%
print ('Single window of past history : {}'.format(x_train_single[0].shape))
# Out:
# Single window of past history : (10, 16)

# %%
BATCH_SIZE = 8
BUFFER_SIZE = 40

# %%
train_data_single = tf.data.Dataset.from_tensor_slices((x_train_single, y_train_single))
train_data_single = train_data_single.cache().shuffle(BUFFER_SIZE).batch(BATCH_SIZE).repeat()

val_data_single = tf.data.Dataset.from_tensor_slices((x_val_single, y_val_single))
val_data_single = val_data_single.batch(BATCH_SIZE).repeat()

# %%
x_train_single.shape
# Out:
# (160, 10, 16)

# %%
single_step_model = tf.keras.models.Sequential()
single_step_model.add(tf.keras.layers.LSTM(128,
                                           input_shape=x_train_single.shape[-2:]))

single_step_model.add(tf.keras.layers.Dense(128,activation='relu'))
single_step_model.add(tf.keras.layers.Dense(64,activation='relu'))
single_step_model.add(tf.keras.layers.Dropout(0.01))
single_step_model.add(tf.keras.layers.Dense(1,activation='linear'))

single_step_model.compile(optimizer=tf.keras.optimizers.Adam(0.001), loss='mae')

# %% [markdown]
# Let's check out a sample prediction.

# %%
for x, y in val_data_single.take(1):
  print(single_step_model.predict(x).shape)
# Out:
# (8, 1)

# %%
EVALUATION_INTERVAL = 200
EPOCHS = 100

# %%
from keras.callbacks import ModelCheckpoint,EarlyStopping
# checkpoint_name = 'Weights-{epoch:03d}--{val_loss:.5f}.hdf5' 
checkpoint_name = 'RNNbestmodel.h5' 
mcp = ModelCheckpoint(checkpoint_name, monitor='val_loss', verbose = 1, save_best_only = True, mode ='auto')

es = EarlyStopping(monitor='val_loss', mode='min', verbose=1, patience=50)

# %%
single_step_history = single_step_model.fit(train_data_single, epochs=EPOCHS,
                                            steps_per_epoch=EVALUATION_INTERVAL,
                                            validation_data=val_data_single,
                                            validation_steps=50, callbacks=[mcp])
# Out:
# ===========] - 2s 11ms/step - loss: 0.0503 - val_loss: 0.0648
# Epoch 11/100
# 194/200 [============================>.] - ETA: 0s - loss: 0.0511
# Epoch 00011: val_loss did not improve from 0.01810
# 200/200 [==============================] - 2s 9ms/step - loss: 0.0521 - val_loss: 0.0861
# Epoch 12/100
# 193/200 [===========================>..] - ETA: 0s - loss: 0.0615
# Epoch 00012: val_loss did not improve from 0.01810
# 200/200 [==============================] - 2s 9ms/step - loss: 0.0617 - val_loss: 0.0200
# Epoch 13/100
# 198/200 [============================>.] - ETA: 0s - loss: 0.0495
# Epoch 00013: val_loss did not improve from 0.01810
# 200/200 [==============================] - 2s 11ms/step - loss: 0.0497 - val_loss: 0.0204
# Epoch 14/100
# 199/200 [============================>.] - ETA: 0s - loss: 0.0528
# Epoch 00014: val_loss did not improve from 0.01810
# 200/200 [==============================] - 2s 9ms/step - loss: 0.0528 - val_loss: 0.0266
# Epoch 15/100
# 198/200 [============================>.] - ETA: 0s - loss: 0.0622
# Epoch 00015: val_loss did not improve from 0.01810
# 200/200 [==============================] - 2s 10ms/step - loss: 0.0624 - val_loss: 0.0988
# Epoch 16/100
# 194/200 [============================>.] - ETA: 0s - loss: 0.0507
# Epoch 00016: val_loss did not improve from 0.01810
# 200/200 [==============================] - 2s 11ms/step - loss: 0.0509 - val_loss: 0.0215
# Epoch 17/100
# 196/200 [============================>.] - ETA: 0s - loss: 0.0464
# Epoch 00017: val_loss did not improve from 0.01810
# 200/200 [==============================] - 2s 9ms/step - loss: 0.0461 - val_loss: 0.0621
# Epoch 18/100
# 198/200 [============================>.] - ETA: 0s - loss: 0.0509
# Epoch 00018: val_loss did not improve from 0.01810
# 200/200 [==============================] - 2s 9ms/step - loss: 0.0514 - val_loss: 0.0231
# Epoch 19/100
# 196/200 [============================>.] - ETA: 0s - loss: 0.0666
# Epoch 00019: val_loss did not improve from 0.01810
# 200/200 [==============================] - 2s 10ms/step - loss: 0.0669 - val_loss: 0.0651
# Epoch 20/100
# 199/200 [============================>.] - ETA: 0s - loss: 0.0475
# Epoch 00020: val_loss did not improve from 0.01810
# 200/200 [==============================] - 2s 11ms/step - loss: 0.0474 - val_loss: 0.0693
# Epoch 21/100
# 194/200 [============================>.] - ETA: 0s - loss: 0.0436
# Epoch 00021: val_loss did not improve from 0.01810
# 200/200 [==============================] - 2s 9ms/step - loss: 0.0432 - val_loss: 0.0497
# Epoch 22/100
# 197/200 [============================>.] - ETA: 0s - loss: 0.0428
# Epoch 00022: val_loss did not improve from 0.01810
# 200/200 [==============================] - 2s 10ms/step - loss: 0.0428 - val_loss: 0.0435
# Epoch 23/100
# 194/200 [============================>.] - ETA: 0s - loss: 0.0440
# Epoch 00023: val_loss did not improve from 0.01810
# 200/200 [==============================] - 2s 10ms/step - loss: 0.0437 - val_loss: 0.0182
# Epoch 24/100
# 196/200 [============================>.] - ETA: 0s - loss: 0.0444
# Epoch 00024: val_loss did not improve from 0.01810
# 200/200 [==============================] - 2s 10ms/step - loss: 0.0445 - val_loss: 0.0570
# Epoch 25/100
# 198/200 [============================>.] - ETA: 0s - loss: 0.0429
# Epoch 00025: val_loss improved from 0.01810 to 0.01765, saving model to RNNbestmodel.h5
# 200/200 [==============================] - 2s 10ms/step - loss: 0.0431 - val_loss: 0.0177
# Epoch 26/100
# 197/200 [============================>.] - ETA: 0s - loss: 0.0426
# Epoch 00026: val_loss did not improve from 0.01765
# 200/200 [==============================] - 2s 11ms/step - loss: 0.0426 - val_loss: 0.0892
# Epoch 27/100
# 197/200 [============================>.] - ETA: 0s - loss: 0.0459
# Epoch 00027: val_loss did not improve from 0.01765
# 200/200 [==============================] - 2s 9ms/step - loss: 0.0458 - val_loss: 0.0595
# Epoch 28/100
# 195/200 [============================>.] - ETA: 0s - loss: 0.0467
# Epoch 00028: val_loss improved from 0.01765 to 0.01629, saving model to RNNbestmodel.h5
# 200/200 [==============================] - 2s 10ms/step - loss: 0.0467 - val_loss: 0.0163
# Epoch 29/100
# 195/200 [============================>.] - ETA: 0s - loss: 0.0468
# Epoch 00029: val_loss did not improve from 0.01629
# 200/200 [==============================] - 2s 10ms/step - loss: 0.0466 - val_loss: 0.0276
# Epoch 30/100
# 198/200 [============================>.] - ETA: 0s - loss: 0.0410
# Epoch 00030: val_loss did not improve from 0.01629
# 200/200 [==============================] - 2s 11ms/step - loss: 0.0409 - val_loss: 0.0227
# Epoch 31/100
# 198/200 [============================>.] - ETA: 0s - loss: 0.0410
# Epoch 00031: val_loss did not improve from 0.01629
# 200/200 [==============================] - 2s 10ms/step - loss: 0.0410 - val_loss: 0.0540
# Epoch 32/100
# 197/200 [============================>.] - ETA: 0s - loss: 0.0383
# Epoch 00032: val_loss did not improve from 0.01629
# 200/200 [==============================] - 2s 10ms/step - loss: 0.0382 - val_loss: 0.0319
# Epoch 33/100
# 197/200 [============================>.] - ETA: 0s - loss: 0.0401
# Epoch 00033: val_loss improved from 0.01629 to 0.01580, saving model to RNNbestmodel.h5
# 200/200 [==============================] - 2s 11ms/step - loss: 0.0399 - val_loss: 0.0158
# Epoch 34/100
# 195/200 [============================>.] - ETA: 0s - loss: 0.0372
# Epoch 00034: val_loss improved from 0.01580 to 0.01497, saving model to RNNbestmodel.h5
# 200/200 [==============================] - 2s 10ms/step - loss: 0.0372 - val_loss: 0.0150
# Epoch 35/100
# 196/200 [============================>.] - ETA: 0s - loss: 0.0443
# Epoch 00035: val_loss did not improve from 0.01497
# 200/200 [==============================] - 2s 9ms/step - loss: 0.0442 - val_loss: 0.0871
# Epoch 36/100
# 198/200 [============================>.] - ETA: 0s - loss: 0.0389
# Epoch 00036: val_loss did not improve from 0.01497
# 200/200 [==============================] - 2s 11ms/step - loss: 0.0388 - val_loss: 0.0383
# Epoch 37/100
# 195/200 [============================>.] - ETA: 0s - loss: 0.0416
# Epoch 00037: val_loss did not improve from 0.01497
# 200/200 [==============================] - 2s 10ms/step - loss: 0.0415 - val_loss: 0.0706
# Epoch 38/100
# 199/200 [============================>.] - ETA: 0s - loss: 0.0346
# Epoch 00038: val_loss did not improve from 0.01497
# 200/200 [==============================] - 2s 9ms/step - loss: 0.0346 - val_loss: 0.0431
# Epoch 39/100
# 195/200 [============================>.] - ETA: 0s - loss: 0.0379
# Epoch 00039: val_loss did not improve from 0.01497
# 200/200 [==============================] - 2s 11ms/step - loss: 0.0379 - val_loss: 0.0479
# Epoch 40/100
# 195/200 [============================>.] - ETA: 0s - loss: 0.0362
# Epoch 00040: val_loss did not improve from 0.01497
# 200/200 [==============================] - 2s 10ms/step - loss: 0.0359 - val_loss: 0.0213
# Epoch 41/100
# 198/200 [============================>.] - ETA: 0s - loss: 0.0475
# Epoch 00041: val_loss did not improve from 0.01497
# 200/200 [==============================] - 2s 9ms/step - loss: 0.0473 - val_loss: 0.0404
# Epoch 42/100
# 198/200 [============================>.] - ETA: 0s - loss: 0.0364
# Epoch 00042: val_loss did not improve from 0.01497
# 200/200 [==============================] - 2s 10ms/step - loss: 0.0364 - val_loss: 0.0470
# Epoch 43/100
# 197/200 [============================>.] - ETA: 0s - loss: 0.0396
# Epoch 00043: val_loss did not improve from 0.01497
# 200/200 [==============================] - 2s 11ms/step - loss: 0.0397 - val_loss: 0.0275
# Epoch 44/100
# 197/200 [============================>.] - ETA: 0s - loss: 0.0377
# Epoch 00044: val_loss did not improve from 0.01497
# 200/200 [==============================] - 2s 10ms/step - loss: 0.0376 - val_loss: 0.0463
# Epoch 45/100
# 195/200 [============================>.] - ETA: 0s - loss: 0.0318
# Epoch 00045: val_loss did not improve from 0.01497
# 200/200 [==============================] - 2s 10ms/step - loss: 0.0318 - val_loss: 0.0579
# Epoch 46/100
# 198/200 [============================>.] - ETA: 0s - loss: 0.0381
# Epoch 00046: val_loss did not improve from 0.01497
# 200/200 [==============================] - 2s 11ms/step - loss: 0.0383 - val_loss: 0.0261
# Epoch 47/100
# 194/200 [============================>.] - ETA: 0s - loss: 0.0365
# Epoch 00047: val_loss did not improve from 0.01497
# 200/200 [==============================] - 2s 10ms/step - loss: 0.0362 - val_loss: 0.0276
# Epoch 48/100
# 199/200 [============================>.] - ETA: 0s - loss: 0.0298
# Epoch 00048: val_loss did not improve from 0.01497
# 200/200 [==============================] - 2s 10ms/step - loss: 0.0298 - val_loss: 0.0219
# Epoch 49/100
# 195/200 [============================>.] - ETA: 0s - loss: 0.0326
# Epoch 00049: val_loss did not improve from 0.01497
# 200/200 [==============================] - 2s 11ms/step - loss: 0.0329 - val_loss: 0.0357
# Epoch 50/100
# 196/200 [============================>.] - ETA: 0s - loss: 0.0327
# Epoch 00050: val_loss did not improve from 0.01497
# 200/200 [==============================] - 2s 10ms/step - loss: 0.0326 - val_loss: 0.0729
# Epoch 51/100
# 199/200 [============================>.] - ETA: 0s - loss: 0.0340
# Epoch 00051: val_loss did not improve from 0.01497
# 200/200 [==============================] - 2s 10ms/step - loss: 0.0339 - val_loss: 0.0218
# Epoch 52/100
# 195/200 [============================>.] - ETA: 0s - loss: 0.0284
# Epoch 00052: val_loss did not improve from 0.01497
# 200/200 [==============================] - 2s 11ms/step - loss: 0.0286 - val_loss: 0.0727
# Epoch 53/100
# 198/200 [============================>.] - ETA: 0s - loss: 0.0380
# Epoch 00053: val_loss did not improve from 0.01497
# 200/200 [==============================] - 2s 11ms/step - loss: 0.0379 - val_loss: 0.0184
# Epoch 54/100
# 199/200 [============================>.] - ETA: 0s - loss: 0.0337
# Epoch 00054: val_loss did not improve from 0.01497
# 200/200 [==============================] - 2s 10ms/step - loss: 0.0337 - val_loss: 0.0536
# Epoch 55/100
# 194/200 [============================>.] - ETA: 0s - loss: 0.0327
# Epoch 00055: val_loss did not improve from 0.01497
# 200/200 [==============================] - 2s 10ms/step - loss: 0.0332 - val_loss: 0.0220
# Epoch 56/100
# 194/200 [============================>.] - ETA: 0s - loss: 0.0354
# Epoch 00056: val_loss did not improve from 0.01497
# 200/200 [==============================] - 2s 11ms/step - loss: 0.0356 - val_loss: 0.0480
# Epoch 57/100
# 198/200 [============================>.] - ETA: 0s - loss: 0.0510
# Epoch 00057: val_loss did not improve from 0.01497
# 200/200 [==============================] - 2s 10ms/step - loss: 0.0507 - val_loss: 0.0211
# Epoch 58/100
# 197/200 [============================>.] - ETA: 0s - loss: 0.0308
# Epoch 00058: val_loss did not improve from 0.01497
# 200/200 [==============================] - 2s 10ms/step - loss: 0.0307 - val_loss: 0.0386
# Epoch 59/100
# 196/200 [============================>.] - ETA: 0s - loss: 0.0300
# Epoch 00059: val_loss did not improve from 0.01497
# 200/200 [==============================] - 2s 11ms/step - loss: 0.0300 - val_loss: 0.0470
# Epoch 60/100
# 195/200 [============================>.] - ETA: 0s - loss: 0.0332
# Epoch 00060: val_loss did not improve from 0.01497
# 200/200 [==============================] - 2s 10ms/step - loss: 0.0331 - val_loss: 0.0182
# Epoch 61/100
# 195/200 [============================>.] - ETA: 0s - loss: 0.0334
# Epoch 00061: val_loss did not improve from 0.01497
# 200/200 [==============================] - 2s 10ms/step - loss: 0.0336 - val_loss: 0.0811
# Epoch 62/100
# 197/200 [============================>.] - ETA: 0s - loss: 0.0329
# Epoch 00062: val_loss did not improve from 0.01497
# 200/200 [==============================] - 2s 11ms/step - loss: 0.0329 - val_loss: 0.0924
# Epoch 63/100
# 198/200 [============================>.] - ETA: 0s - loss: 0.0368
# Epoch 00063: val_loss did not improve from 0.01497
# 200/200 [==============================] - 2s 10ms/step - loss: 0.0368 - val_loss: 0.0419
# Epoch 64/100
# 196/200 [============================>.] - ETA: 0s - loss: 0.0298
# Epoch 00064: val_loss did not improve from 0.01497
# 200/200 [==============================] - 2s 10ms/step - loss: 0.0297 - val_loss: 0.0304
# Epoch 65/100
# 198/200 [============================>.] - ETA: 0s - loss: 0.0287
# Epoch 00065: val_loss did not improve from 0.01497
# 200/200 [==============================] - 2s 10ms/step - loss: 0.0285 - val_loss: 0.0455
# Epoch 66/100
# 194/200 [============================>.] - ETA: 0s - loss: 0.0312
# Epoch 00066: val_loss did not improve from 0.01497
# 200/200 [==============================] - 2s 11ms/step - loss: 0.0320 - val_loss: 0.0658
# Epoch 67/100
# 197/200 [============================>.] - ETA: 0s - loss: 0.0378
# Epoch 00067: val_loss did not improve from 0.01497
# 200/200 [==============================] - 2s 10ms/step - loss: 0.0378 - val_loss: 0.0268
# Epoch 68/100
# 199/200 [============================>.] - ETA: 0s - loss: 0.0344
# Epoch 00068: val_loss did not improve from 0.01497
# 200/200 [==============================] - 2s 10ms/step - loss: 0.0344 - val_loss: 0.0390
# Epoch 69/100
# 194/200 [============================>.] - ETA: 0s - loss: 0.0302
# Epoch 00069: val_loss did not improve from 0.01497
# 200/200 [==============================] - 2s 12ms/step - loss: 0.0308 - val_loss: 0.1076
# Epoch 70/100
# 196/200 [============================>.] - ETA: 0s - loss: 0.0252
# Epoch 00070: val_loss did not improve from 0.01497
# 200/200 [==============================] - 2s 11ms/step - loss: 0.0253 - val_loss: 0.0665
# Epoch 71/100
# 195/200 [============================>.] - ETA: 0s - loss: 0.0281
# Epoch 00071: val_loss did not improve from 0.01497
# 200/200 [==============================] - 2s 10ms/step - loss: 0.0281 - val_loss: 0.0497
# Epoch 72/100
# 197/200 [============================>.] - ETA: 0s - loss: 0.0245
# Epoch 00072: val_loss did not improve from 0.01497
# 200/200 [==============================] - 2s 11ms/step - loss: 0.0244 - val_loss: 0.0487
# Epoch 73/100
# 194/200 [============================>.] - ETA: 0s - loss: 0.0274
# Epoch 00073: val_loss did not improve from 0.01497
# 200/200 [==============================] - 2s 10ms/step - loss: 0.0275 - val_loss: 0.0791
# Epoch 74/100
# 198/200 [============================>.] - ETA: 0s - loss: 0.0326
# Epoch 00074: val_loss did not improve from 0.01497
# 200/200 [==============================] - 2s 10ms/step - loss: 0.0329 - val_loss: 0.1214
# Epoch 75/100
# 195/200 [============================>.] - ETA: 0s - loss: 0.0274
# Epoch 00075: val_loss did not improve from 0.01497
# 200/200 [==============================] - 2s 11ms/step - loss: 0.0275 - val_loss: 0.0827
# Epoch 76/100
# 194/200 [============================>.] - ETA: 0s - loss: 0.0304
# Epoch 00076: val_loss did not improve from 0.01497
# 200/200 [==============================] - 2s 11ms/step - loss: 0.0308 - val_loss: 0.0177
# Epoch 77/100
# 195/200 [============================>.] - ETA: 0s - loss: 0.0315
# Epoch 00077: val_loss did not improve from 0.01497
# 200/200 [==============================] - 2s 10ms/step - loss: 0.0316 - val_loss: 0.0729
# Epoch 78/100
# 199/200 [============================>.] - ETA: 0s - loss: 0.0296
# Epoch 00078: val_loss did not improve from 0.01497
# 200/200 [==============================] - 2s 10ms/step - loss: 0.0298 - val_loss: 0.0186
# Epoch 79/100
# 199/200 [============================>.] - ETA: 0s - loss: 0.0391
# Epoch 00079: val_loss did not improve from 0.01497
# 200/200 [==============================] - 2s 10ms/step - loss: 0.0391 - val_loss: 0.0483
# Epoch 80/100
# 197/200 [============================>.] - ETA: 0s - loss: 0.0324
# Epoch 00080: val_loss did not improve from 0.01497
# 200/200 [==============================] - 2s 10ms/step - loss: 0.0324 - val_loss: 0.0637
# Epoch 81/100
# 193/200 [===========================>..] - ETA: 0s - loss: 0.0279
# Epoch 00081: val_loss did not improve from 0.01497
# 200/200 [==============================] - 2s 9ms/step - loss: 0.0275 - val_loss: 0.0626
# Epoch 82/100
# 195/200 [============================>.] - ETA: 0s - loss: 0.0298
# Epoch 00082: val_loss did not improve from 0.01497
# 200/200 [==============================] - 2s 10ms/step - loss: 0.0299 - val_loss: 0.0561
# Epoch 83/100
# 199/200 [============================>.] - ETA: 0s - loss: 0.0300
# Epoch 00083: val_loss did not improve from 0.01497
# 200/200 [==============================] - 2s 11ms/step - loss: 0.0302 - val_loss: 0.0270
# Epoch 84/100
# 194/200 [============================>.] - ETA: 0s - loss: 0.0270
# Epoch 00084: val_loss did not improve from 0.01497
# 200/200 [==============================] - 2s 10ms/step - loss: 0.0273 - val_loss: 0.0406
# Epoch 85/100
# 198/200 [============================>.] - ETA: 0s - loss: 0.0354
# Epoch 00085: val_loss did not improve from 0.01497
# 200/200 [==============================] - 2s 10ms/step - loss: 0.0354 - val_loss: 0.0699
# Epoch 86/100
# 198/200 [============================>.] - ETA: 0s - loss: 0.0259
# Epoch 00086: val_loss did not improve from 0.01497
# 200/200 [==============================] - 2s 11ms/step - loss: 0.0260 - val_loss: 0.0589
# Epoch 87/100
# 199/200 [============================>.] - ETA: 0s - loss: 0.0277
# Epoch 00087: val_loss did not improve from 0.01497
# 200/200 [==============================] - 2s 10ms/step - loss: 0.0277 - val_loss: 0.0456
# Epoch 88/100
# 197/200 [============================>.] - ETA: 0s - loss: 0.0239
# Epoch 00088: val_loss did not improve from 0.01497
# 200/200 [==============================] - 2s 10ms/step - loss: 0.0239 - val_loss: 0.0308
# Epoch 89/100
# 197/200 [============================>.] - ETA: 0s - loss: 0.0269
# Epoch 00089: val_loss did not improve from 0.01497
# 200/200 [==============================] - 2s 10ms/step - loss: 0.0269 - val_loss: 0.0783
# Epoch 90/100
# 199/200 [============================>.] - ETA: 0s - loss: 0.0286
# Epoch 00090: val_loss did not improve from 0.01497
# 200/200 [==============================] - 2s 10ms/step - loss: 0.0287 - val_loss: 0.0462
# Epoch 91/100
# 194/200 [============================>.] - ETA: 0s - loss: 0.0249
# Epoch 00091: val_loss did not improve from 0.01497
# 200/200 [==============================] - 2s 10ms/step - loss: 0.0250 - val_loss: 0.0726
# Epoch 92/100
# 197/200 [============================>.] - ETA: 0s - loss: 0.0237
# Epoch 00092: val_loss did not improve from 0.01497
# 200/200 [==============================] - 2s 10ms/step - loss: 0.0238 - val_loss: 0.0800
# Epoch 93/100
# 198/200 [============================>.] - ETA: 0s - loss: 0.0251
# Epoch 00093: val_loss did not improve from 0.01497
# 200/200 [==============================] - 2s 11ms/step - loss: 0.0251 - val_loss: 0.0637
# Epoch 94/100
# 198/200 [============================>.] - ETA: 0s - loss: 0.0211
# Epoch 00094: val_loss did not improve from 0.01497
# 200/200 [==============================] - 2s 10ms/step - loss: 0.0212 - val_loss: 0.0357
# Epoch 95/100
# 198/200 [============================>.] - ETA: 0s - loss: 0.0318
# Epoch 00095: val_loss did not improve from 0.01497
# 200/200 [==============================] - 2s 10ms/step - loss: 0.0316 - val_loss: 0.0502
# Epoch 96/100
# 199/200 [============================>.] - ETA: 0s - loss: 0.0260
# Epoch 00096: val_loss did not improve from 0.01497
# 200/200 [==============================] - 2s 11ms/step - loss: 0.0260 - val_loss: 0.0335
# Epoch 97/100
# 198/200 [============================>.] - ETA: 0s - loss: 0.0305
# Epoch 00097: val_loss did not improve from 0.01497
# 200/200 [==============================] - 2s 10ms/step - loss: 0.0305 - val_loss: 0.0312
# Epoch 98/100
# 196/200 [============================>.] - ETA: 0s - loss: 0.0297
# Epoch 00098: val_loss did not improve from 0.01497
# 200/200 [==============================] - 2s 10ms/step - loss: 0.0298 - val_loss: 0.0355
# Epoch 99/100
# 194/200 [============================>.] - ETA: 0s - loss: 0.0279
# Epoch 00099: val_loss did not improve from 0.01497
# 200/200 [==============================] - 2s 10ms/step - loss: 0.0277 - val_loss: 0.0299
# Epoch 100/100
# 194/200 [============================>.] - ETA: 0s - loss: 0.0286
# Epoch 00100: val_loss did not improve from 0.01497
# 200/200 [==============================] - 2s 10ms/step - loss: 0.0284 - val_loss: 0.0730

# %%
def plot_train_history(history, title):
  loss = history.history['loss']
  val_loss = history.history['val_loss']

  epochs = range(len(loss))

  plt.figure()

  plt.plot(epochs, loss, 'b', label='Training loss')
  plt.plot(epochs, val_loss, 'r', label='Validation loss')
  plt.title(title)
  plt.legend()

  plt.show()

# %%
plot_train_history(single_step_history,
                   'Single Step Training and validation loss')

# %% [markdown]
# Load weights file

# %%
wights_file = 'RNNbestmodel.h5'
single_step_model.load_weights(wights_file) # load it
single_step_model.compile(optimizer=tf.keras.optimizers.Adam(0.001), loss='mae', metrics=['mean_absolute_error'])

# %% [markdown]
# #### Predict a single step

# %%
for x, y in val_data_single.take(3):
  plot = show_plot([x[1][:, 12].numpy(), y[1].numpy(),
                    single_step_model.predict(x)[1]], 0,
                   'Single Step Prediction')
  print(x.shape, y.shape)
  plot.show()
# Out:
# (8, 10, 16) (8,)
# (8, 10, 16) (8,)
# (8, 10, 16) (8,)

# %%
predictions=single_step_model.predict(x_test_single)

# %%
predictions=predictions*data_std[12]+data_mean[12]

# %%
y_test_single=y_test_single*data_std[12]+data_mean[12]

# %%
from sklearn import metrics

def RNN_comp_plot(dnn, testy, pred, labelx, labely, ftitle):
    # Look at the results
    lw = 2
    
    fig= plt.figure(figsize=(12, 10))
   
    y_hat=pred
        
    MAE=format(metrics.mean_absolute_error(testy, y_hat),'.3f')
    MSE=format(metrics.mean_squared_error(testy, y_hat),'.2f')
    R2=format(metrics.r2_score(testy, y_hat),'.4f')        
        
    plt.plot(y_hat, color='blue', lw=lw,
                      label='{} (MAE: {},  R^2: {})'.format(dnn, MAE, R2))
    plt.plot(testy, color='red', linestyle=':', lw=3,
                      label='Test data')                    
    plt.legend(loc='upper center',bbox_to_anchor=(0.5, 1.1),fontsize=12)
    plt.xlabel(labelx, fontsize=12)
    plt.ylabel(labely, fontsize=12)
    fig.suptitle(ftitle, fontsize=16)
    plt.show()

# %%
RNN_comp_plot("RNN",
             y_test_single,
             predictions,
             "Week",
             "Pressure",
             "Deep Learning")

# %% [markdown]
# ### Multi-Step model (Predict future sequence '0','1'....)
# In a multi-step prediction model, given a past history, the model needs to learn to predict a range of future values. Thus, unlike a single step model, where only a single future point is predicted, a multi-step model predict a sequence of the future.
#
# For the multi-step model, the training data again consists of recordings over the past five days sampled every hour. However, here, the model needs to learn to predict the temperature for the next 12 hours. Since an obversation is taken every 10 minutes, the output is 72 predictions. For this task, the dataset needs to be prepared accordingly, thus the first step is just to create it again, but with a different target window.

# %%
future_target = 3
x_train_multi, y_train_multi = multivariate_data(dataset, dataset[:, 12], 0,
                                                 TRAIN_VAL, past_history,
                                                 future_target, STEP)
x_val_multi, y_val_multi = multivariate_data(dataset, dataset[:, 12],
                                             TRAIN_VAL, VAL_TEST, past_history,
                                             future_target, STEP)

# %%
x_test_multi, y_test_multi = multivariate_data(dataset, dataset[:, 12],
                                             VAL_TEST, None, past_history,
                                             future_target, STEP)

# %% [markdown]
# Let's check out a sample data-point.

# %%
print ('Single window of past history : {}'.format(x_train_multi[0].shape))
print ('\n Target pressure to predict : {}'.format(y_train_multi[0].shape))
# Out:
# Single window of past history : (10, 16)
#
#  Target pressure to predict : (3,)

# %%
train_data_multi = tf.data.Dataset.from_tensor_slices((x_train_multi, y_train_multi))
train_data_multi = train_data_multi.cache().shuffle(BUFFER_SIZE).batch(BATCH_SIZE).repeat()

val_data_multi = tf.data.Dataset.from_tensor_slices((x_val_multi, y_val_multi))
val_data_multi = val_data_multi.batch(BATCH_SIZE).repeat()

# %% [markdown]
# Plotting a sample data-point.

# %%
def multi_step_plot(history, true_future, prediction):
  plt.figure(figsize=(12, 6))
  num_in = create_time_steps(len(history))
  num_out = len(true_future)

  plt.plot(num_in, np.array(history[:, 1]), label='History')
  plt.plot(np.arange(num_out)/STEP, np.array(true_future), 'bo',
           label='True Future')
  if prediction.any():
    plt.plot(np.arange(num_out)/STEP, np.array(prediction), 'ro',
             label='Predicted Future')
  plt.legend(loc='upper left')
  plt.show()

# %% [markdown]
# In this plot and subsequent similar plots

# %%
for x, y in train_data_multi.take(1):
  multi_step_plot(x[0], y[0], np.array([0]))

# %% [markdown]
# Since the task here is a bit more complicated than the previous task, the model now consists of two LSTM layers. Finally, since 72 predictions are made, the dense layer outputs 72 predictions.

# %%
multi_step_model = tf.keras.models.Sequential()
multi_step_model.add(tf.keras.layers.LSTM(128,
                                          return_sequences=True,
                                          input_shape=x_train_multi.shape[-2:]))
multi_step_model.add(tf.keras.layers.LSTM(256, activation='relu'))
multi_step_model.add(tf.keras.layers.Dense(64, activation='relu'))
multi_step_model.add(tf.keras.layers.Dropout(0.3))
multi_step_model.add(tf.keras.layers.Dense(3))   # Predict 3 steps, which is 'future target' 

multi_step_model.compile(optimizer=tf.keras.optimizers.RMSprop(clipvalue=0.5), loss='mae')

# %% [markdown]
# Let's see how the model predicts before it trains.

# %%
for x, y in val_data_multi.take(1):
  print (multi_step_model.predict(x).shape)
# Out:
# (8, 3)

# %%
multi_step_history = multi_step_model.fit(train_data_multi, epochs=19,
                                          steps_per_epoch=200,
                                          validation_data=val_data_multi,
                                          validation_steps=50)
# Out:
# Train for 200 steps, validate for 50 steps
# Epoch 1/19
# 200/200 [==============================] - 10s 51ms/step - loss: 0.2577 - val_loss: 0.3884
# Epoch 2/19
# 200/200 [==============================] - 6s 30ms/step - loss: 0.1783 - val_loss: 0.0227
# Epoch 3/19
# 200/200 [==============================] - 6s 32ms/step - loss: 0.1636 - val_loss: 0.0627
# Epoch 4/19
# 200/200 [==============================] - 6s 32ms/step - loss: 0.1487 - val_loss: 0.0682
# Epoch 5/19
# 200/200 [==============================] - 6s 30ms/step - loss: 0.1451 - val_loss: 0.3440
# Epoch 6/19
# 200/200 [==============================] - 6s 31ms/step - loss: 0.1348 - val_loss: 0.2057
# Epoch 7/19
# 200/200 [==============================] - 6s 30ms/step - loss: 0.1331 - val_loss: 0.0617
# Epoch 8/19
# 200/200 [==============================] - 6s 30ms/step - loss: 0.1283 - val_loss: 0.1789
# Epoch 9/19
# 200/200 [==============================] - 6s 30ms/step - loss: 0.1219 - val_loss: 0.1223
# Epoch 10/19
# 200/200 [==============================] - 6s 30ms/step - loss: 0.1201 - val_loss: 0.0757
# Epoch 11/19
# 200/200 [==============================] - 6s 29ms/step - loss: 0.1179 - val_loss: 0.0187
# Epoch 12/19
# 200/200 [==============================] - 6s 30ms/step - loss: 0.1171 - val_loss: 0.1334
# Epoch 13/19
# 200/200 [==============================] - 6s 30ms/step - loss: 0.1167 - val_loss: 0.2253
# Epoch 14/19
# 200/200 [==============================] - 6s 30ms/step - loss: 0.1153 - val_loss: 0.0471
# Epoch 15/19
# 200/200 [==============================] - 6s 30ms/step - loss: 0.1115 - val_loss: 0.3721
# Epoch 16/19
# 200/200 [==============================] - 6s 29ms/step - loss: 0.1147 - val_loss: 0.0302
# Epoch 17/19
# 200/200 [==============================] - 6s 29ms/step - loss: 0.1122 - val_loss: 0.1735
# Epoch 18/19
# 200/200 [==============================] - 6s 30ms/step - loss: 0.1094 - val_loss: 0.2380
# Epoch 19/19
# 200/200 [==============================] - 6s 31ms/step - loss: 0.1100 - val_loss: 0.0341

# %%
plot_train_history(multi_step_history, 'Multi-Step Training and validation loss')

# %% [markdown]
# #### Predict a multi-step future
# Let's now have a look at how well your network has learnt to predict the future.

# %%
for x, y in val_data_multi.take(3):
  multi_step_plot(x[0], y[0], multi_step_model.predict(x)[0])

# %%
predictions=multi_step_model.predict(x_test_multi)

# %%
predictions
# Out:
# array([[-1.8596005, -1.8687817, -1.8931618],
#        [-1.8685099, -1.877513 , -1.9020877],
#        [-1.8700253, -1.8789642, -1.9035715],
#        [-1.8765969, -1.8854077, -1.9101119],
#        [-1.881405 , -1.8901031, -1.9148904],
#        [-1.8816428, -1.8903124, -1.9151323],
#        [-1.8888013, -1.8973219, -1.9222901],
#        [-1.8906159, -1.8990935, -1.9240842],
#        [-1.8953371, -1.9037613, -1.9288163],
#        [-1.8986359, -1.9069892, -1.9320844],
#        [-1.8989258, -1.9072679, -1.9323696],
#        [-1.8975146, -1.9058409, -1.9309604],
#        [-1.9016724, -1.9099349, -1.9351245],
#        [-1.9049504, -1.9131569, -1.9383931],
#        [-1.9101703, -1.9182392, -1.9435712],
#        [-1.9163681, -1.9243867, -1.9498084],
#        [-1.9148767, -1.9228774, -1.94827  ],
#        [-1.9209988, -1.9289196, -1.95443  ],
#        [-1.9204324, -1.9283559, -1.9538485],
#        [-1.9217591, -1.9296592, -1.9551785],
#        [-1.9228144, -1.930674 , -1.9562217],
#        [-1.9288701, -1.9366404, -1.9622861],
#        [-1.935516 , -1.9431976, -1.9689308],
#        [-1.9402395, -1.9478153, -1.9736034],
#        [-1.9409916, -1.9485166, -1.9743379],
#        [-1.940891 , -1.9483684, -1.9742727],
#        [-1.9422551, -1.9497141, -1.975641 ],
#        [-1.9498091, -1.9571376, -1.9831834],
#        [-1.9501604, -1.9574692, -1.9835478],
#        [-1.9572276, -1.9644048, -1.9905866],
#        [-1.9586322, -1.9657786, -1.9919926],
#        [-1.9598277, -1.9669436, -1.9931698],
#        [-1.9599483, -1.967047 , -1.9933296],
#        [-1.9639561, -1.9709777, -1.9973284],
#        [-1.9647237, -1.9717164, -1.9980851]], dtype=float32)

# %%
predictions=predictions[:,0]*data_std[12]+data_mean[12]

# %%
predictions
# Out:
# array([302.03357, 296.76843, 295.8728 , 291.98914, 289.1477 , 289.00708,
#        284.7766 , 283.70422, 280.91406, 278.9646 , 278.79333, 279.62732,
#        277.17017, 275.2329 , 272.14795, 268.48523, 269.36658, 265.74866,
#        266.08337, 265.29932, 264.67566, 261.0968 , 257.1693 , 254.3778 ,
#        253.93335, 253.9928 , 253.18665, 248.72241, 248.51477, 244.33826,
#        243.50806, 242.80164, 242.73035, 240.36182, 239.9082 ],
#       dtype=float32)

# %%
y_test_multi1=y_test_multi[:,0]*data_std[12]+data_mean[12]

# %%
y_test_multi1
# Out:
# array([231.3176391, 235.224639 , 228.3363742, 222.8526288, 226.3570202,
#        214.6225366, 218.2026953, 212.6601657, 210.1775518, 211.0185807,
#        213.1813294, 204.6653078, 201.5062796, 197.7646834, 190.1459061,
#        196.9734012, 185.1749399, 192.1043598, 191.3117848, 188.23809  ,
#        179.1661643, 173.2387194, 170.0979091, 173.1210618, 174.4512314,
#        172.1987603, 161.6946088, 164.7307998, 157.0402135, 158.4327221,
#        157.5032157, 158.9434913, 151.9142864, 154.9182652, 150.5523674])

# %%
RNN_comp_plot("RNN",
             y_test_multi1,
             predictions,
             "Week",
             "Pressure",
             "Deep Learning")
