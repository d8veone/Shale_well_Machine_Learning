# %% [markdown]
# # Recurrent Neural Network

# %% [markdown]
# Modified from Tensorflow time series example

# %%
from __future__ import absolute_import, division, print_function, unicode_literals
try:
  # %tensorflow_version only exists in Colab.
  # %tensorflow_version 2.x
except Exception:
  pass
import tensorflow as tf

import matplotlib as mpl
import matplotlib.pyplot as plt
import numpy as np
import os
import pandas as pd

mpl.rcParams['figure.figsize'] = (8, 6)
mpl.rcParams['axes.grid'] = False

# %% [markdown]
# ### Read csv raw data

# %%
df=pd.read_csv('well_2520data_v1.csv')

# %% [markdown]
# Let's take a glance at the data.

# %%
df.shape
# Out:
# (2520, 16)

# %%
df.head()
# Out:
#        Date  Gas Flow_MMSCFD    Oil_bpd   Water_bpd    FWHP_psig  \
# 0  1/1/2020         1.997999  466.86395  4320.80866  5603.811198
# 1  1/2/2020         2.000979  462.75264  3177.54154  5574.183600
# 2  1/3/2020         1.998964  448.63094  2587.33434  5547.496275
# 3  1/4/2020         1.985018  444.05424  2207.89845  5532.051609
# 4  1/5/2020         1.986000  428.11200  1983.00000  5525.004375
#
#    FroudeNumberGas6  FroudeNumberLiquid6  HoldupFractionLiquid6  \
# 0          0.080394             0.799680               0.839809
# 1          0.079922             0.629477               0.811463
# 2          0.080651             0.537949               0.788673
# 3          0.079546             0.481507               0.775623
# 4          0.081171             0.443607               0.759974
#
#    ReynoldsNumber6  SuperficialVelocityGas6  SuperficialVelocityLiquid6  \
# 0      396646.0544                 0.513819                    2.540583
# 1      312421.2874                 0.491906                    1.980774
# 2      268611.3109                 0.484539                    1.681916
# 3      238882.5679                 0.467621                    1.496468
# 4      221882.4547                 0.469368                    1.372262
#
#    SurfaceTensionLiquidInSitu6  ViscosityLiquidInSitu6  FlowPatternGasLiquid6  \
# 0                     0.013141                0.273806                      4
# 1                     0.011881                0.276766                      4
# 2                     0.011080                0.279040                      4
# 3                     0.010385                0.281000                      4
# 4                     0.009937                0.282733                      4
#
#      FINAPRESS    FINATEMP
# 0  2150.835786  211.852508
# 1  2284.109281  207.602074
# 2  2371.590019  204.256007
# 3  2439.152773  201.442625
# 4  2494.398480  199.322796

# %%
df.drop(columns='Date', inplace=True)

# %%
df2=pd.get_dummies(df['FlowPatternGasLiquid6'],prefix='FlowPattern')

# %%
df=pd.concat([df,df2],axis=1)

# %%
df.drop(columns='FlowPatternGasLiquid6', inplace=True)

# %%
df.head()
# Out:
#    Gas Flow_MMSCFD    Oil_bpd   Water_bpd    FWHP_psig  FroudeNumberGas6  \
# 0         1.997999  466.86395  4320.80866  5603.811198          0.080394
# 1         2.000979  462.75264  3177.54154  5574.183600          0.079922
# 2         1.998964  448.63094  2587.33434  5547.496275          0.080651
# 3         1.985018  444.05424  2207.89845  5532.051609          0.079546
# 4         1.986000  428.11200  1983.00000  5525.004375          0.081171
#
#    FroudeNumberLiquid6  HoldupFractionLiquid6  ReynoldsNumber6  \
# 0             0.799680               0.839809      396646.0544
# 1             0.629477               0.811463      312421.2874
# 2             0.537949               0.788673      268611.3109
# 3             0.481507               0.775623      238882.5679
# 4             0.443607               0.759974      221882.4547
#
#    SuperficialVelocityGas6  SuperficialVelocityLiquid6  \
# 0                 0.513819                    2.540583
# 1                 0.491906                    1.980774
# 2                 0.484539                    1.681916
# 3                 0.467621                    1.496468
# 4                 0.469368                    1.372262
#
#    SurfaceTensionLiquidInSitu6  ViscosityLiquidInSitu6    FINAPRESS  \
# 0                     0.013141                0.273806  2150.835786
# 1                     0.011881                0.276766  2284.109281
# 2                     0.011080                0.279040  2371.590019
# 3                     0.010385                0.281000  2439.152773
# 4                     0.009937                0.282733  2494.398480
#
#      FINATEMP  FlowPattern_3  FlowPattern_4
# 0  211.852508              0              1
# 1  207.602074              0              1
# 2  204.256007              0              1
# 3  201.442625              0              1
# 4  199.322796              0              1

# %%
y_pre=df['FINAPRESS']      # Pressure label
X_pre=df.drop(columns=['FINAPRESS','FINATEMP'], axis=1) # Pressure data

# %%
y_hol=df['HoldupFractionLiquid6']     # holdup label
X_hol=df.drop(columns=['HoldupFractionLiquid6','FINATEMP'], axis=1)    # hold up data

# %%
X=df.iloc[:, 0:16]
y=df.iloc[:, 12]

# %%
y.head()
# Out:
# 0    2150.835786
# 1    2284.109281
# 2    2371.590019
# 3    2439.152773
# 4    2494.398480
# Name: FINAPRESS, dtype: float64

# %% [markdown]
# ### Plot the raw data

# %%
def four_y_plot(paraa, labela, parab, labelb, parac, labelc, parad, labeld, labelx, title):
    def make_patch_spines_invisible(ax):
        ax.set_frame_on(True)
        ax.patch.set_visible(False)
        for sp in ax.spines.values():
            sp.set_visible(False)
    
    fig, host = plt.subplots(figsize=(10, 8))
    fig.subplots_adjust(right=1)
    
    par1 = host.twinx()
    par2 = host.twinx()
    par3 = host.twinx()

    # Offset the right spine of par2.  The ticks and label have already been
    # placed on the right by twinx above.
    par2.spines["right"].set_position(("axes", 1.1))
    par3.spines["right"].set_position(("axes", 1.2))
    # Having been created by twinx, par2 has its frame off, so the line of its
    # detached spine is invisible.  First, activate the frame but make the patch
    # and spines invisible.
    make_patch_spines_invisible(par2)
    make_patch_spines_invisible(par3)
    # Second, show the right spine.
    par2.spines["right"].set_visible(True)
    par3.spines["right"].set_visible(True)
    
    p1, = host.plot(paraa, "b-", label=labela)
    p2, = par1.plot(parab, "r-", label=labelb)
    p3, = par2.plot(parac, "g-", label=labelc)
    p4, = par3.plot(parad, "black", label=labeld)
    
    # host.set_xlim(0, 250)
    # host.set_ylim(0, 2.2)
    # par1.set_ylim(0, 500)
    # par2.set_ylim(1, 5000)
    # par3.set_ylim(1, 6000)
    
    host.set_xlabel(labelx, fontsize=14)
    host.set_ylabel(labela, fontsize=14)
    par1.set_ylabel(labelb, fontsize=14)
    par2.set_ylabel(labelc, fontsize=14)
    par3.set_ylabel(labeld, fontsize=14)
    
    host.yaxis.label.set_color(p1.get_color())
    par1.yaxis.label.set_color(p2.get_color())
    par2.yaxis.label.set_color(p3.get_color())
    par3.yaxis.label.set_color(p4.get_color())
    
    tkw = dict(size=4, width=1.5)
    host.tick_params(axis='y', colors=p1.get_color(), labelsize=12)
    par1.tick_params(axis='y', colors=p2.get_color(), labelsize=12)
    par2.tick_params(axis='y', colors=p3.get_color(), labelsize=12)
    par3.tick_params(axis='y', colors=p4.get_color(), labelsize=12)
    host.tick_params(axis='x', labelsize=14)
 
    lines = [p1, p2, p3, p4]
    
    host.legend(lines, [l.get_label() for l in lines], fontsize=14)
    plt.title(title, fontsize=16)
    
    plt.show()

# %%
four_y_plot(df['Gas Flow_MMSCFD'], "Gas",
            df['Oil_bpd'], "Oil", 
            df['Water_bpd'],"Water",
            df['FWHP_psig'], "Pressure",
            "Day",
            "Bottom Hole Conditions")

# %% [markdown]
# ### Reshape the input data

# %% [markdown]
# In both the following, the first 180 rows of the data will be the training dataset, and there remaining will be the validation dataset.

# %%
TRAIN_VAL = 1700   #train and validation split
VAL_TEST=2016    #validation and test split

# %% [markdown]
# Setting seed to ensure reproducibility.

# %%
tf.random.set_seed(13)

# %% [markdown]
# Now that the data has been created, let's take a look at a single example. The information given to the network is given in blue, and it must predict the value at the red cross.

# %%
def create_time_steps(length):
  return list(range(-length, 0))

# %%
def show_plot(plot_data, delta, title):
  labels = ['History', 'True Future', 'Model Prediction']
  marker = ['.-', 'rx', 'go']
  time_steps = create_time_steps(plot_data[0].shape[0])
  if delta:
    future = delta
  else:
    future = 0

  plt.title(title)
  for i, x in enumerate(plot_data):
    if i:
      plt.plot(future, plot_data[i], marker[i], markersize=10,
               label=labels[i])
    else:
      plt.plot(time_steps, plot_data[i].flatten(), marker[i], label=labels[i]) 
      #flattren() remove one layer of list'[]'
  plt.legend()
  plt.xlim([time_steps[0], (future+5)*2])
  plt.xlabel('Time-Step')
  return plt

# %% [markdown]
# ### Baseline
# Before proceeding to train a model, let's first set a simple baseline. Given an input point, the baseline method looks at all the history and predicts the next point to be *the average of the last 20 observations*.

# %%
def baseline(history):
  return np.mean(history)

# %% [markdown]
# ### Recurrent neural network
#
# A Recurrent Neural Network (RNN) is a type of neural network well-suited to time series data. RNNs process a time series step-by-step, maintaining an internal state summarizing the information they've seen so far. For more details, read the [RNN tutorial](https://www.tensorflow.org/tutorials/sequences/recurrent). In this tutorial, you will use a specialized RNN layer called Long Short Term Memory ([LSTM](https://www.tensorflow.org/versions/r2.0/api_docs/python/tf/keras/layers/LSTM))
#
# Let's now use `tf.data` to shuffle, batch, and cache the dataset.

# %% [markdown]
# ## Forecast a multivariate time series

# %%
features = X_pre
# features.index = df['Date Time']
features.head()
# Out:
#    Gas Flow_MMSCFD    Oil_bpd   Water_bpd    FWHP_psig  FroudeNumberGas6  \
# 0         1.997999  466.86395  4320.80866  5603.811198          0.080394
# 1         2.000979  462.75264  3177.54154  5574.183600          0.079922
# 2         1.998964  448.63094  2587.33434  5547.496275          0.080651
# 3         1.985018  444.05424  2207.89845  5532.051609          0.079546
# 4         1.986000  428.11200  1983.00000  5525.004375          0.081171
#
#    FroudeNumberLiquid6  HoldupFractionLiquid6  ReynoldsNumber6  \
# 0             0.799680               0.839809      396646.0544
# 1             0.629477               0.811463      312421.2874
# 2             0.537949               0.788673      268611.3109
# 3             0.481507               0.775623      238882.5679
# 4             0.443607               0.759974      221882.4547
#
#    SuperficialVelocityGas6  SuperficialVelocityLiquid6  \
# 0                 0.513819                    2.540583
# 1                 0.491906                    1.980774
# 2                 0.484539                    1.681916
# 3                 0.467621                    1.496468
# 4                 0.469368                    1.372262
#
#    SurfaceTensionLiquidInSitu6  ViscosityLiquidInSitu6  FlowPattern_3  \
# 0                     0.013141                0.273806              0
# 1                     0.011881                0.276766              0
# 2                     0.011080                0.279040              0
# 3                     0.010385                0.281000              0
# 4                     0.009937                0.282733              0
#
#    FlowPattern_4
# 0              1
# 1              1
# 2              1
# 3              1
# 4              1

# %%
X_pre.dtypes
# Out:
# Gas Flow_MMSCFD                float64
# Oil_bpd                        float64
# Water_bpd                      float64
# FWHP_psig                      float64
# FroudeNumberGas6               float64
# FroudeNumberLiquid6            float64
# HoldupFractionLiquid6          float64
# ReynoldsNumber6                float64
# SuperficialVelocityGas6        float64
# SuperficialVelocityLiquid6     float64
# SurfaceTensionLiquidInSitu6    float64
# ViscosityLiquidInSitu6         float64
# FlowPattern_3                    uint8
# FlowPattern_4                    uint8
# dtype: object

# %% [markdown]
# Let's have a look at how each of these features vary across time.

# %% [markdown]
# As mentioned, the first step will be to standardize the dataset using the mean and standard deviation of the training data.

# %%
dataset = features.values
data_mean = dataset[:TRAIN_VAL].mean(axis=0)
data_std = dataset[:TRAIN_VAL].std(axis=0)

# %%
dataset = X.values
data_mean = dataset[:TRAIN_VAL].mean(axis=0)
data_std = dataset[:TRAIN_VAL].std(axis=0)

# %%
data_mean
# Out:
# array([1.13805686e+00, 8.65170627e+01, 1.74684879e+02, 2.72120634e+03,
#        7.64977705e-02, 4.98453862e-02, 3.88729965e-01, 6.11080269e+04,
#        7.06513237e-01, 1.62371221e-01, 1.99349465e-02, 5.42329717e-01,
#        1.10194955e+03, 9.37904725e+01, 8.74705882e-01, 1.25294118e-01])

# %%
dataset = (dataset-data_mean)/data_std

# %% [markdown]
# ### Single step model (Predict current sequence '0' only, 'Future target' is 0)
# In a single step setup, the model learns to predict a single point in the future based on some history provided.

# %%
def multivariate_data(dataset, target, start_index, end_index, history_size,
                      target_size, step, single_step=False):
  data = []
  labels = []

  start_index = start_index + history_size
  if end_index is None:
    end_index = len(dataset) - target_size

  for i in range(start_index, end_index):
    indices = range(i-history_size, i, step)
    data.append(dataset[indices])

    if single_step:
      labels.append(target[i+target_size])
    else:
      labels.append(target[i:i+target_size])

  return np.array(data), np.array(labels)

# %% [markdown]
# In this tutorial, the network is shown data from the last five (5) days, i.e. 720 observations that are sampled every hour. The sampling is done every one hour since a drastic change is not expected within 60 minutes. Thus, 120 observation represent history of the last five days.  For the single step prediction model, the label for a datapoint is the temperature 12 hours into the future. In order to create a label for this, the temperature after 72(12*6) observations is used.

# %%
past_history = 20
future_target = 0   # predict current. use 'past_history' points
STEP = 1

x_train_single, y_train_single = multivariate_data(dataset, dataset[:,12], 0,
                                                   TRAIN_VAL, past_history,
                                                   future_target, STEP,
                                                   single_step=True)
x_val_single, y_val_single = multivariate_data(dataset, dataset[:,12],
                                               TRAIN_VAL, VAL_TEST, past_history,
                                               future_target, STEP,
                                               single_step=True)

# %%
x_test_single, y_test_single = multivariate_data(dataset, dataset[:,12],
                                               VAL_TEST, None, past_history,
                                               future_target, STEP,
                                               single_step=True)

# %% [markdown]
# Let's look at a single data-point.

# %%
x_train_single.shape
# Out:
# (1680, 20, 16)

# %%
y_train_single.shape
# Out:
# (1680,)

# %%
print ('Single window of past history : {}'.format(x_train_single[0].shape))
# Out:
# Single window of past history : (20, 16)

# %%
BATCH_SIZE = 200
BUFFER_SIZE = 500

# %%
train_data_single = tf.data.Dataset.from_tensor_slices((x_train_single, y_train_single))
train_data_single = train_data_single.cache().shuffle(BUFFER_SIZE).batch(BATCH_SIZE).repeat()

val_data_single = tf.data.Dataset.from_tensor_slices((x_val_single, y_val_single))
val_data_single = val_data_single.batch(BATCH_SIZE).repeat()

# %%
x_train_single.shape
# Out:
# (1680, 20, 16)

# %%
single_step_model = tf.keras.models.Sequential()
single_step_model.add(tf.keras.layers.LSTM(128,
                                           input_shape=x_train_single.shape[-2:]))

single_step_model.add(tf.keras.layers.Dense(128,activation='relu'))
single_step_model.add(tf.keras.layers.Dense(64,activation='relu'))
single_step_model.add(tf.keras.layers.Dropout(0.01))
single_step_model.add(tf.keras.layers.Dense(1,activation='linear'))

single_step_model.compile(optimizer=tf.keras.optimizers.Adam(0.001), loss='mae')

# %% [markdown]
# Let's check out a sample prediction.

# %%
for x, y in val_data_single.take(1):
  print(single_step_model.predict(x).shape)
# Out:
# (200, 1)

# %%
EVALUATION_INTERVAL = 200
EPOCHS = 20

# %%
from keras.callbacks import ModelCheckpoint,EarlyStopping
# checkpoint_name = 'Weights-{epoch:03d}--{val_loss:.5f}.hdf5' 
checkpoint_name = 'RNNv2bestmodel.h5' 
mcp = ModelCheckpoint(checkpoint_name, monitor='val_loss', verbose = 1, save_best_only = True, mode ='auto')

es = EarlyStopping(monitor='val_loss', mode='min', verbose=1, patience=50)
# Out:
# Using TensorFlow backend.

# %%
single_step_history = single_step_model.fit(train_data_single, epochs=EPOCHS,
                                            steps_per_epoch=EVALUATION_INTERVAL,
                                            validation_data=val_data_single,
                                            validation_steps=50, callbacks=[mcp])
# Out:
# Train for 200 steps, validate for 50 steps
# Epoch 1/20
# 199/200 [============================>.] - ETA: 0s - loss: 0.1373
# Epoch 00001: val_loss improved from inf to 0.11298, saving model to RNNv2bestmodel.h5
# 200/200 [==============================] - 18s 89ms/step - loss: 0.1371 - val_loss: 0.1130
# Epoch 2/20
# 199/200 [============================>.] - ETA: 0s - loss: 0.0545
# Epoch 00002: val_loss improved from 0.11298 to 0.02632, saving model to RNNv2bestmodel.h5
# 200/200 [==============================] - 16s 82ms/step - loss: 0.0544 - val_loss: 0.0263
# Epoch 3/20
# 199/200 [============================>.] - ETA: 0s - loss: 0.0534
# Epoch 00003: val_loss did not improve from 0.02632
# 200/200 [==============================] - 15s 73ms/step - loss: 0.0535 - val_loss: 0.0433
# Epoch 4/20
# 199/200 [============================>.] - ETA: 0s - loss: 0.0643
# Epoch 00004: val_loss improved from 0.02632 to 0.00421, saving model to RNNv2bestmodel.h5
# 200/200 [==============================] - 15s 73ms/step - loss: 0.0641 - val_loss: 0.0042
# Epoch 5/20
# 198/200 [============================>.] - ETA: 0s - loss: 0.0563
# Epoch 00005: val_loss did not improve from 0.00421
# 200/200 [==============================] - 14s 72ms/step - loss: 0.0564 - val_loss: 0.0725
# Epoch 6/20
# 199/200 [============================>.] - ETA: 0s - loss: 0.0591
# Epoch 00006: val_loss did not improve from 0.00421
# 200/200 [==============================] - 14s 71ms/step - loss: 0.0590 - val_loss: 0.1237
# Epoch 7/20
# 199/200 [============================>.] - ETA: 0s - loss: 0.0552
# Epoch 00007: val_loss did not improve from 0.00421
# 200/200 [==============================] - 14s 70ms/step - loss: 0.0552 - val_loss: 0.1216
# Epoch 8/20
# 199/200 [============================>.] - ETA: 0s - loss: 0.0519
# Epoch 00008: val_loss did not improve from 0.00421
# 200/200 [==============================] - 12s 62ms/step - loss: 0.0520 - val_loss: 0.1218
# Epoch 9/20
# 199/200 [============================>.] - ETA: 0s - loss: 0.0496
# Epoch 00009: val_loss did not improve from 0.00421
# 200/200 [==============================] - 12s 59ms/step - loss: 0.0496 - val_loss: 0.0779
# Epoch 10/20
# 199/200 [============================>.] - ETA: 0s - loss: 0.0492
# Epoch 00010: val_loss did not improve from 0.00421
# 200/200 [==============================] - 12s 61ms/step - loss: 0.0492 - val_loss: 0.0150
# Epoch 11/20
# 199/200 [============================>.] - ETA: 0s - loss: 0.0468
# Epoch 00011: val_loss did not improve from 0.00421
# 200/200 [==============================] - 12s 60ms/step - loss: 0.0467 - val_loss: 0.0195
# Epoch 12/20
# 199/200 [============================>.] - ETA: 0s - loss: 0.0455
# Epoch 00012: val_loss did not improve from 0.00421
# 200/200 [==============================] - 13s 63ms/step - loss: 0.0456 - val_loss: 0.0195
# Epoch 13/20
# 199/200 [============================>.] - ETA: 0s - loss: 0.0446
# Epoch 00013: val_loss did not improve from 0.00421
# 200/200 [==============================] - 12s 59ms/step - loss: 0.0446 - val_loss: 0.0214
# Epoch 14/20
# 198/200 [============================>.] - ETA: 0s - loss: 0.0433
# Epoch 00014: val_loss did not improve from 0.00421
# 200/200 [==============================] - 12s 62ms/step - loss: 0.0433 - val_loss: 0.0615
# Epoch 15/20
# 199/200 [============================>.] - ETA: 0s - loss: 0.0438
# Epoch 00015: val_loss did not improve from 0.00421
# 200/200 [==============================] - 12s 61ms/step - loss: 0.0438 - val_loss: 0.0931
# Epoch 16/20
# 199/200 [============================>.] - ETA: 0s - loss: 0.0416
# Epoch 00016: val_loss did not improve from 0.00421
# 200/200 [==============================] - 12s 62ms/step - loss: 0.0415 - val_loss: 0.0993
# Epoch 17/20
# 199/200 [============================>.] - ETA: 0s - loss: 0.0409
# Epoch 00017: val_loss did not improve from 0.00421
# 200/200 [==============================] - 12s 61ms/step - loss: 0.0409 - val_loss: 0.0910
# Epoch 18/20
# 199/200 [============================>.] - ETA: 0s - loss: 0.0405
# Epoch 00018: val_loss did not improve from 0.00421
# 200/200 [==============================] - 12s 61ms/step - loss: 0.0405 - val_loss: 0.0607
# Epoch 19/20
# 199/200 [============================>.] - ETA: 0s - loss: 0.0394
# Epoch 00019: val_loss did not improve from 0.00421
# 200/200 [==============================] - 12s 62ms/step - loss: 0.0395 - val_loss: 0.0203
# Epoch 20/20
# 199/200 [============================>.] - ETA: 0s - loss: 0.0458
# Epoch 00020: val_loss did not improve from 0.00421
# 200/200 [==============================] - 13s 67ms/step - loss: 0.0458 - val_loss: 0.0162

# %%
def plot_train_history(history, title):
  loss = history.history['loss']
  val_loss = history.history['val_loss']

  epochs = range(len(loss))

  plt.figure()

  plt.plot(epochs, loss, 'b', label='Training loss')
  plt.plot(epochs, val_loss, 'r', label='Validation loss')
  plt.title(title)
  plt.legend()

  plt.show()

# %%
plot_train_history(single_step_history,
                   'Single Step Training and validation loss')

# %% [markdown]
# Load weights file

# %%
wights_file = 'RNNv2bestmodel.h5'
single_step_model.load_weights(wights_file) # load it
single_step_model.compile(optimizer=tf.keras.optimizers.Adam(0.001), loss='mae', metrics=['mean_absolute_error'])

# %% [markdown]
# #### Predict a single step

# %%
for x, y in val_data_single.take(3):
  plot = show_plot([x[1][:, 12].numpy(), y[1].numpy(),
                    single_step_model.predict(x)[1]], 0,
                   'Single Step Prediction')
  print(x.shape, y.shape)
  plot.show()
# Out:
# (200, 20, 16) (200,)
# (96, 20, 16) (96,)
# (200, 20, 16) (200,)

# %%
predictions=single_step_model.predict(x_test_single)

# %%
predictions=predictions*data_std[12]+data_mean[12]

# %%
y_test_single=y_test_single*data_std[12]+data_mean[12]

# %%
from sklearn import metrics

def RNN_comp_plot(dnn, testy, pred, labelx, labely, ftitle):
    # Look at the results
    lw = 2
    
    fig= plt.figure(figsize=(12, 10))
   
    y_hat=pred
        
    MAE=format(metrics.mean_absolute_error(testy, y_hat),'.3f')
    MSE=format(metrics.mean_squared_error(testy, y_hat),'.2f')
    R2=format(metrics.r2_score(testy, y_hat),'.4f')        
        
    plt.plot(y_hat, color='blue', lw=lw,
                      label='{} (MAE: {},  R^2: {})'.format(dnn, MAE, R2))
    plt.plot(testy, color='red', linestyle=':', lw=3,
                      label='Test data')                    
    plt.legend(loc='upper center',bbox_to_anchor=(0.5, 1.1),fontsize=12)
    plt.xlabel(labelx, fontsize=12)
    plt.ylabel(labely, fontsize=12)
    fig.suptitle(ftitle, fontsize=16)
    plt.show()

# %%
RNN_comp_plot("RNN",
             y_test_single,
             predictions,
             "Day",
             "Pressure",
             "Deep Learning")

# %% [markdown]
# ### Multi-Step model (Predict future sequence '0','1'....)
# In a multi-step prediction model, given a past history, the model needs to learn to predict a range of future values. Thus, unlike a single step model, where only a single future point is predicted, a multi-step model predict a sequence of the future.
#
# For the multi-step model, the training data again consists of recordings over the past five days sampled every hour. However, here, the model needs to learn to predict the temperature for the next 12 hours. Since an obversation is taken every 10 minutes, the output is 72 predictions. For this task, the dataset needs to be prepared accordingly, thus the first step is just to create it again, but with a different target window.

# %%
future_target = 7
x_train_multi, y_train_multi = multivariate_data(dataset, dataset[:, 12], 0,
                                                 TRAIN_VAL, past_history,
                                                 future_target, STEP)
x_val_multi, y_val_multi = multivariate_data(dataset, dataset[:, 12],
                                             TRAIN_VAL, VAL_TEST, past_history,
                                             future_target, STEP)

# %%
x_test_multi, y_test_multi = multivariate_data(dataset, dataset[:, 12],
                                             VAL_TEST, None, past_history,
                                             future_target, STEP)

# %% [markdown]
# Let's check out a sample data-point.

# %%
print ('Single window of past history : {}'.format(x_train_multi[0].shape))
print ('\n Target pressure to predict : {}'.format(y_train_multi[0].shape))
# Out:
# Single window of past history : (20, 16)
#
#  Target pressure to predict : (7,)

# %%
train_data_multi = tf.data.Dataset.from_tensor_slices((x_train_multi, y_train_multi))
train_data_multi = train_data_multi.cache().shuffle(BUFFER_SIZE).batch(BATCH_SIZE).repeat()

val_data_multi = tf.data.Dataset.from_tensor_slices((x_val_multi, y_val_multi))
val_data_multi = val_data_multi.batch(BATCH_SIZE).repeat()

# %% [markdown]
# Plotting a sample data-point.

# %%
def multi_step_plot(history, true_future, prediction):
  plt.figure(figsize=(12, 6))
  num_in = create_time_steps(len(history))
  num_out = len(true_future)

  plt.plot(num_in, np.array(history[:, 1]), label='History')
  plt.plot(np.arange(num_out)/STEP, np.array(true_future), 'bo',
           label='True Future')
  if prediction.any():
    plt.plot(np.arange(num_out)/STEP, np.array(prediction), 'ro',
             label='Predicted Future')
  plt.legend(loc='upper left')
  plt.show()

# %% [markdown]
# In this plot and subsequent similar plots

# %%
for x, y in train_data_multi.take(1):
  multi_step_plot(x[0], y[0], np.array([0]))

# %% [markdown]
# Since the task here is a bit more complicated than the previous task, the model now consists of two LSTM layers. Finally, since 72 predictions are made, the dense layer outputs 72 predictions.

# %%
multi_step_model = tf.keras.models.Sequential()
multi_step_model.add(tf.keras.layers.LSTM(128,
                                          return_sequences=True,
                                          input_shape=x_train_multi.shape[-2:]))
multi_step_model.add(tf.keras.layers.LSTM(256, activation='relu'))
multi_step_model.add(tf.keras.layers.Dense(64, activation='relu'))
multi_step_model.add(tf.keras.layers.Dropout(0.3))
multi_step_model.add(tf.keras.layers.Dense(7))   # Predict 3 steps, which is 'future target' 

multi_step_model.compile(optimizer=tf.keras.optimizers.RMSprop(), loss='mae')

# %% [markdown]
# Let's see how the model predicts before it trains.

# %%
for x, y in val_data_multi.take(1):
  print (multi_step_model.predict(x).shape)
# Out:
# (200, 7)

# %%
# checkpoint_name = 'Weights-{epoch:03d}--{val_loss:.5f}.hdf5' 
checkpoint_name2 = 'RNNv2bestforecastmodel.h5' 
mcp2 = ModelCheckpoint(checkpoint_name2, monitor='val_loss', verbose = 1, save_best_only = True, mode ='auto')

es2 = EarlyStopping(monitor='val_loss', mode='min', verbose=1, patience=50)

# %%
multi_step_history = multi_step_model.fit(train_data_multi, epochs=19,
                                          steps_per_epoch=200,
                                          validation_data=val_data_multi,
                                          validation_steps=50, callbacks=[mcp2])
# Out:
# Train for 200 steps, validate for 50 steps
# Epoch 1/19
# 199/200 [============================>.] - ETA: 0s - loss: 0.3574
# Epoch 00001: val_loss improved from inf to 0.26309, saving model to RNNv2bestforecastmodel.h5
# 200/200 [==============================] - 54s 271ms/step - loss: 0.3566 - val_loss: 0.2631
# Epoch 2/19
# 199/200 [============================>.] - ETA: 0s - loss: 0.1483
# Epoch 00002: val_loss improved from 0.26309 to 0.18989, saving model to RNNv2bestforecastmodel.h5
# 200/200 [==============================] - 50s 248ms/step - loss: 0.1481 - val_loss: 0.1899
# Epoch 3/19
# 199/200 [============================>.] - ETA: 0s - loss: 0.1219
# Epoch 00003: val_loss improved from 0.18989 to 0.05683, saving model to RNNv2bestforecastmodel.h5
# 200/200 [==============================] - 49s 243ms/step - loss: 0.1219 - val_loss: 0.0568
# Epoch 4/19
# 199/200 [============================>.] - ETA: 0s - loss: 0.1090
# Epoch 00004: val_loss improved from 0.05683 to 0.04846, saving model to RNNv2bestforecastmodel.h5
# 200/200 [==============================] - 49s 246ms/step - loss: 0.1089 - val_loss: 0.0485
# Epoch 5/19
# 199/200 [============================>.] - ETA: 0s - loss: 0.1016
# Epoch 00005: val_loss improved from 0.04846 to 0.03906, saving model to RNNv2bestforecastmodel.h5
# 200/200 [==============================] - 49s 245ms/step - loss: 0.1018 - val_loss: 0.0391
# Epoch 6/19
# 199/200 [============================>.] - ETA: 0s - loss: 0.0969
# Epoch 00006: val_loss did not improve from 0.03906
# 200/200 [==============================] - 49s 245ms/step - loss: 0.0968 - val_loss: 0.1522
# Epoch 7/19
# 199/200 [============================>.] - ETA: 0s - loss: 0.0924
# Epoch 00007: val_loss did not improve from 0.03906
# 200/200 [==============================] - 50s 248ms/step - loss: 0.0923 - val_loss: 0.0619
# Epoch 8/19
# 199/200 [============================>.] - ETA: 0s - loss: 0.0902
# Epoch 00008: val_loss did not improve from 0.03906
# 200/200 [==============================] - 48s 240ms/step - loss: 0.0903 - val_loss: 0.1142
# Epoch 9/19
# 199/200 [============================>.] - ETA: 0s - loss: 0.0877
# Epoch 00009: val_loss improved from 0.03906 to 0.03158, saving model to RNNv2bestforecastmodel.h5
# 200/200 [==============================] - 50s 251ms/step - loss: 0.0877 - val_loss: 0.0316
# Epoch 10/19
# 199/200 [============================>.] - ETA: 0s - loss: 0.0863
# Epoch 00010: val_loss improved from 0.03158 to 0.00493, saving model to RNNv2bestforecastmodel.h5
# 200/200 [==============================] - 48s 242ms/step - loss: 0.0863 - val_loss: 0.0049
# Epoch 11/19
# 199/200 [============================>.] - ETA: 0s - loss: 0.0846
# Epoch 00011: val_loss did not improve from 0.00493
# 200/200 [==============================] - 48s 239ms/step - loss: 0.0845 - val_loss: 0.0097
# Epoch 12/19
# 199/200 [============================>.] - ETA: 0s - loss: 0.0848
# Epoch 00012: val_loss did not improve from 0.00493
# 200/200 [==============================] - 51s 257ms/step - loss: 0.0847 - val_loss: 0.1039
# Epoch 13/19
# 199/200 [============================>.] - ETA: 0s - loss: 0.0849
# Epoch 00013: val_loss did not improve from 0.00493
# 200/200 [==============================] - 47s 233ms/step - loss: 0.0849 - val_loss: 0.0082
# Epoch 14/19
# 199/200 [============================>.] - ETA: 0s - loss: 0.0834
# Epoch 00014: val_loss did not improve from 0.00493
# 200/200 [==============================] - 46s 232ms/step - loss: 0.0835 - val_loss: 0.0493
# Epoch 15/19
# 199/200 [============================>.] - ETA: 0s - loss: 0.0828
# Epoch 00015: val_loss did not improve from 0.00493
# 200/200 [==============================] - 47s 236ms/step - loss: 0.0827 - val_loss: 0.0377
# Epoch 16/19
# 199/200 [============================>.] - ETA: 0s - loss: 0.0822
# Epoch 00016: val_loss did not improve from 0.00493
# 200/200 [==============================] - 50s 251ms/step - loss: 0.0821 - val_loss: 0.0468
# Epoch 17/19
# 199/200 [============================>.] - ETA: 0s - loss: 0.0815
# Epoch 00017: val_loss did not improve from 0.00493
# 200/200 [==============================] - 47s 234ms/step - loss: 0.0815 - val_loss: 0.0058
# Epoch 18/19
# 199/200 [============================>.] - ETA: 0s - loss: 0.0809
# Epoch 00018: val_loss did not improve from 0.00493
# 200/200 [==============================] - 46s 232ms/step - loss: 0.0809 - val_loss: 0.0704
# Epoch 19/19
# 199/200 [============================>.] - ETA: 0s - loss: 0.0813
# Epoch 00019: val_loss did not improve from 0.00493
# 200/200 [==============================] - 45s 223ms/step - loss: 0.0813 - val_loss: 0.0325

# %%
plot_train_history(multi_step_history, 'Multi-Step Training and validation loss')

# %%
wights_file2 = 'RNNv2bestforecastmodel.h5'
multi_step_model.load_weights(wights_file2) # load it
multi_step_model.compile(optimizer=tf.keras.optimizers.Adam(0.001), loss='mae', metrics=['mean_absolute_error'])

# %% [markdown]
# #### Predict a multi-step future
# Let's now have a look at how well your network has learnt to predict the future.

# %%
for x, y in val_data_multi.take(3):
  multi_step_plot(x[0], y[0], multi_step_model.predict(x)[0])

# %%
predictions=multi_step_model.predict(x_test_multi)

# %%
predictions=predictions[:,0]*data_std[12]+data_mean[12]

# %%
y_test_multi1=y_test_multi[:,0]*data_std[12]+data_mean[12]

# %%
y_test_multi1
# Out:
# array([214.7487528, 217.3829677, 211.7710457, 217.4773836, 217.1971328,
#        216.2043152, 216.3411286, 212.3116204, 214.7568186, 214.9020482,
#        214.9204852, 208.6228466, 214.3397938, 212.7490859, 210.5444665,
#        209.6926732, 212.759585 , 208.5918395, 209.7590502, 212.6951177,
#        211.5146395, 212.8768474, 207.609346 , 208.9515699, 210.3045644,
#        210.8791315, 208.7007359, 206.9121586, 211.3602315, 205.5140805,
#        209.3296691, 205.0462704, 204.6494732, 209.6984389, 208.1389564,
#        210.04151  , 204.7370086, 207.9481457, 209.8653634, 206.4250385,
#        201.9946199, 204.2298205, 204.0504916, 203.9902145, 207.0389968,
#        203.5597431, 202.9351992, 202.594789 , 204.8507817, 207.6078005,
#        200.7510429, 205.8794748, 202.3251663, 201.2237553, 204.0210941,
#        201.1571957, 200.8271914, 200.7613134, 200.5004569, 204.096247 ,
#        199.0086676, 202.0807616, 196.8576446, 201.5838825, 199.0251079,
#        199.0398383, 200.4616313, 202.1236523, 199.7461602, 202.7250654,
#        199.5867105, 200.616448 , 204.2266513, 200.0119872, 199.6153451,
#        202.5174429, 200.6271378, 199.9131408, 198.496222 , 201.4676627,
#        199.0952214, 197.989461 , 196.8421208, 193.7358597, 198.5721245,
#        195.2579849, 194.646517 , 197.4252002, 194.5614736, 197.6107232,
#        195.5938003, 192.1352341, 192.8671202, 198.4563024, 195.2705493,
#        189.626466 , 195.6416724, 192.5927845, 191.3905504, 195.5047529,
#        195.9115718, 195.1228521, 194.8669625, 189.4985843, 190.5851597,
#        192.6312746, 191.9581412, 191.7164264, 187.9191115, 190.8946765,
#        192.7286678, 188.4094083, 190.6596515, 191.3591981, 193.7569869,
#        191.6416394, 192.0129416, 192.9528477, 187.1177594, 190.9588816,
#        188.6356552, 190.7259065, 189.7241033, 191.7636998, 188.9309172,
#        189.4618543, 185.5786251, 187.940883 , 190.5293395, 189.4504332,
#        187.5273871, 187.1051077, 185.8648299, 189.5494938, 188.0819552,
#        184.0955782, 190.3048783, 187.5863906, 187.6912909, 186.3534661,
#        188.8980909, 181.7245156, 186.0860687, 187.274929 , 185.2126709,
#        186.0729356, 185.6655984, 187.3188234, 181.0759372, 180.604416 ,
#        185.3079718, 180.3361343, 182.127625 , 183.0027515, 184.5398884,
#        184.3990881, 184.1931345, 184.8293636, 185.2817263, 180.2266933,
#        179.7546312, 177.148329 , 184.4467656, 183.2640017, 184.1864307,
#        178.3989189, 179.8912496, 178.9783843, 178.2836653, 181.1873669,
#        182.1487756, 182.7859788, 182.5369862, 180.0159474, 178.7367661,
#        178.7146946, 180.640002 , 180.5908475, 182.8426611, 175.4104537,
#        181.1838207, 176.0696917, 180.7668779, 180.5028117, 179.4480754,
#        175.2350921, 177.3123883, 176.1909722, 176.9382633, 176.0171246,
#        176.2802904, 178.0132047, 177.1465702, 175.607711 , 176.2630355,
#        179.9207486, 178.3835768, 178.4639478, 176.4725318, 173.6965372,
#        175.2322353, 177.2351818, 175.4860156, 173.4492212, 173.7195252,
#        174.8400028, 175.3616835, 173.0879949, 172.4491075, 173.4887377,
#        175.1391866, 174.9064952, 174.7959244, 172.4176631, 172.9557636,
#        174.6082786, 174.274377 , 169.1441652, 170.4885898, 172.4704585,
#        174.8238587, 171.7367285, 171.5184112, 172.3421321, 170.9011836,
#        169.5504438, 168.9353312, 170.7245636, 168.5541672, 167.5157443,
#        172.317842 , 167.4961759, 170.3015551, 167.8595448, 167.9232091,
#        167.288798 , 170.7222425, 170.1971464, 168.8343625, 167.0156539,
#        165.7077314, 168.828428 , 166.3787105, 169.5939244, 168.5883551,
#        167.0414467, 169.6172678, 169.5027591, 164.8129102, 166.3644242,
#        162.8557354, 169.1504841, 169.079801 , 162.9882234, 169.6103864,
#        164.1644071, 166.0334411, 164.2222524, 164.2463587, 167.5042238,
#        163.6245488, 163.8227589, 164.8993093, 164.4521114, 162.9130746,
#        162.2665388, 163.2023863, 162.3223001, 163.4717283, 162.57915  ,
#        160.4623835, 163.462024 , 164.4778905, 163.7520527, 165.2524578,
#        160.6317324, 163.1763853, 160.1727884, 163.1234267, 160.8237187,
#        160.7938886, 165.2847976, 158.5008529, 160.0300222, 160.5208638,
#        158.6715822, 160.2015975, 161.7512689, 156.9857919, 163.3231456,
#        162.7802982, 157.2770146, 161.5193179, 158.1146351, 157.3474003,
#        160.6024707, 158.8538284, 159.3007355, 157.3637428, 159.5141552,
#        159.1338001, 159.4895231, 159.1966125, 158.8088331, 156.4650107,
#        158.7455654, 158.5216938, 157.2423649, 159.3128579, 158.2866942,
#        156.823423 , 154.5739515, 158.1162247, 158.8221036, 156.3822911,
#        157.5900379, 154.5710195, 154.3212956, 154.0395558, 154.9708494,
#        156.6208245, 152.398252 , 154.3481835, 156.0352665, 155.3311662,
#        152.6353177, 155.4395099, 155.5474251, 154.5154301, 152.1237906,
#        155.9273472, 152.9654914, 152.4229152, 156.0525687, 151.5631211,
#        154.1196918, 153.6380836, 151.5537357, 153.4574145, 151.504809 ,
#        153.5182507, 152.0746452, 149.6604917, 154.9864742, 152.9337951,
#        154.5656168, 154.2078942, 149.507797 , 154.1956759, 153.9341024,
#        150.2903284, 152.5891486, 151.477402 , 149.5514871, 152.5128684,
#        152.6163906, 153.1163321, 151.8304211, 150.5595431, 149.2154985,
#        149.8161518, 148.8483434, 147.8046587, 148.1498288, 150.8355506,
#        150.4556117, 148.2703787, 151.1795459, 148.7711639, 148.4672082,
#        147.1700068, 149.0403549, 147.5768254, 147.6116449, 148.8845467,
#        147.868488 , 148.6499294, 148.4203032, 150.990127 , 151.0729612,
#        145.7721525, 147.4399501, 146.7632093, 148.4290576, 144.76101  ,
#        147.8987142, 145.0900389, 145.9357734, 143.3935929, 148.0346984,
#        144.594573 , 144.8015383, 144.4806749, 143.8019505, 147.4153396,
#        144.6248696, 145.3105926, 145.8185804, 142.3913166, 142.2842039,
#        143.2513172, 143.406524 , 147.5606969, 143.1924922, 143.477819 ,
#        145.7437956, 144.8339143, 142.043021 , 141.4166442, 143.1962178,
#        142.4786913, 143.1186669, 144.0335293, 142.2176837, 143.605629 ,
#        141.2687251, 145.8208321, 143.2632542, 142.5933153, 140.8660304,
#        142.8416081, 144.0187387, 138.9007859, 143.5898058, 139.7268958,
#        143.8796693, 140.3204855, 139.5156691, 142.5357068, 141.876388 ,
#        142.0706179, 139.4255709, 140.7580029, 140.0941412, 138.8939374,
#        139.0620837, 139.7158147, 137.7179625, 140.7152785, 140.5086058,
#        138.5252949, 138.4881091, 137.7307722, 137.540628 , 137.2769301,
#        138.8030175, 137.4521319, 135.5392831, 139.21605  , 137.9793543,
#        137.2245891, 137.9098771, 140.6951689, 137.6105489, 138.0572804,
#        136.8996152, 136.4753425, 137.3710297, 138.5733924, 135.324505 ,
#        136.3841531, 136.3069939, 138.1968925, 138.3146387, 135.5057859,
#        134.2435506, 135.5380998, 134.5021633, 136.4598956, 135.93009  ,
#        138.7883475, 135.0315947, 134.0867683, 135.6456487, 132.3357751,
#        135.5963829, 132.878166 ])

# %%
RNN_comp_plot("RNN",
             y_test_multi1,
             predictions,
             "Week",
             "Pressure",
             "Deep Learning")
