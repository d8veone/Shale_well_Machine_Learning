# %%
from __future__ import division
import pandas as pd
import numpy as np

from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.preprocessing import MinMaxScaler

import matplotlib.pyplot as plt
import time, os, math, warnings
from matplotlib import pyplot

import tensorflow as tf
from keras.models import Sequential, Model
from keras.layers import Input, Dense, Dropout, Activation, Flatten, TimeDistributed, Reshape
from keras.layers.recurrent import LSTM, GRU, SimpleRNN
from keras.utils import plot_model
# Out:
# Using TensorFlow backend.

# %%
# Set up some global variables
USE_GPU = True

if USE_GPU:
    device = '/device:GPU:0'
else:
    device = '/cpu:0'

# Constant to control how often we print when training models
print_every = 100

print('Using device: ', device)
# Out:
# Using device:  /device:GPU:0

# %% [markdown]
# ### Pre-processing Functions

# %% [markdown]
# Reshape input data

# %%
# Every "looK_back" X points, only one Y, does not predict future. 
def reshape_data(X, Y, look_back=1):
    dataX, dataY = [], []
    for i in range(len(X) - look_back):
        a = X[i:(i + look_back), :]
        dataX.append(a)
        dataY.append(Y[i + look_back, :])
    print('# of data: ', len(dataY))
    return np.array(dataX), np.array(dataY)

# %% [markdown]
# ### Plotting Functions

# %%
# %matplotlib inline
plt.rcParams['figure.figsize'] = (10.0, 8.0) # set default size of plots
plt.rcParams['image.interpolation'] = 'nearest'
plt.rcParams['image.cmap'] = 'gray'

# for auto-reloading external modules
# see http://stackoverflow.com/questions/1907993/autoreload-of-modules-in-ipython
# %load_ext autoreload
# %autoreload 2



def plot_pressure(t, q_actual, q_pred, dev_fraction, test_fraction, well):
    """This function plots actual and predicted bottom hole pressure"""
    # Plotting pwf v time
    plt.figure()
    plt.plot(t, q_actual, 'k-', linewidth=3, label='Actual oil rate')

    # Training
    train_end = int((1 - dev_fraction - test_fraction) * q_pred.shape[0])
    plt.plot(t[0:train_end], q_pred[0:train_end],
                 'r-', markeredgecolor='red', label='Training Set', linewidth=3)
    
    # Dev
    dev_end = int((1 - test_fraction) * q_pred.shape[0])
    plt.plot(t[train_end:dev_end], q_pred[train_end:dev_end],
                 'y-', markeredgecolor='orange', label='Dev Set', linewidth=3)
    
    # Test
    plt.plot(t[dev_end:], q_pred[dev_end:],
                 'g-', markeredgecolor='green', label='Test Set', linewidth=3)    
    
    plt.xlabel("Time (hours)", fontsize=14)
    plt.ylabel("Bottom Hole Pressure (psi)", fontsize=14)
    plt.title("Bottom Hole Pressure Well "+str(well), y=1, fontsize=13)
    plt.legend(loc="best", prop=dict(size=14))
    plt.xlim(0, max(t))
    plt.ylim(0, max(max(q_actual), max(q_pred)) + 10)
    plt.grid(True)

def plot_pred_rate(t, q_actual, q_pred, dev_fraction, test_fraction, well):
    """This function plots actual and predicted bottom hole pressure"""
    # Plotting pwf v time
    plt.figure()
    plt.plot(t, q_actual, 'k-', linewidth=3, label='Actual oil rate')

    # Training
    train_end = int((1 - dev_fraction - test_fraction) * q_pred.shape[0])
    plt.plot(t[0:train_end], q_pred[0:train_end],
                 'r-', markeredgecolor='red', label='Training Set', linewidth=3)
    
    # Dev
    dev_end = int((1 - test_fraction) * q_pred.shape[0])
    plt.plot(t[train_end:dev_end], q_pred[train_end:dev_end],
                 'y-', markeredgecolor='orange', label='Dev Set', linewidth=3)
    
    # Test
    plt.plot(t[dev_end:], q_pred[dev_end:],
                 'g-', markeredgecolor='green', label='Test Set', linewidth=3)    
    
    plt.xlabel("Time (hours)", fontsize=14)
    plt.ylabel("Flow Rate (STB/d)", fontsize=14)
    plt.title("Flow Rate Well " +str(well), y=1, fontsize=13)
    plt.legend(loc="best", prop=dict(size=14))
    plt.xlim(0, max(t))
    plt.ylim(0, max(max(q_actual), max(q_pred)) + 10)
    plt.grid(True)

def plot_rates(t, q, wellname, color, label):
    """This function plots actual flow rates"""
    # Plotting Flow Rate v time
    plt.plot(t, q, color, linewidth=3, label=label)
    plt.xlabel("Time (hours)", fontsize=11)
    plt.ylabel("Flow Rate (STB/D)", fontsize=11)
    plt.title('Flow Rate Well ' + wellname, y=0.82, fontsize=9)
    plt.legend(loc=1, prop=dict(size=8))
    plt.xlim(0, max(t))
    plt.ylim(0, max(q) + 10)
    plt.grid(True)

def plot_pressure_rates(x, y, y_pred, labelname):
    """This function plots both pressure and actual flow rates"""
    plt.figure()
    if labelname=='Training Data':
        color='red'
    else:
        color='green'

    plt.subplot(411)
    plot_pressure(x['TIME'], y, y_pred, labelname, color)

    plt.subplot(412)
    plot_rates(x['TIME'], x['WWPR:P1'], wellname='A', color='blue', label='Water Rate')
    plot_rates(x['TIME'], x['WOPR:P1'], wellname='A', color='green', label='Oil Rate')
    plt.ylim(0, max(max(x['WWPR:P1'].values), max(x['WOPR:P1'].values)) + 10)

    plt.subplot(413)
    plot_rates(x['TIME'], x['WOPR:P2'],wellname='B',color='green', label='Oil Rate')
    plot_rates(x['TIME'], x['WWPR:P2'],wellname='B',color='blue', label='Water Rate')
    plt.ylim(0, max(max(x['WWPR:P2'].values), max(x['WOPR:P2'].values)) + 10)

    plt.subplot(414)
    plot_rates(x['TIME'], x['WOPR:P3'], wellname='C', color='green', label='Oil Rate')
    plot_rates(x['TIME'], x['WWPR:P3'], wellname='C', color='blue', label='Water Rate')
    plt.ylim(0, max(max(x['WWPR:P3'].values), max(x['WOPR:P3'].values)) + 10)

def plot_loss(history, title):
    plt.figure()
    plt.plot(history.history['loss'], label='Train Loss', linewidth=3)
    plt.plot(history.history['val_loss'], label='Dev Loss', linewidth=3)
    plt.legend()
    plt.grid()
    plt.xlabel("No of Epochs", fontsize=15)
    plt.ylabel("Loss", fontsize=15)
    plt.title('Loss - ' + title, fontsize=15)
    plt.xlim(0, len(history.history['loss']))
    plt.ylim(0, max(history.history['val_loss']))
    plt.show()

def plot_loss_comparison(histories):
    plt.figure()
    plt.plot(histories['Simple RNN'].history['val_loss'], linewidth=3, label='Simple RNN')
    plt.plot(histories['GRU'].history['val_loss'], linewidth=3, label='GRU')
    plt.plot(histories['LSTM'].history['val_loss'], linewidth=3, label='LSTM')
    plt.legend()
    plt.grid()
    plt.xlabel("No of Epochs", fontsize=15)
    plt.ylabel("Loss", fontsize=15)
    plt.title(' Dev Loss', fontsize=15)
    plt.xlim(0, len(histories['Simple RNN'].history['loss']))
    plt.ylim(0, 0.02)
    plt.show()

# %% [markdown]
# ### Load Data

# %%
df=pd.read_csv('simple_well_portional_noise3_less.csv')

# %%
df.drop(columns='Date', inplace=True)
df2=pd.get_dummies(df['FlowPatternGasLiquid6'],prefix='FlowPattern')
df=pd.concat([df,df2],axis=1)
df.drop(columns='FlowPatternGasLiquid6', inplace=True)
df.head()
# Out:
#    Gas Flow_MMSCFD  Oil_bpd    Water_bpd  FWHP_psig  FroudeNumberGas6  \
# 0            2.006    434.3  4358.796496     5714.6          0.082530
# 1            1.983    425.3  3954.486042     5569.2          0.084297
# 2            1.971    423.3  3483.036837     5551.1          0.083442
# 3            1.977    416.3  3290.559813     5483.7          0.085425
# 4            1.961    410.4  2967.713050     5482.5          0.084584
#
#    FroudeNumberLiquid6  HoldupFractionLiquid6  ReynoldsNumber6  \
# 0             0.802494               0.838955      397428.0850
# 1             0.729662               0.820790      370815.2940
# 2             0.658774               0.808913      335519.3383
# 3             0.624417               0.796104      323486.3778
# 4             0.575357               0.786456      298405.2945
#
#    SuperficialVelocityGas6  SuperficialVelocityLiquid6  \
# 0                 0.514045                    2.533015
# 1                 0.537978                    2.317304
# 2                 0.525775                    2.085509
# 3                 0.543198                    1.981269
# 4                 0.530236                    1.819061
#
#    SurfaceTensionLiquidInSitu6  ViscosityLiquidInSitu6    FINAPRESS  \
# 0                     0.012455                0.273919  2245.856283
# 1                     0.013136                0.275289  2167.784425
# 2                     0.012690                0.276644  2214.713037
# 3                     0.012918                0.277573  2191.448539
# 4                     0.012455                0.278797  2240.738376
#
#      FINATEMP  FlowPattern_3  FlowPattern_4
# 0  212.007518              0              1
# 1  210.591058              0              1
# 2  208.827114              0              1
# 3  207.873805              0              1
# 4  206.288196              0              1

# %%
y_pre=df[['FINAPRESS','FINATEMP']]      # Pressure label
X_pre=df.iloc[:,0:11] # Pressure data

# %%
y_pre.head()
# Out:
#      FINAPRESS    FINATEMP
# 0  2245.856283  212.007518
# 1  2167.784425  210.591058
# 2  2214.713037  208.827114
# 3  2191.448539  207.873805
# 4  2240.738376  206.288196

# %% [markdown]
# ### Pre-processing

# %%
# Split train-dev and test sets
test_fraction = 0.20
x_traindev_raw, x_test_raw, y_traindev_raw, y_test_raw = train_test_split(X_pre,
                                                  y_pre,
                                                  test_size=test_fraction,
                                                  shuffle=False)

# Split train and val sets
dev_fraction = 0.20 # of total dataset
x_train_raw, x_dev_raw, y_train_raw, y_dev_raw = train_test_split(x_traindev_raw,
                                                  y_traindev_raw,
                                                  test_size= dev_fraction/(1-test_fraction),
                                                  shuffle=False)

# Data Scaling
scaler_x = MinMaxScaler()
x_train_norm = scaler_x.fit_transform(x_train_raw.as_matrix())  #based on train data
x_dev_norm = scaler_x.transform(x_dev_raw.as_matrix())
x_test_norm = scaler_x.transform(x_test_raw.as_matrix())

scaler_y = MinMaxScaler()
y_train_norm = scaler_y.fit_transform(y_train_raw.as_matrix())
y_dev_norm = scaler_y.transform(y_dev_raw.as_matrix())
y_test_norm = scaler_y.transform(y_test_raw.as_matrix())

# Create time blocks
x_train, y_train = reshape_data(x_train_norm, y_train_norm, look_back=10)
x_dev, y_dev = reshape_data(x_dev_norm, y_dev_norm, look_back=10)
x_test, y_test = reshape_data(x_test_norm, y_test_norm, look_back=10)
# Out:
# # of data:  146
# # of data:  42
# # of data:  42
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/ipykernel_launcher.py:17: FutureWarning: Method .as_matrix will be removed in a future version. Use .values instead.
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: Method .as_matrix will be removed in a future version. Use .values instead.
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/ipykernel_launcher.py:19: FutureWarning: Method .as_matrix will be removed in a future version. Use .values instead.
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/ipykernel_launcher.py:22: FutureWarning: Method .as_matrix will be removed in a future version. Use .values instead.
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/ipykernel_launcher.py:23: FutureWarning: Method .as_matrix will be removed in a future version. Use .values instead.
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/ipykernel_launcher.py:24: FutureWarning: Method .as_matrix will be removed in a future version. Use .values instead.

# %%
y_train.shape
# Out:
# (146, 2)

# %%
def run_model(x_train, y_train, x_dev, y_dev, epochs=500, batch_size=50, method='LSTM'):
    classifier = {'GRU' : GRU,
                  'LSTM' : LSTM,
                  'Simple RNN' : SimpleRNN}


    inputs = Input(shape=(x_train.shape[1], x_train.shape[2]))

    X = classifier[method](128, return_sequences=True)(inputs)    
    # equvilent to X=LSTM(512, return_sequences=True)(inputs)   
    X = classifier[method](128, return_sequences=True)(X)
    
    X = TimeDistributed(Dense(64, activation='relu'))(X)
    # TimeDistrituted allows you to apply that Dense function across every output at same time
    # 2 outputs in current case
    # 2 results at the same time, hence 2 outputs, not 2 nodes. 
    X = Dropout(0.3)(X)
    
    out1 = Dense(1)(Flatten()(X)) # three well flow rates
    out2 = Dense(1)(Flatten()(X))
  
    
    model = Model(input=inputs, output=[out1, out2])
    
    #parallel_model = multi_gpu_model(model, gpus=8)

    model.compile(loss='mean_squared_error', optimizer=tf.keras.optimizers.RMSprop(), metrics=['mae','accuracy'])
    history = model.fit(x_train, [y_train[:, 0], y_train[:, 1]], 
                        epochs=epochs, batch_size=batch_size,
                        validation_data=(x_dev, [y_dev[:, 0], y_dev[:, 1]]), 
                        verbose=1, shuffle=False)
    return model, history

# %%
model_LSTM, history_LSTM = run_model(x_train, y_train, x_dev, y_dev, epochs=50, batch_size=80, method='LSTM')
# Out:
#  0.0068 - val_loss: 0.0162 - val_dense_8_loss: 0.0133 - val_dense_9_loss: 0.0029 - val_dense_8_mae: 0.1118 - val_dense_8_accuracy: 0.0000e+00 - val_dense_9_mae: 0.0523 - val_dense_9_accuracy: 0.0000e+00
# Epoch 4/50
# 146/146 [==============================] - 0s 2ms/step - loss: 0.0571 - dense_8_loss: 0.0439 - dense_9_loss: 0.0097 - dense_8_mae: 0.1508 - dense_8_accuracy: 0.0068 - dense_9_mae: 0.0734 - dense_9_accuracy: 0.0068 - val_loss: 0.0333 - val_dense_8_loss: 0.0300 - val_dense_9_loss: 0.0033 - val_dense_8_mae: 0.1691 - val_dense_8_accuracy: 0.0000e+00 - val_dense_9_mae: 0.0561 - val_dense_9_accuracy: 0.0000e+00
# Epoch 5/50
# 146/146 [==============================] - 0s 2ms/step - loss: 0.0621 - dense_8_loss: 0.0435 - dense_9_loss: 0.0143 - dense_8_mae: 0.1787 - dense_8_accuracy: 0.0137 - dense_9_mae: 0.0963 - dense_9_accuracy: 0.0068 - val_loss: 0.0219 - val_dense_8_loss: 0.0153 - val_dense_9_loss: 0.0065 - val_dense_8_mae: 0.1204 - val_dense_8_accuracy: 0.0000e+00 - val_dense_9_mae: 0.0808 - val_dense_9_accuracy: 0.0000e+00
# Epoch 6/50
# 146/146 [==============================] - 0s 3ms/step - loss: 0.0385 - dense_8_loss: 0.0211 - dense_9_loss: 0.0156 - dense_8_mae: 0.1107 - dense_8_accuracy: 0.0137 - dense_9_mae: 0.0976 - dense_9_accuracy: 0.0068 - val_loss: 0.0433 - val_dense_8_loss: 0.0328 - val_dense_9_loss: 0.0106 - val_dense_8_mae: 0.1773 - val_dense_8_accuracy: 0.0000e+00 - val_dense_9_mae: 0.1012 - val_dense_9_accuracy: 0.0000e+00
# Epoch 7/50
# 146/146 [==============================] - 0s 3ms/step - loss: 0.0493 - dense_8_loss: 0.0248 - dense_9_loss: 0.0219 - dense_8_mae: 0.1350 - dense_8_accuracy: 0.0137 - dense_9_mae: 0.1251 - dense_9_accuracy: 0.0068 - val_loss: 0.0128 - val_dense_8_loss: 0.0127 - val_dense_9_loss: 1.6498e-04 - val_dense_8_mae: 0.1091 - val_dense_8_accuracy: 0.0000e+00 - val_dense_9_mae: 0.0110 - val_dense_9_accuracy: 0.0000e+00
# Epoch 8/50
# 146/146 [==============================] - 0s 2ms/step - loss: 0.0203 - dense_8_loss: 0.0100 - dense_9_loss: 0.0091 - dense_8_mae: 0.0761 - dense_8_accuracy: 0.0137 - dense_9_mae: 0.0691 - dense_9_accuracy: 0.0068 - val_loss: 0.0227 - val_dense_8_loss: 0.0196 - val_dense_9_loss: 0.0031 - val_dense_8_mae: 0.1365 - val_dense_8_accuracy: 0.0000e+00 - val_dense_9_mae: 0.0541 - val_dense_9_accuracy: 0.0000e+00
# Epoch 9/50
# 146/146 [==============================] - 0s 3ms/step - loss: 0.0216 - dense_8_loss: 0.0102 - dense_9_loss: 0.0102 - dense_8_mae: 0.0786 - dense_8_accuracy: 0.0137 - dense_9_mae: 0.0791 - dense_9_accuracy: 0.0068 - val_loss: 0.0077 - val_dense_8_loss: 0.0074 - val_dense_9_loss: 3.6341e-04 - val_dense_8_mae: 0.0821 - val_dense_8_accuracy: 0.0000e+00 - val_dense_9_mae: 0.0181 - val_dense_9_accuracy: 0.0000e+00
# Epoch 10/50
# 146/146 [==============================] - 0s 3ms/step - loss: 0.0253 - dense_8_loss: 0.0126 - dense_9_loss: 0.0113 - dense_8_mae: 0.0838 - dense_8_accuracy: 0.0137 - dense_9_mae: 0.0842 - dense_9_accuracy: 0.0068 - val_loss: 0.0336 - val_dense_8_loss: 0.0266 - val_dense_9_loss: 0.0070 - val_dense_8_mae: 0.1598 - val_dense_8_accuracy: 0.0000e+00 - val_dense_9_mae: 0.0822 - val_dense_9_accuracy: 0.0000e+00
# Epoch 11/50
# 146/146 [==============================] - 0s 2ms/step - loss: 0.0319 - dense_8_loss: 0.0167 - dense_9_loss: 0.0138 - dense_8_mae: 0.1154 - dense_8_accuracy: 0.0137 - dense_9_mae: 0.0924 - dense_9_accuracy: 0.0068 - val_loss: 0.0039 - val_dense_8_loss: 0.0038 - val_dense_9_loss: 7.9956e-05 - val_dense_8_mae: 0.0572 - val_dense_8_accuracy: 0.0000e+00 - val_dense_9_mae: 0.0076 - val_dense_9_accuracy: 0.0000e+00
# Epoch 12/50
# 146/146 [==============================] - 0s 2ms/step - loss: 0.0222 - dense_8_loss: 0.0115 - dense_9_loss: 0.0098 - dense_8_mae: 0.0865 - dense_8_accuracy: 0.0137 - dense_9_mae: 0.0757 - dense_9_accuracy: 0.0068 - val_loss: 0.0303 - val_dense_8_loss: 0.0236 - val_dense_9_loss: 0.0067 - val_dense_8_mae: 0.1502 - val_dense_8_accuracy: 0.0000e+00 - val_dense_9_mae: 0.0806 - val_dense_9_accuracy: 0.0000e+00
# Epoch 13/50
# 146/146 [==============================] - 0s 2ms/step - loss: 0.0254 - dense_8_loss: 0.0107 - dense_9_loss: 0.0134 - dense_8_mae: 0.0855 - dense_8_accuracy: 0.0137 - dense_9_mae: 0.0921 - dense_9_accuracy: 0.0068 - val_loss: 0.0104 - val_dense_8_loss: 0.0101 - val_dense_9_loss: 3.0546e-04 - val_dense_8_mae: 0.0970 - val_dense_8_accuracy: 0.0000e+00 - val_dense_9_mae: 0.0150 - val_dense_9_accuracy: 0.0000e+00
# Epoch 14/50
# 146/146 [==============================] - 0s 2ms/step - loss: 0.0250 - dense_8_loss: 0.0122 - dense_9_loss: 0.0116 - dense_8_mae: 0.0905 - dense_8_accuracy: 0.0137 - dense_9_mae: 0.0849 - dense_9_accuracy: 0.0068 - val_loss: 0.0352 - val_dense_8_loss: 0.0259 - val_dense_9_loss: 0.0094 - val_dense_8_mae: 0.1575 - val_dense_8_accuracy: 0.0000e+00 - val_dense_9_mae: 0.0950 - val_dense_9_accuracy: 0.0000e+00
# Epoch 15/50
# 146/146 [==============================] - 0s 2ms/step - loss: 0.0366 - dense_8_loss: 0.0151 - dense_9_loss: 0.0194 - dense_8_mae: 0.1071 - dense_8_accuracy: 0.0137 - dense_9_mae: 0.1103 - dense_9_accuracy: 0.0068 - val_loss: 0.0088 - val_dense_8_loss: 0.0074 - val_dense_9_loss: 0.0014 - val_dense_8_mae: 0.0820 - val_dense_8_accuracy: 0.0000e+00 - val_dense_9_mae: 0.0345 - val_dense_9_accuracy: 0.0000e+00
# Epoch 16/50
# 146/146 [==============================] - 0s 2ms/step - loss: 0.0248 - dense_8_loss: 0.0129 - dense_9_loss: 0.0108 - dense_8_mae: 0.0932 - dense_8_accuracy: 0.0137 - dense_9_mae: 0.0798 - dense_9_accuracy: 0.0068 - val_loss: 0.0352 - val_dense_8_loss: 0.0275 - val_dense_9_loss: 0.0078 - val_dense_8_mae: 0.1624 - val_dense_8_accuracy: 0.0000e+00 - val_dense_9_mae: 0.0865 - val_dense_9_accuracy: 0.0000e+00
# Epoch 17/50
# 146/146 [==============================] - 0s 3ms/step - loss: 0.0273 - dense_8_loss: 0.0151 - dense_9_loss: 0.0106 - dense_8_mae: 0.1044 - dense_8_accuracy: 0.0137 - dense_9_mae: 0.0820 - dense_9_accuracy: 0.0068 - val_loss: 0.0113 - val_dense_8_loss: 0.0096 - val_dense_9_loss: 0.0017 - val_dense_8_mae: 0.0944 - val_dense_8_accuracy: 0.0000e+00 - val_dense_9_mae: 0.0392 - val_dense_9_accuracy: 0.0000e+00
# Epoch 18/50
# 146/146 [==============================] - 0s 3ms/step - loss: 0.0292 - dense_8_loss: 0.0191 - dense_9_loss: 0.0088 - dense_8_mae: 0.1066 - dense_8_accuracy: 0.0137 - dense_9_mae: 0.0718 - dense_9_accuracy: 0.0068 - val_loss: 0.0355 - val_dense_8_loss: 0.0259 - val_dense_9_loss: 0.0096 - val_dense_8_mae: 0.1576 - val_dense_8_accuracy: 0.0000e+00 - val_dense_9_mae: 0.0965 - val_dense_9_accuracy: 0.0000e+00
# Epoch 19/50
# 146/146 [==============================] - 0s 2ms/step - loss: 0.0390 - dense_8_loss: 0.0247 - dense_9_loss: 0.0119 - dense_8_mae: 0.1377 - dense_8_accuracy: 0.0137 - dense_9_mae: 0.0890 - dense_9_accuracy: 0.0068 - val_loss: 0.0155 - val_dense_8_loss: 0.0107 - val_dense_9_loss: 0.0048 - val_dense_8_mae: 0.1002 - val_dense_8_accuracy: 0.0000e+00 - val_dense_9_mae: 0.0673 - val_dense_9_accuracy: 0.0000e+00
# Epoch 20/50
# 146/146 [==============================] - 0s 3ms/step - loss: 0.0205 - dense_8_loss: 0.0117 - dense_9_loss: 0.0078 - dense_8_mae: 0.0870 - dense_8_accuracy: 0.0137 - dense_9_mae: 0.0665 - dense_9_accuracy: 0.0068 - val_loss: 0.0295 - val_dense_8_loss: 0.0235 - val_dense_9_loss: 0.0060 - val_dense_8_mae: 0.1500 - val_dense_8_accuracy: 0.0000e+00 - val_dense_9_mae: 0.0762 - val_dense_9_accuracy: 0.0000e+00
# Epoch 21/50
# 146/146 [==============================] - 0s 2ms/step - loss: 0.0212 - dense_8_loss: 0.0131 - dense_9_loss: 0.0068 - dense_8_mae: 0.0931 - dense_8_accuracy: 0.0137 - dense_9_mae: 0.0659 - dense_9_accuracy: 0.0068 - val_loss: 0.0159 - val_dense_8_loss: 0.0139 - val_dense_9_loss: 0.0020 - val_dense_8_mae: 0.1145 - val_dense_8_accuracy: 0.0000e+00 - val_dense_9_mae: 0.0427 - val_dense_9_accuracy: 0.0000e+00
# Epoch 22/50
# 146/146 [==============================] - 0s 2ms/step - loss: 0.0204 - dense_8_loss: 0.0109 - dense_9_loss: 0.0086 - dense_8_mae: 0.0823 - dense_8_accuracy: 0.0137 - dense_9_mae: 0.0716 - dense_9_accuracy: 0.0068 - val_loss: 0.0316 - val_dense_8_loss: 0.0227 - val_dense_9_loss: 0.0089 - val_dense_8_mae: 0.1476 - val_dense_8_accuracy: 0.0000e+00 - val_dense_9_mae: 0.0927 - val_dense_9_accuracy: 0.0000e+00
# Epoch 23/50
# 146/146 [==============================] - 0s 3ms/step - loss: 0.0282 - dense_8_loss: 0.0174 - dense_9_loss: 0.0092 - dense_8_mae: 0.1122 - dense_8_accuracy: 0.0137 - dense_9_mae: 0.0796 - dense_9_accuracy: 0.0068 - val_loss: 0.0150 - val_dense_8_loss: 0.0115 - val_dense_9_loss: 0.0034 - val_dense_8_mae: 0.1039 - val_dense_8_accuracy: 0.0000e+00 - val_dense_9_mae: 0.0564 - val_dense_9_accuracy: 0.0000e+00
# Epoch 24/50
# 146/146 [==============================] - 0s 2ms/step - loss: 0.0200 - dense_8_loss: 0.0115 - dense_9_loss: 0.0076 - dense_8_mae: 0.0835 - dense_8_accuracy: 0.0137 - dense_9_mae: 0.0702 - dense_9_accuracy: 0.0068 - val_loss: 0.0325 - val_dense_8_loss: 0.0242 - val_dense_9_loss: 0.0083 - val_dense_8_mae: 0.1523 - val_dense_8_accuracy: 0.0000e+00 - val_dense_9_mae: 0.0897 - val_dense_9_accuracy: 0.0000e+00
# Epoch 25/50
# 146/146 [==============================] - 0s 3ms/step - loss: 0.0224 - dense_8_loss: 0.0110 - dense_9_loss: 0.0101 - dense_8_mae: 0.0904 - dense_8_accuracy: 0.0137 - dense_9_mae: 0.0831 - dense_9_accuracy: 0.0068 - val_loss: 0.0191 - val_dense_8_loss: 0.0151 - val_dense_9_loss: 0.0040 - val_dense_8_mae: 0.1198 - val_dense_8_accuracy: 0.0000e+00 - val_dense_9_mae: 0.0614 - val_dense_9_accuracy: 0.0000e+00
# Epoch 26/50
# 146/146 [==============================] - 0s 2ms/step - loss: 0.0225 - dense_8_loss: 0.0120 - dense_9_loss: 0.0096 - dense_8_mae: 0.0885 - dense_8_accuracy: 0.0137 - dense_9_mae: 0.0753 - dense_9_accuracy: 0.0068 - val_loss: 0.0316 - val_dense_8_loss: 0.0235 - val_dense_9_loss: 0.0081 - val_dense_8_mae: 0.1502 - val_dense_8_accuracy: 0.0000e+00 - val_dense_9_mae: 0.0885 - val_dense_9_accuracy: 0.0000e+00
# Epoch 27/50
# 146/146 [==============================] - 0s 3ms/step - loss: 0.0293 - dense_8_loss: 0.0144 - dense_9_loss: 0.0130 - dense_8_mae: 0.0960 - dense_8_accuracy: 0.0068 - dense_9_mae: 0.0925 - dense_9_accuracy: 0.0068 - val_loss: 0.0159 - val_dense_8_loss: 0.0131 - val_dense_9_loss: 0.0028 - val_dense_8_mae: 0.1111 - val_dense_8_accuracy: 0.0000e+00 - val_dense_9_mae: 0.0512 - val_dense_9_accuracy: 0.0000e+00
# Epoch 28/50
# 146/146 [==============================] - 0s 3ms/step - loss: 0.0223 - dense_8_loss: 0.0104 - dense_9_loss: 0.0109 - dense_8_mae: 0.0818 - dense_8_accuracy: 0.0137 - dense_9_mae: 0.0839 - dense_9_accuracy: 0.0068 - val_loss: 0.0324 - val_dense_8_loss: 0.0246 - val_dense_9_loss: 0.0077 - val_dense_8_mae: 0.1537 - val_dense_8_accuracy: 0.0000e+00 - val_dense_9_mae: 0.0866 - val_dense_9_accuracy: 0.0000e+00
# Epoch 29/50
# 146/146 [==============================] - 0s 2ms/step - loss: 0.0305 - dense_8_loss: 0.0165 - dense_9_loss: 0.0120 - dense_8_mae: 0.1091 - dense_8_accuracy: 0.0137 - dense_9_mae: 0.0867 - dense_9_accuracy: 0.0068 - val_loss: 0.0154 - val_dense_8_loss: 0.0101 - val_dense_9_loss: 0.0052 - val_dense_8_mae: 0.0974 - val_dense_8_accuracy: 0.0000e+00 - val_dense_9_mae: 0.0708 - val_dense_9_accuracy: 0.0000e+00
# Epoch 30/50
# 146/146 [==============================] - 0s 2ms/step - loss: 0.0201 - dense_8_loss: 0.0141 - dense_9_loss: 0.0054 - dense_8_mae: 0.0995 - dense_8_accuracy: 0.0137 - dense_9_mae: 0.0572 - dense_9_accuracy: 0.0068 - val_loss: 0.0354 - val_dense_8_loss: 0.0307 - val_dense_9_loss: 0.0047 - val_dense_8_mae: 0.1717 - val_dense_8_accuracy: 0.0000e+00 - val_dense_9_mae: 0.0675 - val_dense_9_accuracy: 0.0000e+00
# Epoch 31/50
# 146/146 [==============================] - 0s 3ms/step - loss: 0.0250 - dense_8_loss: 0.0165 - dense_9_loss: 0.0068 - dense_8_mae: 0.1061 - dense_8_accuracy: 0.0137 - dense_9_mae: 0.0614 - dense_9_accuracy: 0.0068 - val_loss: 0.0247 - val_dense_8_loss: 0.0212 - val_dense_9_loss: 0.0035 - val_dense_8_mae: 0.1422 - val_dense_8_accuracy: 0.0000e+00 - val_dense_9_mae: 0.0579 - val_dense_9_accuracy: 0.0000e+00
# Epoch 32/50
# 146/146 [==============================] - 0s 2ms/step - loss: 0.0161 - dense_8_loss: 0.0077 - dense_9_loss: 0.0077 - dense_8_mae: 0.0717 - dense_8_accuracy: 0.0137 - dense_9_mae: 0.0663 - dense_9_accuracy: 0.0068 - val_loss: 0.0323 - val_dense_8_loss: 0.0250 - val_dense_9_loss: 0.0074 - val_dense_8_mae: 0.1548 - val_dense_8_accuracy: 0.0000e+00 - val_dense_9_mae: 0.0845 - val_dense_9_accuracy: 0.0000e+00
# Epoch 33/50
# 146/146 [==============================] - 0s 2ms/step - loss: 0.0242 - dense_8_loss: 0.0104 - dense_9_loss: 0.0122 - dense_8_mae: 0.0791 - dense_8_accuracy: 0.0137 - dense_9_mae: 0.0891 - dense_9_accuracy: 0.0068 - val_loss: 0.0223 - val_dense_8_loss: 0.0201 - val_dense_9_loss: 0.0023 - val_dense_8_mae: 0.1382 - val_dense_8_accuracy: 0.0000e+00 - val_dense_9_mae: 0.0463 - val_dense_9_accuracy: 0.0000e+00
# Epoch 34/50
# 146/146 [==============================] - 0s 3ms/step - loss: 0.0164 - dense_8_loss: 0.0067 - dense_9_loss: 0.0088 - dense_8_mae: 0.0663 - dense_8_accuracy: 0.0137 - dense_9_mae: 0.0697 - dense_9_accuracy: 0.0068 - val_loss: 0.0323 - val_dense_8_loss: 0.0232 - val_dense_9_loss: 0.0091 - val_dense_8_mae: 0.1492 - val_dense_8_accuracy: 0.0000e+00 - val_dense_9_mae: 0.0940 - val_dense_9_accuracy: 0.0000e+00
# Epoch 35/50
# 146/146 [==============================] - 0s 2ms/step - loss: 0.0132 - dense_8_loss: 0.0041 - dense_9_loss: 0.0083 - dense_8_mae: 0.0526 - dense_8_accuracy: 0.0137 - dense_9_mae: 0.0712 - dense_9_accuracy: 0.0068 - val_loss: 0.0264 - val_dense_8_loss: 0.0205 - val_dense_9_loss: 0.0059 - val_dense_8_mae: 0.1398 - val_dense_8_accuracy: 0.0000e+00 - val_dense_9_mae: 0.0754 - val_dense_9_accuracy: 0.0000e+00
# Epoch 36/50
# 146/146 [==============================] - 0s 3ms/step - loss: 0.0118 - dense_8_loss: 0.0058 - dense_9_loss: 0.0053 - dense_8_mae: 0.0611 - dense_8_accuracy: 0.0137 - dense_9_mae: 0.0561 - dense_9_accuracy: 0.0068 - val_loss: 0.0312 - val_dense_8_loss: 0.0245 - val_dense_9_loss: 0.0067 - val_dense_8_mae: 0.1536 - val_dense_8_accuracy: 0.0000e+00 - val_dense_9_mae: 0.0801 - val_dense_9_accuracy: 0.0000e+00
# Epoch 37/50
# 146/146 [==============================] - 0s 2ms/step - loss: 0.0107 - dense_8_loss: 0.0053 - dense_9_loss: 0.0049 - dense_8_mae: 0.0557 - dense_8_accuracy: 0.0137 - dense_9_mae: 0.0507 - dense_9_accuracy: 0.0068 - val_loss: 0.0208 - val_dense_8_loss: 0.0170 - val_dense_9_loss: 0.0038 - val_dense_8_mae: 0.1270 - val_dense_8_accuracy: 0.0000e+00 - val_dense_9_mae: 0.0597 - val_dense_9_accuracy: 0.0000e+00
# Epoch 38/50
# 146/146 [==============================] - 0s 2ms/step - loss: 0.0158 - dense_8_loss: 0.0094 - dense_9_loss: 0.0057 - dense_8_mae: 0.0800 - dense_8_accuracy: 0.0137 - dense_9_mae: 0.0551 - dense_9_accuracy: 0.0068 - val_loss: 0.0348 - val_dense_8_loss: 0.0279 - val_dense_9_loss: 0.0069 - val_dense_8_mae: 0.1638 - val_dense_8_accuracy: 0.0000e+00 - val_dense_9_mae: 0.0815 - val_dense_9_accuracy: 0.0000e+00
# Epoch 39/50
# 146/146 [==============================] - 0s 3ms/step - loss: 0.0218 - dense_8_loss: 0.0147 - dense_9_loss: 0.0060 - dense_8_mae: 0.1037 - dense_8_accuracy: 0.0137 - dense_9_mae: 0.0635 - dense_9_accuracy: 0.0068 - val_loss: 0.0204 - val_dense_8_loss: 0.0171 - val_dense_9_loss: 0.0033 - val_dense_8_mae: 0.1278 - val_dense_8_accuracy: 0.0000e+00 - val_dense_9_mae: 0.0553 - val_dense_9_accuracy: 0.0000e+00
# Epoch 40/50
# 146/146 [==============================] - 0s 2ms/step - loss: 0.0130 - dense_8_loss: 0.0078 - dense_9_loss: 0.0050 - dense_8_mae: 0.0713 - dense_8_accuracy: 0.0137 - dense_9_mae: 0.0573 - dense_9_accuracy: 0.0068 - val_loss: 0.0335 - val_dense_8_loss: 0.0242 - val_dense_9_loss: 0.0093 - val_dense_8_mae: 0.1526 - val_dense_8_accuracy: 0.0000e+00 - val_dense_9_mae: 0.0949 - val_dense_9_accuracy: 0.0000e+00
# Epoch 41/50
# 146/146 [==============================] - 0s 2ms/step - loss: 0.0139 - dense_8_loss: 0.0069 - dense_9_loss: 0.0062 - dense_8_mae: 0.0662 - dense_8_accuracy: 0.0137 - dense_9_mae: 0.0620 - dense_9_accuracy: 0.0068 - val_loss: 0.0187 - val_dense_8_loss: 0.0138 - val_dense_9_loss: 0.0049 - val_dense_8_mae: 0.1148 - val_dense_8_accuracy: 0.0000e+00 - val_dense_9_mae: 0.0684 - val_dense_9_accuracy: 0.0000e+00
# Epoch 42/50
# 146/146 [==============================] - 0s 2ms/step - loss: 0.0183 - dense_8_loss: 0.0103 - dense_9_loss: 0.0074 - dense_8_mae: 0.0844 - dense_8_accuracy: 0.0137 - dense_9_mae: 0.0694 - dense_9_accuracy: 0.0068 - val_loss: 0.0326 - val_dense_8_loss: 0.0233 - val_dense_9_loss: 0.0092 - val_dense_8_mae: 0.1500 - val_dense_8_accuracy: 0.0000e+00 - val_dense_9_mae: 0.0947 - val_dense_9_accuracy: 0.0000e+00
# Epoch 43/50
# 146/146 [==============================] - 0s 2ms/step - loss: 0.0252 - dense_8_loss: 0.0145 - dense_9_loss: 0.0092 - dense_8_mae: 0.1045 - dense_8_accuracy: 0.0137 - dense_9_mae: 0.0778 - dense_9_accuracy: 0.0068 - val_loss: 0.0152 - val_dense_8_loss: 0.0085 - val_dense_9_loss: 0.0067 - val_dense_8_mae: 0.0898 - val_dense_8_accuracy: 0.0000e+00 - val_dense_9_mae: 0.0802 - val_dense_9_accuracy: 0.0000e+00
# Epoch 44/50
# 146/146 [==============================] - 0s 2ms/step - loss: 0.0168 - dense_8_loss: 0.0082 - dense_9_loss: 0.0079 - dense_8_mae: 0.0713 - dense_8_accuracy: 0.0137 - dense_9_mae: 0.0686 - dense_9_accuracy: 0.0068 - val_loss: 0.0349 - val_dense_8_loss: 0.0255 - val_dense_9_loss: 0.0094 - val_dense_8_mae: 0.1567 - val_dense_8_accuracy: 0.0000e+00 - val_dense_9_mae: 0.0955 - val_dense_9_accuracy: 0.0000e+00
# Epoch 45/50
# 146/146 [==============================] - 0s 3ms/step - loss: 0.0145 - dense_8_loss: 0.0056 - dense_9_loss: 0.0080 - dense_8_mae: 0.0604 - dense_8_accuracy: 0.0137 - dense_9_mae: 0.0712 - dense_9_accuracy: 0.0068 - val_loss: 0.0237 - val_dense_8_loss: 0.0173 - val_dense_9_loss: 0.0064 - val_dense_8_mae: 0.1289 - val_dense_8_accuracy: 0.0000e+00 - val_dense_9_mae: 0.0786 - val_dense_9_accuracy: 0.0000e+00
# Epoch 46/50
# 146/146 [==============================] - 0s 2ms/step - loss: 0.0155 - dense_8_loss: 0.0083 - dense_9_loss: 0.0065 - dense_8_mae: 0.0714 - dense_8_accuracy: 0.0137 - dense_9_mae: 0.0647 - dense_9_accuracy: 0.0068 - val_loss: 0.0305 - val_dense_8_loss: 0.0229 - val_dense_9_loss: 0.0076 - val_dense_8_mae: 0.1487 - val_dense_8_accuracy: 0.0000e+00 - val_dense_9_mae: 0.0860 - val_dense_9_accuracy: 0.0000e+00
# Epoch 47/50
# 146/146 [==============================] - 0s 3ms/step - loss: 0.0295 - dense_8_loss: 0.0174 - dense_9_loss: 0.0104 - dense_8_mae: 0.1120 - dense_8_accuracy: 0.0137 - dense_9_mae: 0.0806 - dense_9_accuracy: 0.0068 - val_loss: 0.0122 - val_dense_8_loss: 0.0093 - val_dense_9_loss: 0.0029 - val_dense_8_mae: 0.0939 - val_dense_8_accuracy: 0.0000e+00 - val_dense_9_mae: 0.0528 - val_dense_9_accuracy: 0.0000e+00
# Epoch 48/50
# 146/146 [==============================] - 0s 2ms/step - loss: 0.0150 - dense_8_loss: 0.0098 - dense_9_loss: 0.0046 - dense_8_mae: 0.0831 - dense_8_accuracy: 0.0137 - dense_9_mae: 0.0539 - dense_9_accuracy: 0.0068 - val_loss: 0.0320 - val_dense_8_loss: 0.0241 - val_dense_9_loss: 0.0078 - val_dense_8_mae: 0.1526 - val_dense_8_accuracy: 0.0000e+00 - val_dense_9_mae: 0.0871 - val_dense_9_accuracy: 0.0000e+00
# Epoch 49/50
# 146/146 [==============================] - 0s 3ms/step - loss: 0.0171 - dense_8_loss: 0.0101 - dense_9_loss: 0.0059 - dense_8_mae: 0.0794 - dense_8_accuracy: 0.0137 - dense_9_mae: 0.0554 - dense_9_accuracy: 0.0068 - val_loss: 0.0221 - val_dense_8_loss: 0.0155 - val_dense_9_loss: 0.0066 - val_dense_8_mae: 0.1225 - val_dense_8_accuracy: 0.0000e+00 - val_dense_9_mae: 0.0796 - val_dense_9_accuracy: 0.0000e+00
# Epoch 50/50
# 146/146 [==============================] - 0s 2ms/step - loss: 0.0146 - dense_8_loss: 0.0082 - dense_9_loss: 0.0057 - dense_8_mae: 0.0748 - dense_8_accuracy: 0.0137 - dense_9_mae: 0.0613 - dense_9_accuracy: 0.0068 - val_loss: 0.0261 - val_dense_8_loss: 0.0179 - val_dense_9_loss: 0.0082 - val_dense_8_mae: 0.1315 - val_dense_8_accuracy: 0.0000e+00 - val_dense_9_mae: 0.0892 - val_dense_9_accuracy: 0.0000e+00

# %%
# Training
y_pred_train_pre = model_LSTM.predict(x_train)
y_pred_train_scaled = np.concatenate((y_pred_train_pre[0], y_pred_train_pre[1]), axis=1)
y_pred_train = scaler_y.inverse_transform(y_pred_train_scaled)
y_train_act = scaler_y.inverse_transform(y_train)

# Dev
y_pred_dev_pre = model_LSTM.predict(x_dev)
y_pred_dev_scaled = np.concatenate((y_pred_dev_pre[0], y_pred_dev_pre[1]), axis=1)
y_pred_dev = scaler_y.inverse_transform(y_pred_dev_scaled)
y_dev_act = scaler_y.inverse_transform(y_dev)

# Test
y_pred_test_pre = model_LSTM.predict(x_test)
y_pred_test_scaled = np.concatenate((y_pred_test_pre[0], y_pred_test_pre[1]), axis=1)
y_pred_test = scaler_y.inverse_transform(y_pred_test_scaled)
y_test_act = scaler_y.inverse_transform(y_test)

# Train-Dev-Test
y_act = np.concatenate([y_train_act, y_dev_act, y_test_act])
y_pred = np.concatenate([y_pred_train, y_pred_dev, y_pred_test])

# %%
def plot_train_history(history, title):
  loss = history.history['loss']
  val_loss = history.history['val_loss']

  epochs = range(len(loss))

  plt.figure()

  plt.plot(epochs, loss, 'b', label='Training loss')
  plt.plot(epochs, val_loss, 'r', label='Validation loss')
  plt.title(title)
  plt.legend()

  plt.show()

# %%
plot_train_history(history_LSTM,
                   'LSTM Training and validation loss')

# %%
from sklearn import metrics

def RNN_comp_plot(dnn, testy, pred, labelx, labely, ftitle):
    # Look at the results
    lw = 2
    
    fig= plt.figure(figsize=(12, 10))
   
    y_hat=pred
        
    MAE=format(metrics.mean_absolute_error(testy, y_hat),'.3f')
    MSE=format(metrics.mean_squared_error(testy, y_hat),'.2f')
    R2=format(metrics.r2_score(testy, y_hat),'.4f')        
        
    plt.plot(y_hat, color='blue', lw=lw,
                      label='{} (MAE: {},  R^2: {})'.format(dnn, MAE, R2))
    plt.plot(testy, color='red', linestyle=':', lw=3,
                      label='Test data')                    
    plt.legend(loc='upper center',bbox_to_anchor=(0.5, 1.1),fontsize=12)
    plt.xlabel(labelx, fontsize=12)
    plt.ylabel(labely, fontsize=12)
    fig.suptitle(ftitle, fontsize=16)
    plt.show()

# %%
RNN_comp_plot("RNN",
              y_test_act[:,0],
              y_pred_test[:,0],
             "Week",
             "Pressure",
             "Deep Learning")
