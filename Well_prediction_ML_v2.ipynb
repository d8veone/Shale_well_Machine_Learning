# %% [markdown]
# # This is project is to predict the wellhead pressure and flow pattern within the well
#
# ![shale well](img/shallwellimg.jpg)

# %% [markdown]
# ### Import modules

# %%
import itertools
import numpy as np
import matplotlib.pyplot as plt

import pandas as pd
import numpy as np

from sklearn import preprocessing

import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import datasets, layers, models

# %matplotlib inline

# %% [markdown]
# ### Read raw data

# %%
df=pd.read_csv('well_2520data_v1.csv')

# %%
df.head(10)
# Out:
#         Date  Gas Flow_MMSCFD    Oil_bpd   Water_bpd    FWHP_psig  \
# 0   1/1/2020         1.997999  466.86395  4320.80866  5603.811198
# 1   1/2/2020         2.000979  462.75264  3177.54154  5574.183600
# 2   1/3/2020         1.998964  448.63094  2587.33434  5547.496275
# 3   1/4/2020         1.985018  444.05424  2207.89845  5532.051609
# 4   1/5/2020         1.986000  428.11200  1983.00000  5525.004375
# 5   1/6/2020         1.987958  420.11463  1820.87166  5548.391319
# 6   1/7/2020         1.977030  415.01122  1670.88489  5511.073517
# 7   1/8/2020         1.971069  409.78794  1535.60078  5515.186100
# 8   1/9/2020         1.969065  402.03000  1438.51904  5513.816063
# 9  1/10/2020         1.976930  394.22377  1357.69973  5487.840445
#
#    FroudeNumberGas6  FroudeNumberLiquid6  HoldupFractionLiquid6  \
# 0          0.080394             0.799680               0.839809
# 1          0.079922             0.629477               0.811463
# 2          0.080651             0.537949               0.788673
# 3          0.079546             0.481507               0.775623
# 4          0.081171             0.443607               0.759974
# 5          0.081468             0.419461               0.752030
# 6          0.081660             0.394465               0.741363
# 7          0.081495             0.374159               0.734226
# 8          0.082224             0.357779               0.725598
# 9          0.084160             0.342153               0.712889
#
#    ReynoldsNumber6  SuperficialVelocityGas6  SuperficialVelocityLiquid6  \
# 0      396646.0544                 0.513819                    2.540583
# 1      312421.2874                 0.491906                    1.980774
# 2      268611.3109                 0.484539                    1.681916
# 3      238882.5679                 0.467621                    1.496468
# 4      221882.4547                 0.469368                    1.372262
# 5      208901.8706                 0.460970                    1.289409
# 6      197481.0750                 0.459343                    1.210455
# 7      186547.3755                 0.450511                    1.142146
# 8      179023.1202                 0.448904                    1.087958
# 9      173746.6015                 0.457214                    1.038848
#
#    SurfaceTensionLiquidInSitu6  ViscosityLiquidInSitu6  FlowPatternGasLiquid6  \
# 0                     0.013141                0.273806                      4
# 1                     0.011881                0.276766                      4
# 2                     0.011080                0.279040                      4
# 3                     0.010385                0.281000                      4
# 4                     0.009937                0.282733                      4
# 5                     0.009384                0.283624                      4
# 6                     0.009193                0.284948                      4
# 7                     0.008759                0.285707                      4
# 8                     0.008473                0.286459                      4
# 9                     0.008355                0.287522                      4
#
#      FINAPRESS    FINATEMP
# 0  2150.835786  211.852508
# 1  2284.109281  207.602074
# 2  2371.590019  204.256007
# 3  2439.152773  201.442625
# 4  2494.398480  199.322796
# 5  2561.829500  197.628022
# 6  2574.393705  195.777948
# 7  2621.714041  193.960849
# 8  2656.924487  192.472122
# 9  2671.283002  191.060322

# %%
df.drop(columns='Date', inplace=True)

# %%
df.head()
# Out:
#    Gas Flow_MMSCFD    Oil_bpd   Water_bpd    FWHP_psig  FroudeNumberGas6  \
# 0         1.997999  466.86395  4320.80866  5603.811198          0.080394
# 1         2.000979  462.75264  3177.54154  5574.183600          0.079922
# 2         1.998964  448.63094  2587.33434  5547.496275          0.080651
# 3         1.985018  444.05424  2207.89845  5532.051609          0.079546
# 4         1.986000  428.11200  1983.00000  5525.004375          0.081171
#
#    FroudeNumberLiquid6  HoldupFractionLiquid6  ReynoldsNumber6  \
# 0             0.799680               0.839809      396646.0544
# 1             0.629477               0.811463      312421.2874
# 2             0.537949               0.788673      268611.3109
# 3             0.481507               0.775623      238882.5679
# 4             0.443607               0.759974      221882.4547
#
#    SuperficialVelocityGas6  SuperficialVelocityLiquid6  \
# 0                 0.513819                    2.540583
# 1                 0.491906                    1.980774
# 2                 0.484539                    1.681916
# 3                 0.467621                    1.496468
# 4                 0.469368                    1.372262
#
#    SurfaceTensionLiquidInSitu6  ViscosityLiquidInSitu6  FlowPatternGasLiquid6  \
# 0                     0.013141                0.273806                      4
# 1                     0.011881                0.276766                      4
# 2                     0.011080                0.279040                      4
# 3                     0.010385                0.281000                      4
# 4                     0.009937                0.282733                      4
#
#      FINAPRESS    FINATEMP
# 0  2150.835786  211.852508
# 1  2284.109281  207.602074
# 2  2371.590019  204.256007
# 3  2439.152773  201.442625
# 4  2494.398480  199.322796

# %%
df['FlowPatternGasLiquid6'].nunique()
# Out:
# 2

# %% [markdown]
# zero hot encoding

# %%
df2=pd.get_dummies(df['FlowPatternGasLiquid6'],prefix='FlowPattern')

# %%
df2.head()
# Out:
#    FlowPattern_3  FlowPattern_4
# 0              0              1
# 1              0              1
# 2              0              1
# 3              0              1
# 4              0              1

# %%
df=pd.concat([df,df2],axis=1)

# %%
df.drop(columns='FlowPatternGasLiquid6', inplace=True)

# %%
df.head()
# Out:
#    Gas Flow_MMSCFD    Oil_bpd   Water_bpd    FWHP_psig  FroudeNumberGas6  \
# 0         1.997999  466.86395  4320.80866  5603.811198          0.080394
# 1         2.000979  462.75264  3177.54154  5574.183600          0.079922
# 2         1.998964  448.63094  2587.33434  5547.496275          0.080651
# 3         1.985018  444.05424  2207.89845  5532.051609          0.079546
# 4         1.986000  428.11200  1983.00000  5525.004375          0.081171
#
#    FroudeNumberLiquid6  HoldupFractionLiquid6  ReynoldsNumber6  \
# 0             0.799680               0.839809      396646.0544
# 1             0.629477               0.811463      312421.2874
# 2             0.537949               0.788673      268611.3109
# 3             0.481507               0.775623      238882.5679
# 4             0.443607               0.759974      221882.4547
#
#    SuperficialVelocityGas6  SuperficialVelocityLiquid6  \
# 0                 0.513819                    2.540583
# 1                 0.491906                    1.980774
# 2                 0.484539                    1.681916
# 3                 0.467621                    1.496468
# 4                 0.469368                    1.372262
#
#    SurfaceTensionLiquidInSitu6  ViscosityLiquidInSitu6    FINAPRESS  \
# 0                     0.013141                0.273806  2150.835786
# 1                     0.011881                0.276766  2284.109281
# 2                     0.011080                0.279040  2371.590019
# 3                     0.010385                0.281000  2439.152773
# 4                     0.009937                0.282733  2494.398480
#
#      FINATEMP  FlowPattern_3  FlowPattern_4
# 0  211.852508              0              1
# 1  207.602074              0              1
# 2  204.256007              0              1
# 3  201.442625              0              1
# 4  199.322796              0              1

# %%
y_pre=df['FINAPRESS']
X_pre=df.drop(columns=['FINAPRESS','FINATEMP'], axis=1)

# %%
y_hol=df['HoldupFractionLiquid6']
X_hol=df.drop(columns=['HoldupFractionLiquid6','FINATEMP'], axis=1)

# %%
y_pat=df[['FlowPattern_3','FlowPattern_4']]
X_pat=df.drop(columns=['FlowPattern_3','FlowPattern_4','FINATEMP'], axis=1)

# %% [markdown]
# ### Plot four sets of data

# %%
def four_y_plot(paraa, labela, parab, labelb, parac, labelc, parad, labeld, labelx, title):
    def make_patch_spines_invisible(ax):
        ax.set_frame_on(True)
        ax.patch.set_visible(False)
        for sp in ax.spines.values():
            sp.set_visible(False)
    
    fig, host = plt.subplots(figsize=(10, 8))
    fig.subplots_adjust(right=1)
    
    par1 = host.twinx()
    par2 = host.twinx()
    par3 = host.twinx()

    # Offset the right spine of par2.  The ticks and label have already been
    # placed on the right by twinx above.
    par2.spines["right"].set_position(("axes", 1.1))
    par3.spines["right"].set_position(("axes", 1.2))
    # Having been created by twinx, par2 has its frame off, so the line of its
    # detached spine is invisible.  First, activate the frame but make the patch
    # and spines invisible.
    make_patch_spines_invisible(par2)
    make_patch_spines_invisible(par3)
    # Second, show the right spine.
    par2.spines["right"].set_visible(True)
    par3.spines["right"].set_visible(True)
    
    p1, = host.plot(paraa, "b-", label=labela)
    p2, = par1.plot(parab, "r-", label=labelb)
    p3, = par2.plot(parac, "g-", label=labelc)
    p4, = par3.plot(parad, "black", label=labeld)
    
    # host.set_xlim(0, 250)
    # host.set_ylim(0, 2.2)
    # par1.set_ylim(0, 500)
    # par2.set_ylim(1, 5000)
    # par3.set_ylim(1, 6000)
    
    host.set_xlabel(labelx, fontsize=14)
    host.set_ylabel(labela, fontsize=14)
    par1.set_ylabel(labelb, fontsize=14)
    par2.set_ylabel(labelc, fontsize=14)
    par3.set_ylabel(labeld, fontsize=14)
    
    host.yaxis.label.set_color(p1.get_color())
    par1.yaxis.label.set_color(p2.get_color())
    par2.yaxis.label.set_color(p3.get_color())
    par3.yaxis.label.set_color(p4.get_color())
    
    tkw = dict(size=4, width=1.5)
    host.tick_params(axis='y', colors=p1.get_color(), labelsize=12)
    par1.tick_params(axis='y', colors=p2.get_color(), labelsize=12)
    par2.tick_params(axis='y', colors=p3.get_color(), labelsize=12)
    par3.tick_params(axis='y', colors=p4.get_color(), labelsize=12)
    host.tick_params(axis='x', labelsize=14)
    
    lines = [p1, p2, p3, p4]
    
    host.legend(lines, [l.get_label() for l in lines], fontsize=14)
    plt.title(title, fontsize=16)
    
    plt.show()

# %%
four_y_plot(df['Gas Flow_MMSCFD'], "Gas",
            df['Oil_bpd'], "Oil", 
            df['Water_bpd'],"Water",
            df['FWHP_psig'], "Pressure",
            "Week",
            "Bottom Hole Conditions")

# %% [markdown]
# Prepare train and test data

# %%
X_pre= preprocessing.StandardScaler().fit(X_pre).transform(X_pre)
X_pre[0:5]
X_hol= preprocessing.StandardScaler().fit(X_hol).transform(X_hol)
X_hol[0:5]
# Out:
# array([[ 3.08034778,  7.41251108, 22.74044591,  3.52936387,  0.71204048,
#         17.23520473, 17.57055256, -1.33344928, 18.0991947 , -1.29536628,
#         -2.24718977,  1.86092738, -3.29104633,  3.29104633],
#        [ 3.08953373,  7.33546142, 16.52021914,  3.49722259,  0.64370644,
#         13.37361027, 13.19650185, -1.41732485, 13.89191119, -1.43975185,
#         -2.22837368,  2.04598629, -3.29104633,  3.29104633],
#        [ 3.08332346,  7.07080803, 13.30905129,  3.46827104,  0.74919954,
#         11.29701269, 10.92131528, -1.44552037, 11.6458161 , -1.53154325,
#         -2.21392258,  2.16745897, -3.29104633,  3.29104633],
#        [ 3.04034166,  6.98503655, 11.24463673,  3.45151601,  0.58916243,
#         10.01644644,  9.37741039, -1.51027583, 10.25206396, -1.61115899,
#         -2.20146995,  2.26127424, -3.29104633,  3.29104633],
#        [ 3.0433682 ,  6.6862646 , 10.02102124,  3.44387087,  0.82458307,
#          9.15657978,  8.49454233, -1.50359058,  9.3185838 , -1.6624754 ,
#         -2.19045649,  2.3379865 , -3.29104633,  3.29104633]])

# %% [markdown]
# Split train data and test data by 0.8/0.2

# %%
X_pre.shape
# Out:
# (2520, 14)

# %%
X_train=X_pre[0:2016]
y_train=y_pre[0:2016]
X_test=X_pre[2016:]
y_test=y_pre[2016:]
# hold up data
X_hol_train=X_hol[0:2016]
y_hol_train=y_hol[0:2016]
X_hol_test=X_hol[2016:]
y_hol_test=y_hol[2016:]

# %%
y_train[0:5]
# Out:
# 0    2150.835786
# 1    2284.109281
# 2    2371.590019
# 3    2439.152773
# 4    2494.398480
# Name: FINAPRESS, dtype: float64

# %%
y_mean=y_train.mean()
y_std=y_train.std()
y_train=(y_train-y_mean)/y_std

# %%
y_train[0:5]
# Out:
# 0    1.635576
# 1    1.820220
# 2    1.941421
# 3    2.035026
# 4    2.111566
# Name: FINAPRESS, dtype: float64

# %%
y_test[0:5]
# Out:
# 2016    221.526626
# 2017    221.474029
# 2018    218.974897
# 2019    215.275115
# 2020    216.872993
# Name: FINAPRESS, dtype: float64

# %%
'''
# random split train and test
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split( X_pre[0:182],y_pre[0:182], test_size=0.05,random_state=21)
print ('Train set:', X_train.shape,  y_train.shape)
print ('Test set:', X_test.shape,  y_test.shape)
y_test.shape[0]
'''
# Out:
# "\n# random split train and test\nfrom sklearn.model_selection import train_test_split\n\nX_train, X_test, y_train, y_test = train_test_split( X_pre[0:182],y_pre[0:182], test_size=0.05,random_state=21)\nprint ('Train set:', X_train.shape,  y_train.shape)\nprint ('Test set:', X_test.shape,  y_test.shape)\ny_test.shape[0]\n"

# %% [markdown]
# # *SVM*

# %%
from sklearn import svm
from sklearn import metrics
from sklearn import model_selection

# %% [markdown]
# ## Hyperparameter tuning

# %%
from sklearn.model_selection import StratifiedKFold
from sklearn.model_selection import GridSearchCV

# For an initial search, a logarithmic grid with basis
# 10 is often helpful. Using a basis of 2, a finer
# tuning can be achieved but at a much higher cost.
C_range = 10. ** np.arange(-1, 5)
gamma_range = 10. ** np.arange(-1, 2)
param_grid = dict(gamma=gamma_range, C=C_range)

X=X_train
y=y_train

grid = GridSearchCV(svm.SVR(kernel='rbf'), param_grid=param_grid, refit=True, verbose=3)
grid.fit(X, y)
print("The best classifier is: ", grid.best_estimator_)
# Out:
# Fitting 5 folds for each of 18 candidates, totalling 90 fits
# [CV] C=0.1, gamma=0.1 ................................................
# [CV] ................... C=0.1, gamma=0.1, score=-9.900, total=   0.0s
# [CV] C=0.1, gamma=0.1 ................................................
# [CV] .................... C=0.1, gamma=0.1, score=0.866, total=   0.0s
# [CV] C=0.1, gamma=0.1 ................................................
# [CV] .................... C=0.1, gamma=0.1, score=0.558, total=   0.0s
# [CV] C=0.1, gamma=0.1 ................................................
# [CV] .................... C=0.1, gamma=0.1, score=0.878, total=   0.0s
# [CV] C=0.1, gamma=0.1 ................................................
# [CV] .................. C=0.1, gamma=0.1, score=-50.309, total=   0.0s
# [CV] C=0.1, gamma=1.0 ................................................
# [CV] .................. C=0.1, gamma=1.0, score=-12.469, total=   0.0s
# [CV] C=0.1, gamma=1.0 ................................................
# [CV] ................... C=0.1, gamma=1.0, score=-2.270, total=   0.0s
# [CV] C=0.1, gamma=1.0 ................................................
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    0.0s remaining:    0.0s
# [CV] ................... C=0.1, gamma=1.0, score=-0.780, total=   0.0s
# [CV] C=0.1, gamma=1.0 ................................................
# [CV] ................... C=0.1, gamma=1.0, score=-2.093, total=   0.0s
# [CV] C=0.1, gamma=1.0 ................................................
# [CV] ................. C=0.1, gamma=1.0, score=-567.704, total=   0.0s
# [CV] C=0.1, gamma=10.0 ...............................................
# [CV] ................. C=0.1, gamma=10.0, score=-14.061, total=   0.0s
# [CV] C=0.1, gamma=10.0 ...............................................
# [CV] .................. C=0.1, gamma=10.0, score=-6.788, total=   0.1s
# [CV] C=0.1, gamma=10.0 ...............................................
# [CV] ................. C=0.1, gamma=10.0, score=-65.335, total=   0.1s
# [CV] C=0.1, gamma=10.0 ...............................................
# [CV] ................ C=0.1, gamma=10.0, score=-230.961, total=   0.0s
# [CV] C=0.1, gamma=10.0 ...............................................
# [CV] ............... C=0.1, gamma=10.0, score=-1568.368, total=   0.0s
# [CV] C=1.0, gamma=0.1 ................................................
# [CV] ................... C=1.0, gamma=0.1, score=-9.647, total=   0.0s
# [CV] C=1.0, gamma=0.1 ................................................
# [CV] .................... C=1.0, gamma=0.1, score=0.882, total=   0.0s
# [CV] C=1.0, gamma=0.1 ................................................
# [CV] .................... C=1.0, gamma=0.1, score=0.576, total=   0.0s
# [CV] C=1.0, gamma=0.1 ................................................
# [CV] .................... C=1.0, gamma=0.1, score=0.900, total=   0.0s
# [CV] C=1.0, gamma=0.1 ................................................
# [CV] .................. C=1.0, gamma=0.1, score=-42.201, total=   0.0s
# [CV] C=1.0, gamma=1.0 ................................................
# [CV] .................. C=1.0, gamma=1.0, score=-12.329, total=   0.0s
# [CV] C=1.0, gamma=1.0 ................................................
# [CV] ................... C=1.0, gamma=1.0, score=-2.475, total=   0.0s
# [CV] C=1.0, gamma=1.0 ................................................
# [CV] ................... C=1.0, gamma=1.0, score=-0.556, total=   0.0s
# [CV] C=1.0, gamma=1.0 ................................................
# [CV] ................... C=1.0, gamma=1.0, score=-1.029, total=   0.0s
# [CV] C=1.0, gamma=1.0 ................................................
# [CV] ................. C=1.0, gamma=1.0, score=-523.996, total=   0.0s
# [CV] C=1.0, gamma=10.0 ...............................................
# [CV] ................. C=1.0, gamma=10.0, score=-13.877, total=   0.0s
# [CV] C=1.0, gamma=10.0 ...............................................
# [CV] ................. C=1.0, gamma=10.0, score=-15.535, total=   0.0s
# [CV] C=1.0, gamma=10.0 ...............................................
# [CV] ................. C=1.0, gamma=10.0, score=-98.061, total=   0.0s
# [CV] C=1.0, gamma=10.0 ...............................................
# [CV] ................ C=1.0, gamma=10.0, score=-276.019, total=   0.1s
# [CV] C=1.0, gamma=10.0 ...............................................
# [CV] ............... C=1.0, gamma=10.0, score=-1999.479, total=   0.0s
# [CV] C=10.0, gamma=0.1 ...............................................
# [CV] .................. C=10.0, gamma=0.1, score=-9.630, total=   0.0s
# [CV] C=10.0, gamma=0.1 ...............................................
# [CV] ................... C=10.0, gamma=0.1, score=0.881, total=   0.0s
# [CV] C=10.0, gamma=0.1 ...............................................
# [CV] ................... C=10.0, gamma=0.1, score=0.576, total=   0.0s
# [CV] C=10.0, gamma=0.1 ...............................................
# [CV] ................... C=10.0, gamma=0.1, score=0.900, total=   0.0s
# [CV] C=10.0, gamma=0.1 ...............................................
# [CV] ................. C=10.0, gamma=0.1, score=-42.323, total=   0.0s
# [CV] C=10.0, gamma=1.0 ...............................................
# [CV] ................. C=10.0, gamma=1.0, score=-12.329, total=   0.0s
# [CV] C=10.0, gamma=1.0 ...............................................
# [CV] .................. C=10.0, gamma=1.0, score=-2.447, total=   0.0s
# [CV] C=10.0, gamma=1.0 ...............................................
# [CV] .................. C=10.0, gamma=1.0, score=-0.555, total=   0.0s
# [CV] C=10.0, gamma=1.0 ...............................................
# [CV] .................. C=10.0, gamma=1.0, score=-0.781, total=   0.0s
# [CV] C=10.0, gamma=1.0 ...............................................
# [CV] ................ C=10.0, gamma=1.0, score=-503.910, total=   0.0s
# [CV] C=10.0, gamma=10.0 ..............................................
# [CV] ................ C=10.0, gamma=10.0, score=-13.877, total=   0.0s
# [CV] C=10.0, gamma=10.0 ..............................................
# [CV] ................ C=10.0, gamma=10.0, score=-15.373, total=   0.1s
# [CV] C=10.0, gamma=10.0 ..............................................
# [CV] ................ C=10.0, gamma=10.0, score=-96.763, total=   0.1s
# [CV] C=10.0, gamma=10.0 ..............................................
# [CV] ............... C=10.0, gamma=10.0, score=-271.053, total=   0.1s
# [CV] C=10.0, gamma=10.0 ..............................................
# [CV] .............. C=10.0, gamma=10.0, score=-1964.097, total=   0.0s
# [CV] C=100.0, gamma=0.1 ..............................................
# [CV] ................. C=100.0, gamma=0.1, score=-9.630, total=   0.0s
# [CV] C=100.0, gamma=0.1 ..............................................
# [CV] .................. C=100.0, gamma=0.1, score=0.881, total=   0.0s
# [CV] C=100.0, gamma=0.1 ..............................................
# [CV] .................. C=100.0, gamma=0.1, score=0.576, total=   0.0s
# [CV] C=100.0, gamma=0.1 ..............................................
# [CV] .................. C=100.0, gamma=0.1, score=0.900, total=   0.0s
# [CV] C=100.0, gamma=0.1 ..............................................
# [CV] ................ C=100.0, gamma=0.1, score=-42.323, total=   0.0s
# [CV] C=100.0, gamma=1.0 ..............................................
# [CV] ................ C=100.0, gamma=1.0, score=-12.329, total=   0.0s
# [CV] C=100.0, gamma=1.0 ..............................................
# [CV] ................. C=100.0, gamma=1.0, score=-2.447, total=   0.0s
# [CV] C=100.0, gamma=1.0 ..............................................
# [CV] ................. C=100.0, gamma=1.0, score=-0.555, total=   0.0s
# [CV] C=100.0, gamma=1.0 ..............................................
# [CV] ................. C=100.0, gamma=1.0, score=-0.781, total=   0.0s
# [CV] C=100.0, gamma=1.0 ..............................................
# [CV] ............... C=100.0, gamma=1.0, score=-503.910, total=   0.0s
# [CV] C=100.0, gamma=10.0 .............................................
# [CV] ............... C=100.0, gamma=10.0, score=-13.877, total=   0.0s
# [CV] C=100.0, gamma=10.0 .............................................
# [CV] ............... C=100.0, gamma=10.0, score=-15.373, total=   0.1s
# [CV] C=100.0, gamma=10.0 .............................................
# [CV] ............... C=100.0, gamma=10.0, score=-96.763, total=   0.1s
# [CV] C=100.0, gamma=10.0 .............................................
# [CV] .............. C=100.0, gamma=10.0, score=-271.053, total=   0.1s
# [CV] C=100.0, gamma=10.0 .............................................
# [CV] ............. C=100.0, gamma=10.0, score=-1964.097, total=   0.0s
# [CV] C=1000.0, gamma=0.1 .............................................
# [CV] ................ C=1000.0, gamma=0.1, score=-9.630, total=   0.0s
# [CV] C=1000.0, gamma=0.1 .............................................
# [CV] ................. C=1000.0, gamma=0.1, score=0.881, total=   0.0s
# [CV] C=1000.0, gamma=0.1 .............................................
# [CV] ................. C=1000.0, gamma=0.1, score=0.576, total=   0.0s
# [CV] C=1000.0, gamma=0.1 .............................................
# [CV] ................. C=1000.0, gamma=0.1, score=0.900, total=   0.0s
# [CV] C=1000.0, gamma=0.1 .............................................
# [CV] ............... C=1000.0, gamma=0.1, score=-42.323, total=   0.0s
# [CV] C=1000.0, gamma=1.0 .............................................
# [CV] ............... C=1000.0, gamma=1.0, score=-12.329, total=   0.0s
# [CV] C=1000.0, gamma=1.0 .............................................
# [CV] ................ C=1000.0, gamma=1.0, score=-2.447, total=   0.0s
# [CV] C=1000.0, gamma=1.0 .............................................
# [CV] ................ C=1000.0, gamma=1.0, score=-0.555, total=   0.0s
# [CV] C=1000.0, gamma=1.0 .............................................
# [CV] ................ C=1000.0, gamma=1.0, score=-0.781, total=   0.0s
# [CV] C=1000.0, gamma=1.0 .............................................
# [CV] .............. C=1000.0, gamma=1.0, score=-503.910, total=   0.0s
# [CV] C=1000.0, gamma=10.0 ............................................
# [CV] .............. C=1000.0, gamma=10.0, score=-13.877, total=   0.0s
# [CV] C=1000.0, gamma=10.0 ............................................
# [CV] .............. C=1000.0, gamma=10.0, score=-15.373, total=   0.0s
# [CV] C=1000.0, gamma=10.0 ............................................
# [CV] .............. C=1000.0, gamma=10.0, score=-96.763, total=   0.1s
# [CV] C=1000.0, gamma=10.0 ............................................
# [CV] ............. C=1000.0, gamma=10.0, score=-271.053, total=   0.1s
# [CV] C=1000.0, gamma=10.0 ............................................
# [CV] ............ C=1000.0, gamma=10.0, score=-1964.097, total=   0.0s
# [CV] C=10000.0, gamma=0.1 ............................................
# [CV] ............... C=10000.0, gamma=0.1, score=-9.630, total=   0.0s
# [CV] C=10000.0, gamma=0.1 ............................................
# [CV] ................ C=10000.0, gamma=0.1, score=0.881, total=   0.0s
# [CV] C=10000.0, gamma=0.1 ............................................
# [CV] ................ C=10000.0, gamma=0.1, score=0.576, total=   0.0s
# [CV] C=10000.0, gamma=0.1 ............................................
# [CV] ................ C=10000.0, gamma=0.1, score=0.900, total=   0.0s
# [CV] C=10000.0, gamma=0.1 ............................................
# [CV] .............. C=10000.0, gamma=0.1, score=-42.323, total=   0.0s
# [CV] C=10000.0, gamma=1.0 ............................................
# [CV] .............. C=10000.0, gamma=1.0, score=-12.329, total=   0.0s
# [CV] C=10000.0, gamma=1.0 ............................................
# [CV] ............... C=10000.0, gamma=1.0, score=-2.447, total=   0.0s
# [CV] C=10000.0, gamma=1.0 ............................................
# [CV] ............... C=10000.0, gamma=1.0, score=-0.555, total=   0.0s
# [CV] C=10000.0, gamma=1.0 ............................................
# [CV] ............... C=10000.0, gamma=1.0, score=-0.781, total=   0.1s
# [CV] C=10000.0, gamma=1.0 ............................................
# [CV] ............. C=10000.0, gamma=1.0, score=-503.910, total=   0.0s
# [CV] C=10000.0, gamma=10.0 ...........................................
# [CV] ............. C=10000.0, gamma=10.0, score=-13.877, total=   0.0s
# [CV] C=10000.0, gamma=10.0 ...........................................
# [CV] ............. C=10000.0, gamma=10.0, score=-15.373, total=   0.1s
# [CV] C=10000.0, gamma=10.0 ...........................................
# [CV] ............. C=10000.0, gamma=10.0, score=-96.763, total=   0.1s
# [CV] C=10000.0, gamma=10.0 ...........................................
# [CV] ............ C=10000.0, gamma=10.0, score=-271.053, total=   0.1s
# [CV] C=10000.0, gamma=10.0 ...........................................
# [CV] ........... C=10000.0, gamma=10.0, score=-1964.097, total=   0.1s
# The best classifier is:  SVR(C=1.0, cache_size=200, coef0=0.0, degree=3, epsilon=0.1, gamma=0.1,
#     kernel='rbf', max_iter=-1, shrinking=True, tol=0.001, verbose=False)
# [Parallel(n_jobs=1)]: Done  90 out of  90 | elapsed:    2.7s finished

# %% [markdown]
# Set the models

# %%
'''
# Parameters for best fit
svr_rbf = svm.SVR(kernel='rbf', C=100, gamma=0.0029, epsilon=0.1)
svr_lin = svm.SVR(kernel='linear', C=18, gamma=0.01, epsilon=0.1)
svr_poly = svm.SVR(kernel='poly',gamma=1, degree=3, epsilon=.1,
               coef0=1)

clf=svr_poly.fit(X_train, y_train)
print(clf.score(X_test,y_test))

'''
# print("DecisionTrees's Accuracy: ", metrics.accuracy_score(y_test, y_hat))
# Out:
# 0.9511294851312608

# %%
# Parameters 
svr_rbf = svm.SVR(kernel='rbf', C=4, gamma=0.002, epsilon=0.0001)
svr_lin = svm.SVR(kernel='linear', C=0.023, gamma=0.01, epsilon=0.0001)
svr_poly = svm.SVR(kernel='poly',gamma=0.006, degree=2, epsilon=.0001,
               coef0=3)

clf=svr_rbf.fit(X_train, y_train)
print(clf.score(X_test,y_test))
# Out:
# 0.9506770274946993

# %%
def cross_valuations(svr_, Xdata, ydata, nsplit, s1, l1, s2, l2, s3, l3):
    
    kfold = model_selection.KFold(n_splits=nsplit, random_state=21, shuffle=True)
    
    scores = [s1, s2, s3]
    labels = [l1, l2, l3]
    
    for ix, score in enumerate(scores):
        results = model_selection.cross_val_score(svr_, Xdata, ydata, cv=kfold, scoring=scores[ix])
        print("SVR", svr_.kernel,labels[ix],format(results.mean(),'.4f'), format(results.std(),'.4f'))
    print('\n')

# %% [markdown]
# Evaluate different algorithms

# %%
'''
svrs = [svr_rbf, svr_lin, svr_poly]
for i in range(len(svrs)):
    cross_valuations(svrs[i],
                 X_train,
                 y_train,
                 7,
                 "neg_mean_absolute_error", "MAE:",
                 "neg_root_mean_squared_error", "RMSE:",
                 "r2", "R^2:"
                 )
'''
# Out:
# '\nsvrs = [svr_rbf, svr_lin, svr_poly]\nfor i in range(len(svrs)):\n    cross_valuations(svrs[i],\n                 X_train,\n                 y_train,\n                 7,\n                 "neg_mean_absolute_error", "MAE:",\n                 "neg_root_mean_squared_error", "RMSE:",\n                 "r2", "R^2:"\n                 )\n'

# %%
def three_svr_plot(svr1, label1, svr2, label2, svr3, label3, trainx, trainy, testx, testy, labelx, labely, ftitle):
    # Look at the results
    lw = 2
    
    svrs = [svr1, svr2, svr3]
    kernel_label = [label1, label2, label3]
    model_color = ['b', 'c', 'g']
    
    fig, axes = plt.subplots(nrows=1, ncols=3, figsize=(24, 12), sharey=True)
    for ix, svr in enumerate(svrs):
        y_hat=svr.fit(trainx, trainy).predict(testx)

        y_hat=y_hat*y_std+y_mean
     
        MAE=format(metrics.mean_absolute_error(testy, y_hat),'.3f')
        MSE=format(metrics.mean_squared_error(testy, y_hat),'.2f')
        R2=format(metrics.r2_score(testy, y_hat),'.4f')        
        
        axes[ix].plot(y_hat, color=model_color[ix], lw=lw,
                      label='{} (MAE: {},  R^2: {})'.format(kernel_label[ix], MAE, R2))
        axes[ix].plot(testy.reset_index(drop=True), color='red', linestyle=':', lw=3,
                      label='Test data')                    
        axes[ix].legend(loc='upper center', bbox_to_anchor=(0.5, 1.1),
                        ncol=1, fancybox=False, shadow=False, fontsize=14)
    fig.text(0.5, 0.04, labelx, ha='center', va='center', fontsize=12)
    fig.text(0.06, 0.5, labely, ha='center', va='center', rotation='vertical', fontsize=12)
    fig.suptitle(ftitle, fontsize=16)
    plt.show()

# %%
three_svr_plot(svr_rbf, "SVR-RBF",
               svr_lin, "SVR-Linear",
               svr_poly, "SVR-Poly",
               X_train,
               y_train,
               X_test,
               y_test,
               "Day",
               "Pressure",
               "Support Vector Regression-Pressure")

# %% [markdown]
# ## Predict Holdup

# %%
hol_svr_rbf = svm.SVR(kernel='rbf', C=20, gamma=0.001, epsilon=0.0001)
hol_svr_lin = svm.SVR(kernel='linear', C=1, gamma=0.006, epsilon=0.0001)
hol_svr_poly = svm.SVR(kernel='poly',gamma=0.01, degree=2, epsilon=.00001,
               coef0=0.3)


clf2=hol_svr_poly.fit(X_hol_train, y_hol_train)
print(clf2.score(X_hol_test,y_hol_test))
# Out:
# 0.9845689592782063

# %%
svrs = [hol_svr_rbf, hol_svr_lin, hol_svr_poly]
for i in range(len(svrs)):
    cross_valuations(svrs[i],
                 X_hol_train,
                 y_hol_train,
                 10,
                 "neg_mean_absolute_error", "MAE:",
                 "neg_root_mean_squared_error", "RMSE:",
                 "r2", "R^2:"
                 )
# Out:
# SVR rbf MAE: -0.0004 0.0001
# SVR rbf RMSE: -0.0006 0.0002
# SVR rbf R^2: 0.9998 0.0002
#
#
# SVR linear MAE: -0.0006 0.0001
# SVR linear RMSE: -0.0009 0.0002
# SVR linear R^2: 0.9996 0.0001
#
#
# SVR poly MAE: -0.0003 0.0001
# SVR poly RMSE: -0.0006 0.0002
# SVR poly R^2: 0.9998 0.0001

# %%
def three_hol_plot(svr1, label1, svr2, label2, svr3, label3, trainx, trainy, testx, testy, labelx, labely, ftitle):
    # Look at the results
    lw = 2
    
    svrs = [svr1, svr2, svr3]
    kernel_label = [label1, label2, label3]
    model_color = ['b', 'c', 'g']
    
    fig, axes = plt.subplots(nrows=1, ncols=3, figsize=(24, 12), sharey=True)
    for ix, svr in enumerate(svrs):
        y_hat=svr.fit(trainx, trainy).predict(testx)

        MAE=format(metrics.mean_absolute_error(testy, y_hat),'.3f')
        MSE=format(metrics.mean_squared_error(testy, y_hat),'.2f')
        R2=format(metrics.r2_score(testy, y_hat),'.4f')        
        
        axes[ix].plot(y_hat, color=model_color[ix], lw=lw,
                      label='{} (MAE: {},  R^2: {})'.format(kernel_label[ix], MAE, R2))
        axes[ix].plot(testy.reset_index(drop=True), color='red', linestyle=':', lw=3,
                      label='Test data')                    
        axes[ix].legend(loc='upper center', bbox_to_anchor=(0.5, 1.1),
                        ncol=1, fancybox=False, shadow=False, fontsize=14)
    fig.text(0.5, 0.04, labelx, ha='center', va='center', fontsize=12)
    fig.text(0.06, 0.5, labely, ha='center', va='center', rotation='vertical', fontsize=12)
    fig.suptitle(ftitle, fontsize=16)
    plt.show()

# %%
three_hol_plot(hol_svr_rbf, "SVR-RBF",
               hol_svr_lin, "SVR-Linear",
               hol_svr_poly, "SVR-Poly",
               X_hol_train,
               y_hol_train,
               X_hol_test,
               y_hol_test,
               "Day",
               "Liquid Holdup",
               "Support Vector Regression-Holdup")

# %%
def comp_plot(ml1, label1, trainx, trainy, testx, testy, labelx, labely, ftitle):
    # Look at the results
    lw = 2
    
    fig= plt.figure(figsize=(12, 10))
   
    y_hat=ml1.fit(trainx, trainy).predict(testx)

    y_hat=y_hat*y_std+y_mean
        
    MAE=format(metrics.mean_absolute_error(testy, y_hat),'.3f')
    MSE=format(metrics.mean_squared_error(testy, y_hat),'.2f')
    R2=format(metrics.r2_score(testy, y_hat),'.4f')        
        
    plt.plot(y_hat, color='blue', lw=lw,
                      label='{} (MAE: {},  R^2: {})'.format(label1, MAE, R2))
    plt.plot(testy.reset_index(drop=True), color='red', linestyle=':', lw=3,
                      label='Test data')                    
    plt.legend(loc='upper center',bbox_to_anchor=(0.5, 1.1),fontsize=12)
    plt.xlabel(labelx, fontsize=12)
    plt.ylabel(labely, fontsize=12)
    fig.suptitle(ftitle, fontsize=16)
    plt.show()

# %% [markdown]
# ## Model evaluation modules

# %%
# model evaluation
from sklearn.metrics import r2_score, mean_squared_error
from sklearn.model_selection import KFold
from sklearn.model_selection import cross_val_score
from sklearn.metrics import mean_squared_error

from sklearn.model_selection import GridSearchCV

# %% [markdown]
# ## Ridge, Lasso, Linear Regression

# %%
from sklearn.linear_model import LinearRegression, Ridge, Lasso, SGDRegressor

# %%
rreg = Ridge(alpha=1.0, copy_X=True, fit_intercept=True,
                             max_iter=None, normalize=False, random_state=None,
                             solver='auto', tol=0.001)
lareg= Lasso(alpha=0.02)
linreg=LinearRegression()


kfold = KFold(n_splits=10, random_state=7, shuffle=True)
results = cross_val_score(rreg, X_train, y_train, cv=kfold)
print("Cross Val Accuracy: %.2f%% (%.2f%%)" % (results.mean()*100, results.std()*100))


linreg.fit(X_train, y_train)
y_pred =linreg.predict(X_test)
y_pred=y_pred*y_std+y_mean


MAE=format(metrics.mean_absolute_error(y_test, y_pred),'.3f')
MSE=format(metrics.mean_squared_error(y_test, y_pred),'.2f')
R2=format(metrics.r2_score(y_test, y_pred),'.4f')       


# print('RMSE: %.4f' % lin_rmse)
print('MAE:', MAE)
print('MSE:', MSE)
print('R2:',  R2)
# Out:
# Cross Val Accuracy: 99.99% (0.01%)
# MAE: 9.546
# MSE: 131.40
# R2: 0.7862

# %%
type(y_pred)
# Out:
# numpy.ndarray

# %%
def cross_valuations2(svr_, Xdata, ydata, nsplit, s1, l1, s2, l2, s3, l3):
    
    kfold = model_selection.KFold(n_splits=nsplit, random_state=21, shuffle=True)
    
    scores = [s1, s2, s3]
    labels = [l1, l2, l3]
    
    for ix, score in enumerate(scores):
        results = model_selection.cross_val_score(svr_, Xdata, ydata, cv=kfold, scoring=scores[ix])
        print(str(svr_)[0:5],labels[ix],format(results.mean(),'.4f'), format(results.std(),'.4f'))
    print('\n')

# %%
linregs = [rreg, lareg, linreg]
for i in range(len(linregs)):
    cross_valuations2(linregs[i],
                 X_train,
                 y_train,
                 7,
                 "neg_mean_absolute_error", "MAE:",
                 "neg_root_mean_squared_error", "RMSE:",
                 "r2", "R^2:"
                 )
# Out:
# Ridge MAE: -0.0079 0.0005
# Ridge RMSE: -0.0117 0.0031
# Ridge R^2: 0.9999 0.0001
#
#
# Lasso MAE: -0.0281 0.0018
# Lasso RMSE: -0.0373 0.0056
# Lasso R^2: 0.9986 0.0005
#
#
# Linea MAE: -0.0027 0.0002
# Linea RMSE: -0.0049 0.0027
# Linea R^2: 1.0000 0.0000

# %%
three_svr_plot(rreg, "Ridge",
               lareg, "Lasso",
               linreg, "Least Sqr",
               X_train,
               y_train,
               X_test,
               y_test,
               "Day",
               "Pressure",
               "Linear Regression-Pressure")

# %% [markdown]
# ## Grid search parameter

# %%
alphas = np.array([1,0.1,0.01,0.001,0.0001,0.00001])
# create and fit a ridge regression model, testing each alpha
model = Ridge()
grid = GridSearchCV(estimator=model, param_grid=dict(alpha=alphas))
grid.fit(X_train, y_train)
print(grid)
# summarize the results of the grid search
print(grid.best_score_)
print(grid.best_estimator_.alpha)
# Out:
# GridSearchCV(cv=None, error_score=nan,
#              estimator=Ridge(alpha=1.0, copy_X=True, fit_intercept=True,
#                              max_iter=None, normalize=False, random_state=None,
#                              solver='auto', tol=0.001),
#              iid='deprecated', n_jobs=None,
#              param_grid={'alpha': array([1.e+00, 1.e-01, 1.e-02, 1.e-03, 1.e-04, 1.e-05])},
#              pre_dispatch='2*n_jobs', refit=True, return_train_score=False,
#              scoring=None, verbose=0)
# 0.9557372437326729
# 0.001

# %% [markdown]
# ## Random search paramter

# %%
from sklearn.model_selection import RandomizedSearchCV
from scipy.stats import uniform as sp_rand
# load the diabetes datasets

param_grid = {'alpha': sp_rand()}
# create and fit a ridge regression model, testing random alpha values
model = Ridge()
rsearch = RandomizedSearchCV(estimator=model, param_distributions=param_grid, n_iter=100)
rsearch.fit(X_test, y_test)
print(rsearch)
# summarize the results of the random parameter search
print(rsearch.best_score_)
print(rsearch.best_estimator_.alpha)
# Out:
# RandomizedSearchCV(cv=None, error_score=nan,
#                    estimator=Ridge(alpha=1.0, copy_X=True, fit_intercept=True,
#                                    max_iter=None, normalize=False,
#                                    random_state=None, solver='auto',
#                                    tol=0.001),
#                    iid='deprecated', n_iter=100, n_jobs=None,
#                    param_distributions={'alpha': <scipy.stats._distn_infrastructure.rv_frozen object at 0x00000253BE757C88>},
#                    pre_dispatch='2*n_jobs', random_state=None, refit=True,
#                    return_train_score=False, scoring=None, verbose=0)
# 0.7584333556543621
# 0.005809043051333229

# %% [markdown]
# ## SGD Regression

# %%
alphas = np.array([0.1,1,2,5,10,100,1000,10000])
l1_ratios=np.array([0,0.2,0.5,0.7,1])
epsilons=np.array([0.1,0.01,0.001])
power_ts=np.array([0.1,0.25,0.5,1,2])

params=dict(alpha=alphas)

# create and fit a ridge regression model, testing each alpha
model = SGDRegressor()
grid = GridSearchCV(estimator=model, param_grid=params)
grid.fit(X_train, y_train)
print(grid)
# summarize the results of the grid search
print(grid.best_score_)
print(grid.best_estimator_.alpha)
# Out:
# GridSearchCV(cv=None, error_score=nan,
#              estimator=SGDRegressor(alpha=0.0001, average=False,
#                                     early_stopping=False, epsilon=0.1,
#                                     eta0=0.01, fit_intercept=True,
#                                     l1_ratio=0.15, learning_rate='invscaling',
#                                     loss='squared_loss', max_iter=1000,
#                                     n_iter_no_change=5, penalty='l2',
#                                     power_t=0.25, random_state=None,
#                                     shuffle=True, tol=0.001,
#                                     validation_fraction=0.1, verbose=0,
#                                     warm_start=False),
#              iid='deprecated', n_jobs=None,
#              param_grid={'alpha': array([1.e-01, 1.e+00, 2.e+00, 5.e+00, 1.e+01, 1.e+02, 1.e+03, 1.e+04])},
#              pre_dispatch='2*n_jobs', refit=True, return_train_score=False,
#              scoring=None, verbose=0)
# 0.8388408475736263
# 0.1

# %%
sgdreg=SGDRegressor(alpha=0.0001, average=False,
                                    early_stopping=False, epsilon=0.1,
                                    eta0=0.01, fit_intercept=True,
                                    l1_ratio=0.15, learning_rate='invscaling',
                                    loss='squared_loss', max_iter=1000,
                                    n_iter_no_change=5, penalty='l2',
                                    power_t=0.25, random_state=None,
                                    shuffle=True, tol=0.001,
                                    validation_fraction=0.1, verbose=0,
                                    warm_start=False)

# %%
comp_plot(sgdreg, "SGD",
          X_train,
          y_train,
          X_test,
          y_test,
          "Week",
          "Pressure",
          "SGD Regression")

# %%
from sklearn.model_selection import RandomizedSearchCV
from scipy.stats import uniform as sp_rand
# load the diabetes datasets
'''
param_grid = {'alpha': sp_rand()}
# create and fit a ridge regression model, testing random alpha values
model = SGDRegressor()
rsearch = RandomizedSearchCV(estimator=model, param_distributions=param_grid, n_iter=100)
rsearch.fit(X_test, y_test)
print(rsearch)
# summarize the results of the random parameter search
print(rsearch.best_score_)
print(rsearch.best_estimator_.alpha)
'''
# Out:
# "\nparam_grid = {'alpha': sp_rand()}\n# create and fit a ridge regression model, testing random alpha values\nmodel = SGDRegressor()\nrsearch = RandomizedSearchCV(estimator=model, param_distributions=param_grid, n_iter=100)\nrsearch.fit(X_test, y_test)\nprint(rsearch)\n# summarize the results of the random parameter search\nprint(rsearch.best_score_)\nprint(rsearch.best_estimator_.alpha)\n"

# %% [markdown]
# # Gradient Boost

# %%
from sklearn.ensemble import GradientBoostingRegressor



params = {'n_estimators': 1000, 'max_depth': 4, 'min_samples_split': 2,
          'learning_rate': 0.01, 'loss': 'ls'}
gbrt= GradientBoostingRegressor(**params)


kfold = KFold(n_splits=10, random_state=7, shuffle=True)
results = cross_val_score(gbrt, X_train, y_train, cv=kfold)
print("Cross Val Accuracy: %.2f%% (%.2f%%)" % (results.mean()*100, results.std()*100))


gbrt.fit(X_train, y_train)
y_pred = gbrt.predict(X_test)

y_pred=y_pred*y_std+y_mean

MAE=format(metrics.mean_absolute_error(y_test, y_pred),'.3f')
MSE=format(metrics.mean_squared_error(y_test, y_pred),'.2f')
R2=format(metrics.r2_score(y_test, y_pred),'.4f')       

lin_mse = mean_squared_error(y_pred, y_test)
lin_rmse = np.sqrt(lin_mse)
print('RMSE: %.4f' % lin_rmse)
print('MAE:', MAE)
print('MSE:', MSE)
print('R2:',  R2)
# Out:
# Cross Val Accuracy: 99.99% (0.01%)
# RMSE: 53.3519
# MAE: 46.944
# MSE: 2846.43
# R2: -3.6303

# %% [markdown]
# ## GB

# %%
comp_plot(gbrt, "GBRT",
          X_train,
          y_train,
          X_test,
          y_test,
          "Week",
          "Pressure",
          "Gradient Boost")

# %% [markdown]
# # Random Forest

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
params = {'n_estimators': 100, 'max_depth': 30, 'random_state': 0,}

RFR = RandomForestRegressor(**params)

# %%
estimators = np.arange(10, 200, 10)
scores = []
for n in estimators:
    RFR.set_params(n_estimators=n)
    RFR.fit(X_train, y_train)
    scores.append(RFR.score(X_test, y_test))
fig= plt.figure(figsize=(8, 6))
plt.xlabel("n_estimator",fontsize=12)
plt.ylabel("score",fontsize=12)
fig.suptitle("Effect of n_estimators", fontsize=16)
plt.plot(estimators, scores)
plt.show()

# %%
comp_plot(RFR, "RFR",
          X_train,
          y_train,
          X_test,
          y_test,
          "Week",
          "Pressure",
          "Random Forest")

# %% [markdown]
# # XGBoost

# %%
import xgboost as xgb
from sklearn.metrics import auc, accuracy_score, confusion_matrix, mean_squared_error

# %%
params={'colsample_bytree': 0.8167605036202489, 'gamma': 0.000541882574014918, 'learning_rate': 0.3016145929257791, 'max_depth': 5, 'n_estimators': 108, 'subsample': 0.7277254550361659}

xgbr = xgb.XGBRegressor(**params)

xgbr.fit(X_train, y_train)

y_pred = xgbr.predict(X_test)
y_pred=y_pred*y_std+y_mean
MAE=format(metrics.mean_absolute_error(y_test, y_pred),'.3f')
MSE=format(metrics.mean_squared_error(y_test, y_pred),'.2f')
R2=format(metrics.r2_score(y_test, y_pred),'.4f')       

lin_mse = mean_squared_error(y_pred, y_test)
lin_rmse = np.sqrt(lin_mse)
print('RMSE: %.4f' % lin_rmse)
print('MAE:', MAE)
print('MSE:', MSE)
print('R2:',  R2)
# Out:
# C:\Users\xuesong.wang1\AppData\Local\Programs\Python\Python37\lib\site-packages\xgboost\core.py:587: FutureWarning: Series.base is deprecated and will be removed in a future version
#   if getattr(data, 'base', None) is not None and \
# [20:52:52] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# RMSE: 55.2934
# MAE: 49.283
# MSE: 3057.36
# R2: -3.9734

# %%
comp_plot(xgbr, "XGBoost",
          X_train,
          y_train,
          X_test,
          y_test,
          "Week",
          "Pressure",
          "XGBoost")
# Out:
# C:\Users\xuesong.wang1\AppData\Local\Programs\Python\Python37\lib\site-packages\xgboost\core.py:587: FutureWarning: Series.base is deprecated and will be removed in a future version
#   if getattr(data, 'base', None) is not None and \
# [20:52:55] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.

# %%
def display_scores(scores):
    print("Scores: {0}\nMean: {1:.3f}\nStd: {2:.3f}".format(scores, np.mean(scores), np.std(scores)))

# %%
def report_best_scores(results, n_top=3):
    for i in range(1, n_top + 1):
        candidates = np.flatnonzero(results['rank_test_score'] == i)
        for candidate in candidates:
            print("Model with rank: {0}".format(i))
            print("Mean validation score: {0:.3f} (std: {1:.3f})".format(
                  results['mean_test_score'][candidate],
                  results['std_test_score'][candidate]))
            print("Parameters: {0}".format(results['params'][candidate]))
            print("")

# %%
xgbr.fit(X_train, y_train)

y_pred = xgbr.predict(X_test)
mse=mean_squared_error(y_test, y_pred)

print(np.sqrt(mse))
# Out:
# C:\Users\xuesong.wang1\AppData\Local\Programs\Python\Python37\lib\site-packages\xgboost\core.py:587: FutureWarning: Series.base is deprecated and will be removed in a future version
#   if getattr(data, 'base', None) is not None and \
# [20:44:51] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# 174.85255409962167

# %% [markdown]
# Hyperparameter tuning

# %%
from scipy.stats import uniform, randint
'''
# from sklearn.datasets import load_breast_cancer, load_diabetes, load_wine
from sklearn.metrics import auc, accuracy_score, confusion_matrix, mean_squared_error
from sklearn.model_selection import cross_val_score, GridSearchCV, KFold, RandomizedSearchCV, train_test_split

xgb_model = xgb.XGBRegressor()

params = {
    "colsample_bytree": uniform(0.7, 0.3),
    "gamma": uniform(0, 0.5),
    "learning_rate": uniform(0.03, 0.3), # default 0.1 
    "max_depth": randint(2, 6), # default 3
    "n_estimators": randint(100, 150), # default 100
    "subsample": uniform(0.6, 0.4)
}

search = RandomizedSearchCV(xgb_model, param_distributions=params, random_state=42, n_iter=200, cv=3, verbose=1, n_jobs=1, return_train_score=True)

search.fit(X_train, y_train)

report_best_scores(search.cv_results_, 1)
'''
# Out:
#  version
#   if getattr(data, 'base', None) is not None and \
# [20:48:34] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# C:\Users\xuesong.wang1\AppData\Local\Programs\Python\Python37\lib\site-packages\xgboost\core.py:587: FutureWarning: Series.base is deprecated and will be removed in a future version
#   if getattr(data, 'base', None) is not None and \
# [20:48:35] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# C:\Users\xuesong.wang1\AppData\Local\Programs\Python\Python37\lib\site-packages\xgboost\core.py:587: FutureWarning: Series.base is deprecated and will be removed in a future version
#   if getattr(data, 'base', None) is not None and \
# [20:48:35] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# C:\Users\xuesong.wang1\AppData\Local\Programs\Python\Python37\lib\site-packages\xgboost\core.py:587: FutureWarning: Series.base is deprecated and will be removed in a future version
#   if getattr(data, 'base', None) is not None and \
# [20:48:36] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# C:\Users\xuesong.wang1\AppData\Local\Programs\Python\Python37\lib\site-packages\xgboost\core.py:587: FutureWarning: Series.base is deprecated and will be removed in a future version
#   if getattr(data, 'base', None) is not None and \
# [20:48:36] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# C:\Users\xuesong.wang1\AppData\Local\Programs\Python\Python37\lib\site-packages\xgboost\core.py:587: FutureWarning: Series.base is deprecated and will be removed in a future version
#   if getattr(data, 'base', None) is not None and \
# [20:48:37] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# C:\Users\xuesong.wang1\AppData\Local\Programs\Python\Python37\lib\site-packages\xgboost\core.py:587: FutureWarning: Series.base is deprecated and will be removed in a future version
#   if getattr(data, 'base', None) is not None and \
# [20:48:37] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# C:\Users\xuesong.wang1\AppData\Local\Programs\Python\Python37\lib\site-packages\xgboost\core.py:587: FutureWarning: Series.base is deprecated and will be removed in a future version
#   if getattr(data, 'base', None) is not None and \
# [20:48:38] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# C:\Users\xuesong.wang1\AppData\Local\Programs\Python\Python37\lib\site-packages\xgboost\core.py:587: FutureWarning: Series.base is deprecated and will be removed in a future version
#   if getattr(data, 'base', None) is not None and \
# [20:48:38] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# C:\Users\xuesong.wang1\AppData\Local\Programs\Python\Python37\lib\site-packages\xgboost\core.py:587: FutureWarning: Series.base is deprecated and will be removed in a future version
#   if getattr(data, 'base', None) is not None and \
# [20:48:38] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# C:\Users\xuesong.wang1\AppData\Local\Programs\Python\Python37\lib\site-packages\xgboost\core.py:587: FutureWarning: Series.base is deprecated and will be removed in a future version
#   if getattr(data, 'base', None) is not None and \
# [20:48:39] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# C:\Users\xuesong.wang1\AppData\Local\Programs\Python\Python37\lib\site-packages\xgboost\core.py:587: FutureWarning: Series.base is deprecated and will be removed in a future version
#   if getattr(data, 'base', None) is not None and \
# [20:48:39] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# C:\Users\xuesong.wang1\AppData\Local\Programs\Python\Python37\lib\site-packages\xgboost\core.py:587: FutureWarning: Series.base is deprecated and will be removed in a future version
#   if getattr(data, 'base', None) is not None and \
# [20:48:40] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# C:\Users\xuesong.wang1\AppData\Local\Programs\Python\Python37\lib\site-packages\xgboost\core.py:587: FutureWarning: Series.base is deprecated and will be removed in a future version
#   if getattr(data, 'base', None) is not None and \
# [20:48:40] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# C:\Users\xuesong.wang1\AppData\Local\Programs\Python\Python37\lib\site-packages\xgboost\core.py:587: FutureWarning: Series.base is deprecated and will be removed in a future version
#   if getattr(data, 'base', None) is not None and \
# [20:48:41] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# C:\Users\xuesong.wang1\AppData\Local\Programs\Python\Python37\lib\site-packages\xgboost\core.py:587: FutureWarning: Series.base is deprecated and will be removed in a future version
#   if getattr(data, 'base', None) is not None and \
# [20:48:41] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# C:\Users\xuesong.wang1\AppData\Local\Programs\Python\Python37\lib\site-packages\xgboost\core.py:587: FutureWarning: Series.base is deprecated and will be removed in a future version
#   if getattr(data, 'base', None) is not None and \
# [20:48:41] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# C:\Users\xuesong.wang1\AppData\Local\Programs\Python\Python37\lib\site-packages\xgboost\core.py:587: FutureWarning: Series.base is deprecated and will be removed in a future version
#   if getattr(data, 'base', None) is not None and \
# [20:48:42] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# C:\Users\xuesong.wang1\AppData\Local\Programs\Python\Python37\lib\site-packages\xgboost\core.py:587: FutureWarning: Series.base is deprecated and will be removed in a future version
#   if getattr(data, 'base', None) is not None and \
# [20:48:42] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# C:\Users\xuesong.wang1\AppData\Local\Programs\Python\Python37\lib\site-packages\xgboost\core.py:587: FutureWarning: Series.base is deprecated and will be removed in a future version
#   if getattr(data, 'base', None) is not None and \
# [20:48:43] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# C:\Users\xuesong.wang1\AppData\Local\Programs\Python\Python37\lib\site-packages\xgboost\core.py:587: FutureWarning: Series.base is deprecated and will be removed in a future version
#   if getattr(data, 'base', None) is not None and \
# [20:48:43] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# C:\Users\xuesong.wang1\AppData\Local\Programs\Python\Python37\lib\site-packages\xgboost\core.py:587: FutureWarning: Series.base is deprecated and will be removed in a future version
#   if getattr(data, 'base', None) is not None and \
# [20:48:43] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# C:\Users\xuesong.wang1\AppData\Local\Programs\Python\Python37\lib\site-packages\xgboost\core.py:587: FutureWarning: Series.base is deprecated and will be removed in a future version
#   if getattr(data, 'base', None) is not None and \
# [20:48:44] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# C:\Users\xuesong.wang1\AppData\Local\Programs\Python\Python37\lib\site-packages\xgboost\core.py:587: FutureWarning: Series.base is deprecated and will be removed in a future version
#   if getattr(data, 'base', None) is not None and \
# [20:48:44] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# C:\Users\xuesong.wang1\AppData\Local\Programs\Python\Python37\lib\site-packages\xgboost\core.py:587: FutureWarning: Series.base is deprecated and will be removed in a future version
#   if getattr(data, 'base', None) is not None and \
# [20:48:44] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# C:\Users\xuesong.wang1\AppData\Local\Programs\Python\Python37\lib\site-packages\xgboost\core.py:587: FutureWarning: Series.base is deprecated and will be removed in a future version
#   if getattr(data, 'base', None) is not None and \
# [20:48:45] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# C:\Users\xuesong.wang1\AppData\Local\Programs\Python\Python37\lib\site-packages\xgboost\core.py:587: FutureWarning: Series.base is deprecated and will be removed in a future version
#   if getattr(data, 'base', None) is not None and \
# [20:48:45] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# C:\Users\xuesong.wang1\AppData\Local\Programs\Python\Python37\lib\site-packages\xgboost\core.py:587: FutureWarning: Series.base is deprecated and will be removed in a future version
#   if getattr(data, 'base', None) is not None and \
# [20:48:45] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# C:\Users\xuesong.wang1\AppData\Local\Programs\Python\Python37\lib\site-packages\xgboost\core.py:587: FutureWarning: Series.base is deprecated and will be removed in a future version
#   if getattr(data, 'base', None) is not None and \
# [20:48:46] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# C:\Users\xuesong.wang1\AppData\Local\Programs\Python\Python37\lib\site-packages\xgboost\core.py:587: FutureWarning: Series.base is deprecated and will be removed in a future version
#   if getattr(data, 'base', None) is not None and \
# [20:48:46] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# C:\Users\xuesong.wang1\AppData\Local\Programs\Python\Python37\lib\site-packages\xgboost\core.py:587: FutureWarning: Series.base is deprecated and will be removed in a future version
#   if getattr(data, 'base', None) is not None and \
# [20:48:46] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# C:\Users\xuesong.wang1\AppData\Local\Programs\Python\Python37\lib\site-packages\xgboost\core.py:587: FutureWarning: Series.base is deprecated and will be removed in a future version
#   if getattr(data, 'base', None) is not None and \
# [20:48:47] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# C:\Users\xuesong.wang1\AppData\Local\Programs\Python\Python37\lib\site-packages\xgboost\core.py:587: FutureWarning: Series.base is deprecated and will be removed in a future version
#   if getattr(data, 'base', None) is not None and \
# [20:48:47] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# C:\Users\xuesong.wang1\AppData\Local\Programs\Python\Python37\lib\site-packages\xgboost\core.py:587: FutureWarning: Series.base is deprecated and will be removed in a future version
#   if getattr(data, 'base', None) is not None and \
# [20:48:48] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# C:\Users\xuesong.wang1\AppData\Local\Programs\Python\Python37\lib\site-packages\xgboost\core.py:587: FutureWarning: Series.base is deprecated and will be removed in a future version
#   if getattr(data, 'base', None) is not None and \
# [20:48:48] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# C:\Users\xuesong.wang1\AppData\Local\Programs\Python\Python37\lib\site-packages\xgboost\core.py:587: FutureWarning: Series.base is deprecated and will be removed in a future version
#   if getattr(data, 'base', None) is not None and \
# [20:48:48] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# C:\Users\xuesong.wang1\AppData\Local\Programs\Python\Python37\lib\site-packages\xgboost\core.py:587: FutureWarning: Series.base is deprecated and will be removed in a future version
#   if getattr(data, 'base', None) is not None and \
# [20:48:49] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# C:\Users\xuesong.wang1\AppData\Local\Programs\Python\Python37\lib\site-packages\xgboost\core.py:587: FutureWarning: Series.base is deprecated and will be removed in a future version
#   if getattr(data, 'base', None) is not None and \
# [20:48:49] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# C:\Users\xuesong.wang1\AppData\Local\Programs\Python\Python37\lib\site-packages\xgboost\core.py:587: FutureWarning: Series.base is deprecated and will be removed in a future version
#   if getattr(data, 'base', None) is not None and \
# [20:48:49] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# C:\Users\xuesong.wang1\AppData\Local\Programs\Python\Python37\lib\site-packages\xgboost\core.py:587: FutureWarning: Series.base is deprecated and will be removed in a future version
#   if getattr(data, 'base', None) is not None and \
# [20:48:49] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# C:\Users\xuesong.wang1\AppData\Local\Programs\Python\Python37\lib\site-packages\xgboost\core.py:587: FutureWarning: Series.base is deprecated and will be removed in a future version
#   if getattr(data, 'base', None) is not None and \
# [20:48:50] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# C:\Users\xuesong.wang1\AppData\Local\Programs\Python\Python37\lib\site-packages\xgboost\core.py:587: FutureWarning: Series.base is deprecated and will be removed in a future version
#   if getattr(data, 'base', None) is not None and \
# [20:48:50] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# C:\Users\xuesong.wang1\AppData\Local\Programs\Python\Python37\lib\site-packages\xgboost\core.py:587: FutureWarning: Series.base is deprecated and will be removed in a future version
#   if getattr(data, 'base', None) is not None and \
# [20:48:50] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# C:\Users\xuesong.wang1\AppData\Local\Programs\Python\Python37\lib\site-packages\xgboost\core.py:587: FutureWarning: Series.base is deprecated and will be removed in a future version
#   if getattr(data, 'base', None) is not None and \
# [20:48:51] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# C:\Users\xuesong.wang1\AppData\Local\Programs\Python\Python37\lib\site-packages\xgboost\core.py:587: FutureWarning: Series.base is deprecated and will be removed in a future version
#   if getattr(data, 'base', None) is not None and \
# [20:48:51] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# C:\Users\xuesong.wang1\AppData\Local\Programs\Python\Python37\lib\site-packages\xgboost\core.py:587: FutureWarning: Series.base is deprecated and will be removed in a future version
#   if getattr(data, 'base', None) is not None and \
# [20:48:51] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# C:\Users\xuesong.wang1\AppData\Local\Programs\Python\Python37\lib\site-packages\xgboost\core.py:587: FutureWarning: Series.base is deprecated and will be removed in a future version
#   if getattr(data, 'base', None) is not None and \
# [20:48:52] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# C:\Users\xuesong.wang1\AppData\Local\Programs\Python\Python37\lib\site-packages\xgboost\core.py:587: FutureWarning: Series.base is deprecated and will be removed in a future version
#   if getattr(data, 'base', None) is not None and \
# [20:48:52] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# C:\Users\xuesong.wang1\AppData\Local\Programs\Python\Python37\lib\site-packages\xgboost\core.py:587: FutureWarning: Series.base is deprecated and will be removed in a future version
#   if getattr(data, 'base', None) is not None and \
# [20:48:52] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [Parallel(n_jobs=1)]: Done 600 out of 600 | elapsed:  3.7min finished
# C:\Users\xuesong.wang1\AppData\Local\Programs\Python\Python37\lib\site-packages\xgboost\core.py:587: FutureWarning: Series.base is deprecated and will be removed in a future version
#   if getattr(data, 'base', None) is not None and \
# [20:48:53] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# Model with rank: 1
# Mean validation score: -2.308 (std: 1.967)
# Parameters: {'colsample_bytree': 0.8167605036202489, 'gamma': 0.00541882574014918, 'learning_rate': 0.3016145929257791, 'max_depth': 5, 'n_estimators': 108, 'subsample': 0.7277254550361659}

# %% [markdown]
# # Deep Learning

# %% [markdown]
# ## Deep Neural Netowrk

# %%
from keras.callbacks import ModelCheckpoint
from keras.models import Sequential
from keras.layers import Dense, Activation, Flatten, Dropout
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_absolute_error 
from keras.callbacks import EarlyStopping

import seaborn as sb

import warnings 
warnings.filterwarnings('ignore')
warnings.filterwarnings('ignore', category=DeprecationWarning)
# Out:
# Using TensorFlow backend.

# %%
'''
# saved network config
NN_model = Sequential()
NN_model.add(Dense(256,input_dim = X_train.shape[1], activation='relu'))
NN_model.add(Dense(256,activation='relu'))

NN_model.add(Dense(1,activation='relu'))
'''
# Out:
# "\n# saved network config\nNN_model = Sequential()\nNN_model.add(Dense(256,input_dim = X_train.shape[1], activation='relu'))\nNN_model.add(Dense(256,activation='relu'))\n\nNN_model.add(Dense(1,activation='relu'))\n"

# %%
NN_model = Sequential()
NN_model.add(Dense(256,input_dim = X_train.shape[1], activation='relu'))
NN_model.add(Dense(256,activation='relu'))
# NN_model.add(Dropout(0.1))
NN_model.add(Dense(1))

# %%
optimizer1=tf.keras.optimizers.Adam(0.001)
optimizer2=tf.keras.optimizers.RMSprop(0.001)
optimizer2=optimizer1

NN_model.compile(loss='mse', optimizer=optimizer2, metrics=['mean_absolute_error'])
# NN_model.summary()

# %%
# checkpoint_name = 'Weights-{epoch:03d}--{val_loss:.5f}.hdf5' 
checkpoint_name = 'NNv2bestmodel.h5' 
mcp = ModelCheckpoint(checkpoint_name, monitor='val_loss', verbose = 1, save_best_only = True, mode ='auto')

es = EarlyStopping(monitor='val_loss', mode='min', verbose=1, patience=50)

# %%
NN_model.fit(X_train, y_train, epochs=500, batch_size=100, validation_split = 0.2, callbacks=[mcp])
# Out:
# 0448e-05 - mean_absolute_error: 0.0047 - val_loss: 3.0633e-05 - val_mean_absolute_error: 0.0045
#
# Epoch 00414: val_loss did not improve from 0.00002
# Epoch 415/500
# 1612/1612 [==============================] - 0s 28us/step - loss: 5.6043e-05 - mean_absolute_error: 0.0042 - val_loss: 1.0157e-04 - val_mean_absolute_error: 0.0085
#
# Epoch 00415: val_loss did not improve from 0.00002
# Epoch 416/500
# 1612/1612 [==============================] - 0s 25us/step - loss: 3.0732e-05 - mean_absolute_error: 0.0030 - val_loss: 1.4240e-04 - val_mean_absolute_error: 0.0104
#
# Epoch 00416: val_loss did not improve from 0.00002
# Epoch 417/500
# 1612/1612 [==============================] - 0s 32us/step - loss: 3.6998e-05 - mean_absolute_error: 0.0037 - val_loss: 7.9100e-05 - val_mean_absolute_error: 0.0073
#
# Epoch 00417: val_loss did not improve from 0.00002
# Epoch 418/500
# 1612/1612 [==============================] - 0s 35us/step - loss: 2.9917e-05 - mean_absolute_error: 0.0035 - val_loss: 2.7490e-05 - val_mean_absolute_error: 0.0044
#
# Epoch 00418: val_loss did not improve from 0.00002
# Epoch 419/500
# 1612/1612 [==============================] - 0s 37us/step - loss: 3.5037e-05 - mean_absolute_error: 0.0039 - val_loss: 8.4457e-05 - val_mean_absolute_error: 0.0077
#
# Epoch 00419: val_loss did not improve from 0.00002
# Epoch 420/500
# 1612/1612 [==============================] - 0s 27us/step - loss: 3.7655e-05 - mean_absolute_error: 0.0034 - val_loss: 2.2919e-04 - val_mean_absolute_error: 0.0141
#
# Epoch 00420: val_loss did not improve from 0.00002
# Epoch 421/500
# 1612/1612 [==============================] - 0s 21us/step - loss: 4.8510e-05 - mean_absolute_error: 0.0046 - val_loss: 2.1685e-04 - val_mean_absolute_error: 0.0135
#
# Epoch 00421: val_loss did not improve from 0.00002
# Epoch 422/500
# 1612/1612 [==============================] - 0s 21us/step - loss: 3.7254e-05 - mean_absolute_error: 0.0035 - val_loss: 2.1005e-04 - val_mean_absolute_error: 0.0132
#
# Epoch 00422: val_loss did not improve from 0.00002
# Epoch 423/500
# 1612/1612 [==============================] - 0s 26us/step - loss: 4.1488e-05 - mean_absolute_error: 0.0040 - val_loss: 8.9357e-05 - val_mean_absolute_error: 0.0080
#
# Epoch 00423: val_loss did not improve from 0.00002
# Epoch 424/500
# 1612/1612 [==============================] - 0s 29us/step - loss: 2.6831e-05 - mean_absolute_error: 0.0028 - val_loss: 3.4345e-05 - val_mean_absolute_error: 0.0048
#
# Epoch 00424: val_loss did not improve from 0.00002
# Epoch 425/500
# 1612/1612 [==============================] - 0s 27us/step - loss: 3.9424e-05 - mean_absolute_error: 0.0034 - val_loss: 6.2579e-05 - val_mean_absolute_error: 0.0064
#
# Epoch 00425: val_loss did not improve from 0.00002
# Epoch 426/500
# 1612/1612 [==============================] - 0s 26us/step - loss: 4.5834e-05 - mean_absolute_error: 0.0040 - val_loss: 8.9995e-05 - val_mean_absolute_error: 0.0079
#
# Epoch 00426: val_loss did not improve from 0.00002
# Epoch 427/500
# 1612/1612 [==============================] - 0s 43us/step - loss: 2.7692e-05 - mean_absolute_error: 0.0024 - val_loss: 6.1658e-05 - val_mean_absolute_error: 0.0064
#
# Epoch 00427: val_loss did not improve from 0.00002
# Epoch 428/500
# 1612/1612 [==============================] - 0s 30us/step - loss: 3.2606e-05 - mean_absolute_error: 0.0029 - val_loss: 1.0969e-04 - val_mean_absolute_error: 0.0090
#
# Epoch 00428: val_loss did not improve from 0.00002
# Epoch 429/500
# 1612/1612 [==============================] - 0s 30us/step - loss: 5.0991e-05 - mean_absolute_error: 0.0035 - val_loss: 8.6129e-05 - val_mean_absolute_error: 0.0077
#
# Epoch 00429: val_loss did not improve from 0.00002
# Epoch 430/500
# 1612/1612 [==============================] - 0s 23us/step - loss: 7.0368e-05 - mean_absolute_error: 0.0045 - val_loss: 1.6389e-04 - val_mean_absolute_error: 0.0115
#
# Epoch 00430: val_loss did not improve from 0.00002
# Epoch 431/500
# 1612/1612 [==============================] - 0s 27us/step - loss: 4.2410e-05 - mean_absolute_error: 0.0029 - val_loss: 4.6286e-05 - val_mean_absolute_error: 0.0055
#
# Epoch 00431: val_loss did not improve from 0.00002
# Epoch 432/500
# 1612/1612 [==============================] - 0s 32us/step - loss: 1.2323e-04 - mean_absolute_error: 0.0066 - val_loss: 4.9230e-04 - val_mean_absolute_error: 0.0213
#
# Epoch 00432: val_loss did not improve from 0.00002
# Epoch 433/500
# 1612/1612 [==============================] - 0s 48us/step - loss: 6.5968e-05 - mean_absolute_error: 0.0057 - val_loss: 2.8167e-04 - val_mean_absolute_error: 0.0152
#
# Epoch 00433: val_loss did not improve from 0.00002
# Epoch 434/500
# 1612/1612 [==============================] - 0s 30us/step - loss: 4.8387e-05 - mean_absolute_error: 0.0042 - val_loss: 1.8397e-05 - val_mean_absolute_error: 0.0036
#
# Epoch 00434: val_loss did not improve from 0.00002
# Epoch 435/500
# 1612/1612 [==============================] - 0s 44us/step - loss: 3.6683e-05 - mean_absolute_error: 0.0037 - val_loss: 1.8868e-05 - val_mean_absolute_error: 0.0035
#
# Epoch 00435: val_loss did not improve from 0.00002
# Epoch 436/500
# 1612/1612 [==============================] - 0s 39us/step - loss: 3.1940e-05 - mean_absolute_error: 0.0035 - val_loss: 9.4480e-05 - val_mean_absolute_error: 0.0084
#
# Epoch 00436: val_loss did not improve from 0.00002
# Epoch 437/500
# 1612/1612 [==============================] - 0s 26us/step - loss: 5.1671e-05 - mean_absolute_error: 0.0040 - val_loss: 1.4519e-04 - val_mean_absolute_error: 0.0109
#
# Epoch 00437: val_loss did not improve from 0.00002
# Epoch 438/500
# 1612/1612 [==============================] - 0s 35us/step - loss: 2.4650e-05 - mean_absolute_error: 0.0028 - val_loss: 1.4775e-04 - val_mean_absolute_error: 0.0114
#
# Epoch 00438: val_loss did not improve from 0.00002
# Epoch 439/500
# 1612/1612 [==============================] - 0s 56us/step - loss: 9.0824e-05 - mean_absolute_error: 0.0072 - val_loss: 6.0226e-04 - val_mean_absolute_error: 0.0242
#
# Epoch 00439: val_loss did not improve from 0.00002
# Epoch 440/500
# 1612/1612 [==============================] - 0s 52us/step - loss: 5.5106e-05 - mean_absolute_error: 0.0057 - val_loss: 2.9049e-05 - val_mean_absolute_error: 0.0047
#
# Epoch 00440: val_loss did not improve from 0.00002
# Epoch 441/500
# 1612/1612 [==============================] - 0s 29us/step - loss: 2.7953e-05 - mean_absolute_error: 0.0034 - val_loss: 1.9738e-05 - val_mean_absolute_error: 0.0038
#
# Epoch 00441: val_loss did not improve from 0.00002
# Epoch 442/500
# 1612/1612 [==============================] - 0s 23us/step - loss: 3.1623e-05 - mean_absolute_error: 0.0040 - val_loss: 1.1290e-04 - val_mean_absolute_error: 0.0099
#
# Epoch 00442: val_loss did not improve from 0.00002
# Epoch 443/500
# 1612/1612 [==============================] - 0s 25us/step - loss: 3.9842e-05 - mean_absolute_error: 0.0043 - val_loss: 1.9112e-05 - val_mean_absolute_error: 0.0034
#
# Epoch 00443: val_loss did not improve from 0.00002
# Epoch 444/500
# 1612/1612 [==============================] - 0s 24us/step - loss: 4.8001e-05 - mean_absolute_error: 0.0043 - val_loss: 3.7806e-05 - val_mean_absolute_error: 0.0049
#
# Epoch 00444: val_loss did not improve from 0.00002
# Epoch 445/500
# 1612/1612 [==============================] - 0s 35us/step - loss: 6.3486e-05 - mean_absolute_error: 0.0045 - val_loss: 4.5162e-05 - val_mean_absolute_error: 0.0056
#
# Epoch 00445: val_loss did not improve from 0.00002
# Epoch 446/500
# 1612/1612 [==============================] - 0s 25us/step - loss: 4.3810e-05 - mean_absolute_error: 0.0035 - val_loss: 1.3706e-05 - val_mean_absolute_error: 0.0031
#
# Epoch 00446: val_loss improved from 0.00002 to 0.00001, saving model to NNv2bestmodel.h5
# Epoch 447/500
# 1612/1612 [==============================] - 0s 22us/step - loss: 8.0703e-05 - mean_absolute_error: 0.0048 - val_loss: 5.7358e-05 - val_mean_absolute_error: 0.0062
#
# Epoch 00447: val_loss did not improve from 0.00001
# Epoch 448/500
# 1612/1612 [==============================] - 0s 22us/step - loss: 9.8609e-05 - mean_absolute_error: 0.0053 - val_loss: 7.8621e-05 - val_mean_absolute_error: 0.0074
#
# Epoch 00448: val_loss did not improve from 0.00001
# Epoch 449/500
# 1612/1612 [==============================] - 0s 25us/step - loss: 4.3971e-05 - mean_absolute_error: 0.0032 - val_loss: 9.6791e-05 - val_mean_absolute_error: 0.0085
#
# Epoch 00449: val_loss did not improve from 0.00001
# Epoch 450/500
# 1612/1612 [==============================] - 0s 28us/step - loss: 5.2954e-05 - mean_absolute_error: 0.0039 - val_loss: 7.6624e-05 - val_mean_absolute_error: 0.0075
#
# Epoch 00450: val_loss did not improve from 0.00001
# Epoch 451/500
# 1612/1612 [==============================] - 0s 32us/step - loss: 3.9203e-05 - mean_absolute_error: 0.0031 - val_loss: 1.3537e-05 - val_mean_absolute_error: 0.0031
#
# Epoch 00451: val_loss improved from 0.00001 to 0.00001, saving model to NNv2bestmodel.h5
# Epoch 452/500
# 1612/1612 [==============================] - 0s 38us/step - loss: 2.4443e-05 - mean_absolute_error: 0.0024 - val_loss: 3.1219e-05 - val_mean_absolute_error: 0.0044
#
# Epoch 00452: val_loss did not improve from 0.00001
# Epoch 453/500
# 1612/1612 [==============================] - 0s 28us/step - loss: 8.5502e-05 - mean_absolute_error: 0.0054 - val_loss: 1.6371e-05 - val_mean_absolute_error: 0.0034
#
# Epoch 00453: val_loss did not improve from 0.00001
# Epoch 454/500
# 1612/1612 [==============================] - 0s 30us/step - loss: 7.0971e-05 - mean_absolute_error: 0.0048 - val_loss: 1.5207e-04 - val_mean_absolute_error: 0.0109
#
# Epoch 00454: val_loss did not improve from 0.00001
# Epoch 455/500
# 1612/1612 [==============================] - 0s 33us/step - loss: 5.6148e-05 - mean_absolute_error: 0.0045 - val_loss: 5.0144e-05 - val_mean_absolute_error: 0.0057
#
# Epoch 00455: val_loss did not improve from 0.00001
# Epoch 456/500
# 1612/1612 [==============================] - 0s 33us/step - loss: 5.0365e-05 - mean_absolute_error: 0.0036 - val_loss: 1.0481e-04 - val_mean_absolute_error: 0.0089
#
# Epoch 00456: val_loss did not improve from 0.00001
# Epoch 457/500
# 1612/1612 [==============================] - 0s 28us/step - loss: 6.9297e-05 - mean_absolute_error: 0.0049 - val_loss: 1.8806e-04 - val_mean_absolute_error: 0.0127
#
# Epoch 00457: val_loss did not improve from 0.00001
# Epoch 458/500
# 1612/1612 [==============================] - 0s 30us/step - loss: 4.7638e-05 - mean_absolute_error: 0.0038 - val_loss: 1.5111e-04 - val_mean_absolute_error: 0.0113
#
# Epoch 00458: val_loss did not improve from 0.00001
# Epoch 459/500
# 1612/1612 [==============================] - 0s 37us/step - loss: 9.4281e-05 - mean_absolute_error: 0.0058 - val_loss: 1.7856e-04 - val_mean_absolute_error: 0.0118
#
# Epoch 00459: val_loss did not improve from 0.00001
# Epoch 460/500
# 1612/1612 [==============================] - 0s 70us/step - loss: 6.0738e-05 - mean_absolute_error: 0.0045 - val_loss: 1.2876e-04 - val_mean_absolute_error: 0.0098
#
# Epoch 00460: val_loss did not improve from 0.00001
# Epoch 461/500
# 1612/1612 [==============================] - 0s 43us/step - loss: 5.5894e-05 - mean_absolute_error: 0.0039 - val_loss: 1.4439e-04 - val_mean_absolute_error: 0.0106
#
# Epoch 00461: val_loss did not improve from 0.00001
# Epoch 462/500
# 1612/1612 [==============================] - 0s 37us/step - loss: 6.3727e-05 - mean_absolute_error: 0.0047 - val_loss: 4.0817e-05 - val_mean_absolute_error: 0.0053
#
# Epoch 00462: val_loss did not improve from 0.00001
# Epoch 463/500
# 1612/1612 [==============================] - 0s 40us/step - loss: 7.6254e-05 - mean_absolute_error: 0.0060 - val_loss: 5.3602e-05 - val_mean_absolute_error: 0.0060
#
# Epoch 00463: val_loss did not improve from 0.00001
# Epoch 464/500
# 1612/1612 [==============================] - 0s 30us/step - loss: 4.9643e-05 - mean_absolute_error: 0.0039 - val_loss: 2.4060e-05 - val_mean_absolute_error: 0.0042
#
# Epoch 00464: val_loss did not improve from 0.00001
# Epoch 465/500
# 1612/1612 [==============================] - 0s 27us/step - loss: 3.5145e-05 - mean_absolute_error: 0.0035 - val_loss: 1.6764e-05 - val_mean_absolute_error: 0.0034
#
# Epoch 00465: val_loss did not improve from 0.00001
# Epoch 466/500
# 1612/1612 [==============================] - 0s 57us/step - loss: 1.0727e-04 - mean_absolute_error: 0.0059 - val_loss: 7.0712e-05 - val_mean_absolute_error: 0.0072
#
# Epoch 00466: val_loss did not improve from 0.00001
# Epoch 467/500
# 1612/1612 [==============================] - 0s 73us/step - loss: 1.3222e-04 - mean_absolute_error: 0.0061 - val_loss: 1.8949e-04 - val_mean_absolute_error: 0.0126
#
# Epoch 00467: val_loss did not improve from 0.00001
# Epoch 468/500
# 1612/1612 [==============================] - 0s 53us/step - loss: 1.2582e-04 - mean_absolute_error: 0.0062 - val_loss: 1.0834e-04 - val_mean_absolute_error: 0.0090
#
# Epoch 00468: val_loss did not improve from 0.00001
# Epoch 469/500
# 1612/1612 [==============================] - 0s 27us/step - loss: 4.0947e-05 - mean_absolute_error: 0.0033 - val_loss: 1.3208e-04 - val_mean_absolute_error: 0.0100
#
# Epoch 00469: val_loss did not improve from 0.00001
# Epoch 470/500
# 1612/1612 [==============================] - 0s 28us/step - loss: 6.5717e-05 - mean_absolute_error: 0.0051 - val_loss: 2.8005e-04 - val_mean_absolute_error: 0.0156
#
# Epoch 00470: val_loss did not improve from 0.00001
# Epoch 471/500
# 1612/1612 [==============================] - 0s 30us/step - loss: 4.7908e-05 - mean_absolute_error: 0.0044 - val_loss: 1.9931e-04 - val_mean_absolute_error: 0.0128
#
# Epoch 00471: val_loss did not improve from 0.00001
# Epoch 472/500
# 1612/1612 [==============================] - 0s 32us/step - loss: 4.0429e-05 - mean_absolute_error: 0.0038 - val_loss: 1.6025e-05 - val_mean_absolute_error: 0.0033
#
# Epoch 00472: val_loss did not improve from 0.00001
# Epoch 473/500
# 1612/1612 [==============================] - 0s 48us/step - loss: 1.7740e-04 - mean_absolute_error: 0.0074 - val_loss: 1.5292e-04 - val_mean_absolute_error: 0.0114
#
# Epoch 00473: val_loss did not improve from 0.00001
# Epoch 474/500
# 1612/1612 [==============================] - 0s 36us/step - loss: 3.7427e-05 - mean_absolute_error: 0.0033 - val_loss: 7.0899e-05 - val_mean_absolute_error: 0.0069
#
# Epoch 00474: val_loss did not improve from 0.00001
# Epoch 475/500
# 1612/1612 [==============================] - 0s 37us/step - loss: 4.7643e-05 - mean_absolute_error: 0.0037 - val_loss: 3.0854e-04 - val_mean_absolute_error: 0.0166
#
# Epoch 00475: val_loss did not improve from 0.00001
# Epoch 476/500
# 1612/1612 [==============================] - 0s 41us/step - loss: 1.3553e-04 - mean_absolute_error: 0.0070 - val_loss: 4.6123e-05 - val_mean_absolute_error: 0.0055
#
# Epoch 00476: val_loss did not improve from 0.00001
# Epoch 477/500
# 1612/1612 [==============================] - 0s 29us/step - loss: 7.1091e-04 - mean_absolute_error: 0.0154 - val_loss: 7.0865e-05 - val_mean_absolute_error: 0.0070
#
# Epoch 00477: val_loss did not improve from 0.00001
# Epoch 478/500
# 1612/1612 [==============================] - 0s 36us/step - loss: 3.0675e-04 - mean_absolute_error: 0.0097 - val_loss: 0.0015 - val_mean_absolute_error: 0.0370
#
# Epoch 00478: val_loss did not improve from 0.00001
# Epoch 479/500
# 1612/1612 [==============================] - 0s 37us/step - loss: 1.4839e-04 - mean_absolute_error: 0.0082 - val_loss: 6.0086e-05 - val_mean_absolute_error: 0.0066
#
# Epoch 00479: val_loss did not improve from 0.00001
# Epoch 480/500
# 1612/1612 [==============================] - 0s 31us/step - loss: 8.1061e-05 - mean_absolute_error: 0.0059 - val_loss: 4.8906e-05 - val_mean_absolute_error: 0.0057
#
# Epoch 00480: val_loss did not improve from 0.00001
# Epoch 481/500
# 1612/1612 [==============================] - 0s 51us/step - loss: 7.8987e-05 - mean_absolute_error: 0.0048 - val_loss: 1.8339e-05 - val_mean_absolute_error: 0.0035
#
# Epoch 00481: val_loss did not improve from 0.00001
# Epoch 482/500
# 1612/1612 [==============================] - 0s 30us/step - loss: 5.6715e-05 - mean_absolute_error: 0.0047 - val_loss: 5.6559e-05 - val_mean_absolute_error: 0.0062
#
# Epoch 00482: val_loss did not improve from 0.00001
# Epoch 483/500
# 1612/1612 [==============================] - 0s 30us/step - loss: 3.1292e-05 - mean_absolute_error: 0.0031 - val_loss: 1.5028e-04 - val_mean_absolute_error: 0.0110
#
# Epoch 00483: val_loss did not improve from 0.00001
# Epoch 484/500
# 1612/1612 [==============================] - 0s 33us/step - loss: 4.3623e-05 - mean_absolute_error: 0.0035 - val_loss: 3.6722e-05 - val_mean_absolute_error: 0.0050
#
# Epoch 00484: val_loss did not improve from 0.00001
# Epoch 485/500
# 1612/1612 [==============================] - 0s 28us/step - loss: 4.8913e-05 - mean_absolute_error: 0.0039 - val_loss: 3.5137e-05 - val_mean_absolute_error: 0.0049
#
# Epoch 00485: val_loss did not improve from 0.00001
# Epoch 486/500
# 1612/1612 [==============================] - 0s 34us/step - loss: 5.0065e-05 - mean_absolute_error: 0.0040 - val_loss: 2.0355e-04 - val_mean_absolute_error: 0.0128
#
# Epoch 00486: val_loss did not improve from 0.00001
# Epoch 487/500
# 1612/1612 [==============================] - 0s 37us/step - loss: 4.0527e-05 - mean_absolute_error: 0.0038 - val_loss: 7.9067e-05 - val_mean_absolute_error: 0.0075
#
# Epoch 00487: val_loss did not improve from 0.00001
# Epoch 488/500
# 1612/1612 [==============================] - 0s 67us/step - loss: 2.7510e-05 - mean_absolute_error: 0.0026 - val_loss: 8.3568e-05 - val_mean_absolute_error: 0.0077
#
# Epoch 00488: val_loss did not improve from 0.00001
# Epoch 489/500
# 1612/1612 [==============================] - 0s 43us/step - loss: 3.0589e-05 - mean_absolute_error: 0.0033 - val_loss: 1.2495e-04 - val_mean_absolute_error: 0.0097
#
# Epoch 00489: val_loss did not improve from 0.00001
# Epoch 490/500
# 1612/1612 [==============================] - 0s 31us/step - loss: 2.7194e-05 - mean_absolute_error: 0.0029 - val_loss: 9.3271e-05 - val_mean_absolute_error: 0.0081
#
# Epoch 00490: val_loss did not improve from 0.00001
# Epoch 491/500
# 1612/1612 [==============================] - 0s 41us/step - loss: 3.3180e-05 - mean_absolute_error: 0.0037 - val_loss: 1.5487e-05 - val_mean_absolute_error: 0.0032
#
# Epoch 00491: val_loss did not improve from 0.00001
# Epoch 492/500
# 1612/1612 [==============================] - 0s 26us/step - loss: 3.6728e-05 - mean_absolute_error: 0.0039 - val_loss: 7.8584e-05 - val_mean_absolute_error: 0.0083
#
# Epoch 00492: val_loss did not improve from 0.00001
# Epoch 493/500
# 1612/1612 [==============================] - 0s 27us/step - loss: 3.5088e-05 - mean_absolute_error: 0.0037 - val_loss: 1.4919e-05 - val_mean_absolute_error: 0.0033
#
# Epoch 00493: val_loss did not improve from 0.00001
# Epoch 494/500
# 1612/1612 [==============================] - 0s 29us/step - loss: 2.3342e-05 - mean_absolute_error: 0.0030 - val_loss: 6.2211e-05 - val_mean_absolute_error: 0.0065
#
# Epoch 00494: val_loss did not improve from 0.00001
# Epoch 495/500
# 1612/1612 [==============================] - 0s 29us/step - loss: 3.0077e-05 - mean_absolute_error: 0.0029 - val_loss: 1.1504e-04 - val_mean_absolute_error: 0.0095
#
# Epoch 00495: val_loss did not improve from 0.00001
# Epoch 496/500
# 1612/1612 [==============================] - 0s 25us/step - loss: 5.6931e-05 - mean_absolute_error: 0.0043 - val_loss: 1.1342e-04 - val_mean_absolute_error: 0.0094
#
# Epoch 00496: val_loss did not improve from 0.00001
# Epoch 497/500
# 1612/1612 [==============================] - 0s 24us/step - loss: 1.3818e-04 - mean_absolute_error: 0.0073 - val_loss: 1.3197e-04 - val_mean_absolute_error: 0.0105
#
# Epoch 00497: val_loss did not improve from 0.00001
# Epoch 498/500
# 1612/1612 [==============================] - 0s 28us/step - loss: 2.0855e-04 - mean_absolute_error: 0.0084 - val_loss: 2.6170e-05 - val_mean_absolute_error: 0.0043
#
# Epoch 00498: val_loss did not improve from 0.00001
# Epoch 499/500
# 1612/1612 [==============================] - 0s 32us/step - loss: 2.6018e-04 - mean_absolute_error: 0.0106 - val_loss: 1.1138e-04 - val_mean_absolute_error: 0.0100
#
# Epoch 00499: val_loss did not improve from 0.00001
# Epoch 500/500
# 1612/1612 [==============================] - 0s 27us/step - loss: 1.8629e-04 - mean_absolute_error: 0.0074 - val_loss: 1.0222e-04 - val_mean_absolute_error: 0.0099
#
# Epoch 00500: val_loss did not improve from 0.00001

# %% [markdown]
# ## Loop to find better weights.

# %%
'''
for i in range(50):
    NN_model.fit(X_train, y_train, epochs=500, batch_size=32, validation_split = 0.2, callbacks=[mcp, es])
    predictions = NN_model.predict(X_noisetest0)
    ss=metrics.r2_score(y_test, predictions)
    if ss>0.95 :
        print('0.95 scored! after loop:', i)
        break

'''
# Out:
# "\nfor i in range(50):\n    NN_model.fit(X_train, y_train, epochs=500, batch_size=32, validation_split = 0.2, callbacks=[mcp, es])\n    predictions = NN_model.predict(X_noisetest0)\n    ss=metrics.r2_score(y_test, predictions)\n    if ss>0.95 :\n        print('0.95 scored! after loop:', i)\n        break\n\n"

# %%
# Load wights file of the best model :

wights_file = 'NNv2bestmodel983.h5' # choose the best checkpoint 
NN_model.load_weights(wights_file) # load it
NN_model.compile(loss='mean_absolute_error', optimizer=optimizer2, metrics=['mean_absolute_error'])

# %%
predictions = NN_model.predict(X_test)

# %%
predictions=predictions*y_std+y_mean

# %%
predictions[0:5]
# Out:
# array([[220.82666],
#        [224.6029 ],
#        [215.87903],
#        [214.23523],
#        [219.58801]], dtype=float32)

# %%
metrics.r2_score(y_test, predictions)
# Out:
# 0.9832355189044993

# %%
def NN_comp_plot(dnn, testy, pred, labelx, labely, ftitle):
    # Look at the results
    lw = 2
    
    fig= plt.figure(figsize=(12, 10))
   
    y_hat=predictions
     
    MAE=format(metrics.mean_absolute_error(testy, y_hat),'.3f')
    MSE=format(metrics.mean_squared_error(testy, y_hat),'.2f')
    R2=format(metrics.r2_score(testy, y_hat),'.4f')        
        
    plt.plot(y_hat, color='blue', lw=lw,
                      label='{} (MAE: {},  R^2: {})'.format(dnn, MAE, R2))
    plt.plot(testy.reset_index(drop=True), color='red', linestyle=':', lw=3,
                      label='Test data')                    
    plt.legend(loc='upper center',bbox_to_anchor=(0.5, 1.1),fontsize=12)
    plt.xlabel(labelx, fontsize=12)
    plt.ylabel(labely, fontsize=12)
    fig.suptitle(ftitle, fontsize=16)
    plt.show()

# %%
NN_comp_plot("DNN",
             y_test,
             predictions,
             "Week",
             "Pressure",
             "Deep Learning")

# %%
metrics.r2_score(y_test, predictions)
